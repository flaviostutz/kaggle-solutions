# %% [markdown]
# ## Train sea lion classifier with a convnet

# %%
INPUT_DIR = '../../input/kaggle-sea-lion/02/'
OUTPUT_DIR = '../../output/kaggle-sea-lion/05/'
#IMAGE_DIMS = (148,148,3)
IMAGE_DIMS = (84,84,3)
#IMAGE_DIMS = (32,32,3)

INPUT_DATASET_NAME = 'lion-patches-0px'
SAVE_WEIGHTS_FILE = OUTPUT_DIR + 'last-weights-medium.h5'
SAVE_MODEL_FILE = OUTPUT_DIR + 'last-model-medium.yml'
LOAD_WEIGHTS_FILE = OUTPUT_DIR + 'last-weights-medium.h5'
LOAD_MODEL_FILE = None

RECREATE_OUTPUT_DIR = False
RUN_TRAINING = True

OUTPUT_WEIGHT = (1,1,1,1,1,1)
TRAIN_EPOCHS = 100
INPUT_RANGE = 1

BATCH_SIZE=64

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import sklearn
import os
import glob

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import models

from modules.logging import logger
import modules.utils as utils
from modules.utils import Timer
import modules.logging
import modules.cnn as cnn
import modules.lions as lions
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, dirs=['tf-logs','weights'], recreate=RECREATE_OUTPUT_DIR)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
TF_LOGS_DIR = OUTPUT_DIR + 'tf-logs/'
WEIGHTS_DIR = OUTPUT_DIR + 'weights/'
input_dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)

logger.info('Output dirs created')
# Out:
# 2017-04-25 23:49:36,294 INFO Output dirs created

# %% [markdown]
# ### Prepare train, validate and test data flows

# %%
logger.info('Using dataset ' + input_dataset_path + ' as input')
h5file = h5py.File(input_dataset_path, 'r')

#used for image augmentation (creating new images for balancing)
image_augmentation_generator = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=359,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0,
        horizontal_flip=True,
        vertical_flip=True)

#applied to all images during training
image_randomize_generator = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=359,
        width_shift_range=0,
        height_shift_range=0,
        shear_range=0,
        horizontal_flip=True,
        vertical_flip=True)

logger.info('preparing train data')
train_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
train_balance_generator = utils.ClassBalancerGeneratorXY(train_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=0,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         batch_size=BATCH_SIZE,
                                                         start_ratio=0, end_ratio=0.7)
train_generator = utils.image_augmentation_xy(train_balance_generator.flow(), image_randomize_generator)
logger.info('train size=' + str(train_balance_generator.size) + ' batches=' + str(train_balance_generator.nr_batches))


logger.info('preparing valid data')
valid_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
valid_balance_generator = utils.ClassBalancerGeneratorXY(valid_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=0,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         batch_size=BATCH_SIZE,
                                                         start_ratio=0.7, end_ratio=0.85)
logger.info('valid size=' + str(valid_balance_generator.size) + ' batches=' + str(valid_balance_generator.nr_batches))



logger.info('preparing test data')
test_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
test_balance_generator = utils.ClassBalancerGeneratorXY(test_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=0,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         batch_size=BATCH_SIZE,
                                                         start_ratio=0.85, end_ratio=1)
logger.info('test size=' + str(test_balance_generator.size) + ' batches=' + str(test_balance_generator.nr_batches))

#FIXME when using 1 on end ratio size and nr_batches gets negative (h5 batch generator, not balancer...)
# Out:
# 2017-04-25 23:49:36,328 INFO Using dataset ../../input/kaggle-sea-lion/02/lion-patches-0px-84-84.h5 as input
# 2017-04-25 23:49:36,330 INFO preparing train data
# 2017-04-25 23:49:36,331 INFO loading input data for class distribution analysis...
# 2017-04-25 23:49:36,332 INFO loading Y from raw dataset
# 2017-04-25 23:49:36,333 INFO > [started] generator dump...
# 135062/135062
# 2017-04-25 23:50:17,374 INFO > [done]    generator dump (41040.930 ms)
# 2017-04-25 23:50:17,435 INFO raw sample class distribution
# 2017-04-25 23:50:17,436 INFO 0: 4930
# 2017-04-25 23:50:17,437 INFO 1: 3902
# 2017-04-25 23:50:17,438 INFO 2: 33128
# 2017-04-25 23:50:17,439 INFO 3: 17819
# 2017-04-25 23:50:17,440 INFO 4: 14882
# 2017-04-25 23:50:17,441 INFO 5: 60401
# 2017-04-25 23:50:17,442 INFO overall output samples per class: 3902
# 2017-04-25 23:50:17,442 INFO augmentation/undersampling ratio per class
# 2017-04-25 23:50:17,443 INFO SETUP FLOW 0 0.7
# 2017-04-25 23:50:17,444 INFO calculating source range according to start/end range of the desired output..
# 2017-04-25 23:50:17,445 INFO output distribution for this flow
# 2017-04-25 23:50:17,446 INFO 0: 2731 (0.79)
# 2017-04-25 23:50:17,447 INFO 1: 2731 (1.00)
# 2017-04-25 23:50:17,448 INFO 2: 2731 (0.12)
# 2017-04-25 23:50:17,449 INFO 3: 2731 (0.22)
# 2017-04-25 23:50:17,449 INFO 4: 2731 (0.26)
# 2017-04-25 23:50:17,450 INFO 5: 2731 (0.06)
# 2017-04-25 23:50:17,558 INFO source range: 0-94748 (94748)
# 2017-04-25 23:50:17,559 INFO output range: 0-16388 (16388)
# 2017-04-25 23:50:17,560 INFO train size=16388 batches=257
# 2017-04-25 23:50:17,561 INFO preparing valid data
# 2017-04-25 23:50:17,562 INFO loading input data for class distribution analysis...
# 2017-04-25 23:50:17,563 INFO loading Y from raw dataset
# 2017-04-25 23:50:17,564 INFO > [started] generator dump...
# 135062/135062
# 2017-04-25 23:50:59,019 INFO > [done]    generator dump (41454.786 ms)
# 2017-04-25 23:50:59,081 INFO raw sample class distribution
# 2017-04-25 23:50:59,082 INFO 0: 4930
# 2017-04-25 23:50:59,083 INFO 1: 3902
# 2017-04-25 23:50:59,084 INFO 2: 33128
# 2017-04-25 23:50:59,085 INFO 3: 17819
# 2017-04-25 23:50:59,087 INFO 4: 14882
# 2017-04-25 23:50:59,088 INFO 5: 60401
# 2017-04-25 23:50:59,089 INFO overall output samples per class: 3902
# 2017-04-25 23:50:59,090 INFO augmentation/undersampling ratio per class
# 2017-04-25 23:50:59,095 INFO SETUP FLOW 0.7 0.85
# 2017-04-25 23:50:59,096 INFO calculating source range according to start/end range of the desired output..
# 2017-04-25 23:50:59,097 INFO output distribution for this flow
# 2017-04-25 23:50:59,098 INFO 0: 585 (0.79)
# 2017-04-25 23:50:59,099 INFO 1: 585 (1.00)
# 2017-04-25 23:50:59,100 INFO 2: 585 (0.12)
# 2017-04-25 23:50:59,101 INFO 3: 585 (0.22)
# 2017-04-25 23:50:59,103 INFO 4: 585 (0.26)
# 2017-04-25 23:50:59,104 INFO 5: 585 (0.06)
# 2017-04-25 23:50:59,211 INFO source range: 93951-114567 (20616)
# 2017-04-25 23:50:59,212 INFO output range: 16389-19900 (3511)
# 2017-04-25 23:50:59,214 INFO valid size=3511 batches=55
# 2017-04-25 23:50:59,215 INFO preparing test data
# 2017-04-25 23:50:59,217 INFO loading input data for class distribution analysis...
# 2017-04-25 23:50:59,218 INFO loading Y from raw dataset
# 2017-04-25 23:50:59,220 INFO > [started] generator dump...
# 135062/135062
# 2017-04-25 23:51:41,612 INFO > [done]    generator dump (42391.694 ms)
# 2017-04-25 23:51:41,673 INFO raw sample class distribution
# 2017-04-25 23:51:41,675 INFO 0: 4930
# 2017-04-25 23:51:41,675 INFO 1: 3902
# 2017-04-25 23:51:41,676 INFO 2: 33128
# 2017-04-25 23:51:41,677 INFO 3: 17819
# 2017-04-25 23:51:41,678 INFO 4: 14882
# 2017-04-25 23:51:41,679 INFO 5: 60401
# 2017-04-25 23:51:41,680 INFO overall output samples per class: 3902
# 2017-04-25 23:51:41,680 INFO augmentation/undersampling ratio per class
# 2017-04-25 23:51:41,681 INFO SETUP FLOW 0.85 1
# 2017-04-25 23:51:41,682 INFO calculating source range according to start/end range of the desired output..
# 2017-04-25 23:51:41,683 INFO output distribution for this flow
# 2017-04-25 23:51:41,684 INFO 0: 585 (0.79)
# 2017-04-25 23:51:41,684 INFO 1: 585 (1.00)
# 2017-04-25 23:51:41,685 INFO 2: 585 (0.12)
# 2017-04-25 23:51:41,686 INFO 3: 585 (0.22)
# 2017-04-25 23:51:41,687 INFO 4: 585 (0.26)
# 2017-04-25 23:51:41,688 INFO 5: 585 (0.06)
# 2017-04-25 23:51:41,793 INFO source range: 114684-135061 (20377)
# 2017-04-25 23:51:41,794 INFO output range: 19901-23412 (3511)
# 2017-04-25 23:51:41,795 INFO test size=3511 batches=55

# %%
#logger.info('INPUT DATASET DATA')
#dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)
#with h5py.File(input_dataset_path, 'r') as h5file:
#    logger.info('generator')
#    input_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0.001, end_ratio=0.0012, batch_size=64)
#    X, Y = utils.dump_xy_to_array(input_generator.flow(), input_generator.size, x=True, y=True)
#    utils.show_images(X, image_labels=utils.onehot_to_label(Y), group_by_label=False, cols=10, is_bgr=True, size=2)
#
#    logger.info('x ' + str(np.shape(X)))
#    logger.info('y ' + str(np.shape(Y)))
#    logger.info(str(utils.class_distribution(Y)))

logger.info('BALANCE GENERATOR DATA')
#dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)
X_train, Y_train = utils.dump_xy_to_array(train_generator, train_balance_generator.size, x=False, y=True)
logger.info('y ' + str(np.shape(Y_train)))
logger.info(str(utils.class_distribution(Y_train)))

for xs,ys in train_balance_generator.flow():
    utils.show_images(xs, image_labels=utils.onehot_to_label(ys), cols=10, is_bgr=True, size=2)
    break
# Out:
# 2017-04-25 23:51:41,805 INFO BALANCE GENERATOR DATA
# 2017-04-25 23:51:41,806 INFO > [started] generator dump...
# 2017-04-25 23:51:41,807 INFO starting new flow...
# 16448/16388
# 2017-04-25 23:52:36,179 INFO > [done]    generator dump (54372.871 ms)
# 2017-04-25 23:52:36,180 INFO y (16388, 6)
# 2017-04-25 23:52:36,188 INFO [2755 2872 2811 2716 2481 2753]
# 2017-04-25 23:52:36,189 INFO starting new flow...
# 2017-04-25 23:52:36,301 INFO showing 64 images
# 2017-04-25 23:52:36,304 INFO > [started] generating image patches. rows=7; cols=10...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:608: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-25 23:52:43,360 INFO > [done]    generating image patches. rows=7; cols=10 (7056.721 ms)

# %% [markdown]
# ### Prepare CNN model

# %%
logger.info('Load CNN model')
#model = lions.convnet_alexnet2_lion_keras(IMAGE_DIMS)

model = None
if(LOAD_MODEL_FILE!=None and os.path.isfile(LOAD_MODEL_FILE)):
    with open(LOAD_MODEL_FILE, 'r') as model_file:
        my = model_file.read()
        model = models.model_from_yaml(my)
        logger.info('loaded model from file ' + LOAD_MODEL_FILE)
else:
    model = lions.convnet_medium_lion_keras(IMAGE_DIMS)
    logger.info('loaded model from function convnet_simple_lion_keras')
    

if(LOAD_WEIGHTS_FILE!=None and os.path.isfile(LOAD_WEIGHTS_FILE)):
    model.load_weights(LOAD_WEIGHTS_FILE)
    logger.info('Loaded model weights from ' + LOAD_WEIGHTS_FILE)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])    
logger.info('Model prepared')
# Out:
# 2017-04-25 23:52:43,393 INFO Load CNN model
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:94: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_initializer="glorot_uniform", activation="relu", padding="same")`
#   model.add(convolutional.Conv2D(64, (3, 3), activation='relu', padding='same', init='glorot_uniform'))
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:96: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_initializer="glorot_uniform", activation="relu", padding="same")`
#   model.add(convolutional.Conv2D(128, (3, 3), activation='relu', padding='same', init='glorot_uniform'))
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:98: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), kernel_initializer="glorot_uniform", activation="relu", padding="same")`
#   model.add(convolutional.Conv2D(256, (3, 3), activation='relu', padding='same', init='glorot_uniform'))
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:103: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1024, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(core.Dense(1024, activation='relu', init='glorot_uniform'))
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:105: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2048, kernel_initializer="glorot_uniform", activation="relu")`
#   model.add(core.Dense(2048, activation='relu', init='glorot_uniform'))
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/lions.py:107: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(6, kernel_initializer="glorot_uniform", activation="softmax")`
#   model.add(core.Dense(6, activation='softmax', init='glorot_uniform'))
# 2017-04-25 23:52:43,693 INFO loaded model from function convnet_simple_lion_keras
# 2017-04-25 23:52:44,419 INFO Loaded model weights from ../../output/kaggle-sea-lion/05/last-weights.h5
# 2017-04-25 23:52:44,445 INFO Model prepared

# %% [markdown]
# ## Train model

# %%
if(RUN_TRAINING):
    logger.info('Starting CNN training...')
    history = model.fit_generator(train_generator,
                  steps_per_epoch = train_balance_generator.nr_batches,
                  nb_epoch = TRAIN_EPOCHS,
                  callbacks = cnn.get_callbacks_keras(model, WEIGHTS_DIR, TF_LOGS_DIR),
                  validation_data = valid_balance_generator.flow(), 
                  validation_steps = valid_balance_generator.nr_batches,
                  verbose = 1)

    if(SAVE_MODEL_FILE!=None):
        with open(SAVE_MODEL_FILE, 'w') as model_file:
            model_file.write(model.to_yaml())
            logger.info('Saved last model to ' + SAVE_MODEL_FILE)
    
    if(SAVE_WEIGHTS_FILE!=None):
        model.save_weights(SAVE_WEIGHTS_FILE)
        logger.info('Saved last weights to ' + SAVE_WEIGHTS_FILE)
# Out:
# 2017-04-25 23:52:44,455 INFO Starting CNN training...
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# 2017-04-25 23:52:44,467 INFO Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# 2017-04-25 23:52:44,472 INFO Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# 2017-04-25 23:52:44,474 INFO Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# 2017-04-25 23:52:44,480 INFO Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# 2017-04-25 23:52:44,485 INFO Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# 2017-04-25 23:52:44,490 INFO Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# 2017-04-25 23:52:44,493 INFO Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# 2017-04-25 23:52:44,498 INFO Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# 2017-04-25 23:52:44,504 INFO Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# 2017-04-25 23:52:44,509 INFO Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# 2017-04-25 23:52:44,511 INFO Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# 2017-04-25 23:52:44,517 INFO Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# 2017-04-25 23:52:44,522 INFO Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# 2017-04-25 23:52:44,530 INFO Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# 2017-04-25 23:52:44,533 INFO Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# 2017-04-25 23:52:44,539 INFO Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# 2017-04-25 23:52:44,543 INFO Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# 2017-04-25 23:52:44,548 INFO Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2017-04-25 23:52:44,551 INFO Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2017-04-25 23:52:44,557 INFO Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# 2017-04-25 23:52:44,561 INFO Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# 2017-04-25 23:52:44,569 INFO Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2017-04-25 23:52:44,572 INFO Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2017-04-25 23:52:44,578 INFO Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:9: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., callbacks=[<keras.ca..., validation_steps=55, validation_data=<generator..., steps_per_epoch=257, verbose=1, epochs=50)`
# Epoch 1/50
# Epoch 1/50
# 256/257 [============================>.] - ETA: 0s - loss: 0.7670 - acc: 0.6893
# 2017-04-25 23:53:44,186 INFO starting new flow...
# Epoch 00000: val_acc improved from -inf to 0.73636, saving model to ../../output/kaggle-sea-lion/05/weights/weights-00-0.74.h5
# 257/257 [==============================] - 68s - loss: 0.7678 - acc: 0.6884 - val_loss: 0.6864 - val_acc: 0.7364
# 257/257 [==============================] - 68s - loss: 0.7678 - acc: 0.6884 - val_loss: 0.6864 - val_acc: 0.7364
# Epoch 2/50
# Epoch 2/50
# Epoch 00001: val_acc did not improve
# 257/257 [==============================] - 63s - loss: 0.7580 - acc: 0.6926 - val_loss: 0.7125 - val_acc: 0.7259
# 257/257 [==============================] - 63s - loss: 0.7580 - acc: 0.6926 - val_loss: 0.7125 - val_acc: 0.7259
# Epoch 3/50
# Epoch 3/50
# Epoch 00002: val_acc did not improve
# 257/257 [==============================] - 62s - loss: 0.7568 - acc: 0.6893 - val_loss: 0.7305 - val_acc: 0.7074
# 257/257 [==============================] - 62s - loss: 0.7568 - acc: 0.6893 - val_loss: 0.7305 - val_acc: 0.7074
# Epoch 4/50
# Epoch 4/50
# Epoch 00003: val_acc did not improve
# 257/257 [==============================] - 75s - loss: 0.7633 - acc: 0.6939 - val_loss: 0.7242 - val_acc: 0.7219
# 257/257 [==============================] - 75s - loss: 0.7633 - acc: 0.6939 - val_loss: 0.7242 - val_acc: 0.7219
# Epoch 5/50
# Epoch 5/50
#   4/257 [..............................] - ETA: 39s - loss: 0.7880 - acc: 0.6523
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ef53e140ebd6> in <module>()
#       7                   validation_data = valid_balance_generator.flow(),
#       8                   validation_steps = valid_balance_generator.nr_batches,
# ----> 9                   verbose = 1)
#      10
#      11     if(SAVE_MODEL_FILE!=None):
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1105                                         workers=workers,
#    1106                                         pickle_safe=pickle_safe,
# -> 1107                                         initial_epoch=initial_epoch)
#    1108
#    1109     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1883                     outs = self.train_on_batch(x, y,
#    1884                                                sample_weight=sample_weight,
# -> 1885                                                class_weight=class_weight)
#    1886
#    1887                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1626             ins = x + y + sample_weights
#    1627         self._make_train_function()
# -> 1628         outputs = self.train_function(ins)
#    1629         if len(outputs) == 1:
#    1630             return outputs[0]
#
# /usr/local/lib/python3.5/dist-packages/Keras-2.0.3-py3.5.egg/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2129         session = get_session()
#    2130         updated = session.run(self.outputs + [self.updates_op],
# -> 2131                               feed_dict=feed_dict)
#    2132         return updated[:len(self.outputs)]
#    2133
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Epoch accuracy/loss

# %%
if(RUN_TRAINING):
    logger.info('Training info')
    cnn.show_training_info_keras(history)
# Out:
# 2017-04-25 23:59:22,149 INFO Training info
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e4f04d7c1f79> in <module>()
#       1 if(RUN_TRAINING):
#       2     logger.info('Training info')
# ----> 3     cnn.show_training_info_keras(history)
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### Confusion matrix

# %%
cnn.evaluate_dataset_keras(test_balance_generator.flow(), 
                       test_balance_generator.nr_batches, 
                       test_balance_generator.size, 
                       model, 
                       class_labels=lions.CLASS_LABELS)
# Out:
# 2017-04-25 23:59:27,179 INFO Evaluating model performance (3511 samples)...
# 2017-04-25 23:59:27,181 INFO starting new flow...
# 2017-04-25 23:59:34,769 INFO Accuracy: 0.707954545455 - Loss: 0.762909415635
# 2017-04-25 23:59:34,770 INFO Predicting Y for detailed analysis...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/cnn.py:59: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(self.y_ds==None):
# 2017-04-25 23:59:42,674 INFO Number of test samples: 3511
# 2017-04-25 23:59:42,681 INFO Kappa score: 0.641456632856 (-1 bad; 0 just luck; 1 great)
# 2017-04-25 23:59:42,684 INFO
#                  precision    recall  f1-score   support
#
#    0-adult_male       0.69      0.64      0.66       589
# 1-subadult_male       0.47      0.47      0.47       512
#  2-adult_female       0.60      0.55      0.57       584
#      3-juvenile       0.66      0.64      0.65       599
#           4-pup       0.86      0.90      0.88       644
#      5-non lion       0.84      0.97      0.90       583
#
#     avg / total       0.69      0.70      0.70      3511
#
# 2017-04-25 23:59:42,684 INFO Accuracy per class:
# 2017-04-25 23:59:42,686 INFO 0-adult_male: 69.4%
# 2017-04-25 23:59:42,687 INFO 1-subadult_male: 46.9%
# 2017-04-25 23:59:42,688 INFO 2-adult_female: 60.3%
# 2017-04-25 23:59:42,689 INFO 3-juvenile: 66.1%
# 2017-04-25 23:59:42,690 INFO 4-pup: 85.9%
# 2017-04-25 23:59:42,691 INFO 5-non lion: 84.0%
# 2017-04-25 23:59:42,692 INFO Confusion matrix:
# 2017-04-25 23:59:42,694 INFO
# [[376 139  35   9   7  23]
#  [136 241  75  46   8   6]
#  [ 25  98 320 121  12   8]
#  [  5  34  98 382  55  25]
#  [  0   2   1  15 581  45]
#  [  0   0   2   5  13 563]]

# %%
a = test_balance_generator.flow()
cnn.show_predictions(a, 50, model)
