# %% [markdown]
# ## Train sea lion classifier with a convnet

# %%
INPUT_DIR = '../../input/kaggle-sea-lion/02/'
OUTPUT_DIR = '../../output/kaggle-sea-lion/05/'
#IMAGE_DIMS = (148,148,3)
IMAGE_DIMS = (84,84,3)
#IMAGE_DIMS = (32,32,3)

INPUT_DATASET_NAME = 'lion-patches-0px'
SAVE_WEIGHTS_FILE = OUTPUT_DIR + 'last-weights.h5'
SAVE_MODEL_FILE = OUTPUT_DIR + 'last-model.yml'
LOAD_WEIGHTS_FILE = None#OUTPUT_DIR + 'weights-0.72-simple.h5'
LOAD_MODEL_FILE = None

RECREATE_OUTPUT_DIR = False
RUN_TRAINING = True

OUTPUT_WEIGHT = (1,1,1,1,1,1)
TRAIN_EPOCHS = 50
INPUT_RANGE = 1

BATCH_SIZE=64

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import sklearn
import os
import glob

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import models

from modules.logging import logger
import modules.utils as utils
from modules.utils import Timer
import modules.logging
import modules.cnn as cnn
import modules.lions as lions
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, dirs=['tf-logs','weights'], recreate=RECREATE_OUTPUT_DIR)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
TF_LOGS_DIR = OUTPUT_DIR + 'tf-logs/'
WEIGHTS_DIR = OUTPUT_DIR + 'weights/'
input_dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)

logger.info('Output dirs created')
# Out:
# 2017-04-23 21:28:30,428 INFO Output dirs created

# %% [markdown]
# ### Prepare train, validate and test data flows

# %%
logger.info('Using dataset ' + input_dataset_path + ' as input')
h5file = h5py.File(input_dataset_path, 'r')

#used for image augmentation (creating new images for balancing)
image_augmentation_generator = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=359,
        width_shift_range=0,
        height_shift_range=0,
        horizontal_flip=True,
        vertical_flip=True)

#applied to all images during training
image_randomize_generator = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=True,
        featurewise_std_normalization=False,
        samplewise_std_normalization=True,
        zca_whitening=False,
        rotation_range=359,
        width_shift_range=6,
        height_shift_range=6,
        horizontal_flip=True,
        vertical_flip=True)

logger.info('preparing train data')
train_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
train_balance_generator = utils.ClassBalancerGeneratorXY(train_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=5,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         start_ratio=0, end_ratio=0.7)
train_generator = utils.image_augmentation_xy(train_balance_generator.flow(), image_randomize_generator)
logger.info('train size=' + str(train_balance_generator.size) + ' batches=' + str(train_balance_generator.nr_batches))


logger.info('preparing valid data')
valid_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
valid_balance_generator = utils.ClassBalancerGeneratorXY(valid_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=5,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         start_ratio=0.7, end_ratio=0.85)
logger.info('valid size=' + str(valid_balance_generator.size) + ' batches=' + str(valid_balance_generator.nr_batches))



logger.info('preparing test data')
test_batch_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=INPUT_RANGE)
test_balance_generator = utils.ClassBalancerGeneratorXY(test_batch_generator,
                                                         image_augmentation=image_augmentation_generator,
                                                         output_weight=OUTPUT_WEIGHT,
                                                         max_augmentation_ratio=5,
                                                         max_undersampling_ratio=1,
                                                         enforce_max_ratios=False,
                                                         start_ratio=0.85, end_ratio=1)
logger.info('test size=' + str(test_balance_generator.size) + ' batches=' + str(test_balance_generator.nr_batches))

#FIXME when using 1 on end ratio size and nr_batches gets negative (h5 batch generator, not balancer...)
# Out:
# 2017-04-23 21:28:30,460 INFO Using dataset ../../input/kaggle-sea-lion/02/lion-patches-0px-84-84.h5 as input
# 2017-04-23 21:28:30,462 INFO preparing train data
# 2017-04-23 21:28:30,464 INFO loading input data for class distribution analysis...
# 2017-04-23 21:28:30,465 INFO loading Y from raw dataset
# 2017-04-23 21:28:30,466 INFO > [started] generator dump...
# 27072/27013
# 2017-04-23 21:28:38,427 INFO > [done]    generator dump (7961.437 ms)
# 2017-04-23 21:28:38,441 INFO raw sample class distribution
# 2017-04-23 21:28:38,442 INFO 0: 992
# 2017-04-23 21:28:38,443 INFO 1: 864
# 2017-04-23 21:28:38,444 INFO 2: 6739
# 2017-04-23 21:28:38,444 INFO 3: 3436
# 2017-04-23 21:28:38,445 INFO 4: 2892
# 2017-04-23 21:28:38,446 INFO 5: 12090
# 2017-04-23 21:28:38,447 INFO overall output samples per class: 5184
# 2017-04-23 21:28:38,448 INFO augmentation/undersampling ratio per class
# 2017-04-23 21:28:38,449 INFO SETUP FLOW 0 0.7
# 2017-04-23 21:28:38,449 INFO calculating source range according to start/end range of the desired output..
# 2017-04-23 21:28:38,451 INFO output distribution for this flow
# 2017-04-23 21:28:38,452 INFO 0: 3628 (5.23)
# 2017-04-23 21:28:38,453 INFO 1: 3628 (6.00)
# 2017-04-23 21:28:38,453 INFO 2: 3628 (0.77)
# 2017-04-23 21:28:38,454 INFO 3: 3628 (1.51)
# 2017-04-23 21:28:38,455 INFO 4: 3628 (1.79)
# 2017-04-23 21:28:38,456 INFO 5: 3628 (0.43)
# 2017-04-23 21:28:38,485 INFO source range: 0-19386 (19386)
# 2017-04-23 21:28:38,486 INFO output range: 0-21772 (21772)
# 2017-04-23 21:28:38,487 INFO train size=21772 batches=341
# 2017-04-23 21:28:38,488 INFO preparing valid data
# 2017-04-23 21:28:38,489 INFO loading input data for class distribution analysis...
# 2017-04-23 21:28:38,490 INFO loading Y from raw dataset
# 2017-04-23 21:28:38,491 INFO > [started] generator dump...
# 27072/27013
# 2017-04-23 21:28:46,484 INFO > [done]    generator dump (7993.691 ms)
# 2017-04-23 21:28:46,498 INFO raw sample class distribution
# 2017-04-23 21:28:46,499 INFO 0: 992
# 2017-04-23 21:28:46,500 INFO 1: 864
# 2017-04-23 21:28:46,502 INFO 2: 6739
# 2017-04-23 21:28:46,503 INFO 3: 3436
# 2017-04-23 21:28:46,504 INFO 4: 2892
# 2017-04-23 21:28:46,505 INFO 5: 12090
# 2017-04-23 21:28:46,506 INFO overall output samples per class: 5184
# 2017-04-23 21:28:46,507 INFO augmentation/undersampling ratio per class
# 2017-04-23 21:28:46,507 INFO SETUP FLOW 0.7 0.85
# 2017-04-23 21:28:46,508 INFO calculating source range according to start/end range of the desired output..
# 2017-04-23 21:28:46,509 INFO output distribution for this flow
# 2017-04-23 21:28:46,510 INFO 0: 777 (5.23)
# 2017-04-23 21:28:46,511 INFO 1: 777 (6.00)
# 2017-04-23 21:28:46,512 INFO 2: 777 (0.77)
# 2017-04-23 21:28:46,513 INFO 3: 777 (1.51)
# 2017-04-23 21:28:46,514 INFO 4: 777 (1.79)
# 2017-04-23 21:28:46,515 INFO 5: 777 (0.43)
# 2017-04-23 21:28:46,543 INFO source range: 19394-22863 (3469)
# 2017-04-23 21:28:46,545 INFO output range: 21773-26438 (4665)
# 2017-04-23 21:28:46,546 INFO valid size=4665 batches=73
# 2017-04-23 21:28:46,546 INFO preparing test data
# 2017-04-23 21:28:46,548 INFO loading input data for class distribution analysis...
# 2017-04-23 21:28:46,549 INFO loading Y from raw dataset
# 2017-04-23 21:28:46,550 INFO > [started] generator dump...
# 27072/27013
# 2017-04-23 21:28:54,538 INFO > [done]    generator dump (7988.237 ms)
# 2017-04-23 21:28:54,552 INFO raw sample class distribution
# 2017-04-23 21:28:54,553 INFO 0: 992
# 2017-04-23 21:28:54,554 INFO 1: 864
# 2017-04-23 21:28:54,554 INFO 2: 6739
# 2017-04-23 21:28:54,555 INFO 3: 3436
# 2017-04-23 21:28:54,556 INFO 4: 2892
# 2017-04-23 21:28:54,557 INFO 5: 12090
# 2017-04-23 21:28:54,558 INFO overall output samples per class: 5184
# 2017-04-23 21:28:54,559 INFO augmentation/undersampling ratio per class
# 2017-04-23 21:28:54,560 INFO SETUP FLOW 0.85 1
# 2017-04-23 21:28:54,561 INFO calculating source range according to start/end range of the desired output..
# 2017-04-23 21:28:54,562 INFO output distribution for this flow
# 2017-04-23 21:28:54,563 INFO 0: 777 (5.23)
# 2017-04-23 21:28:54,564 INFO 1: 777 (6.00)
# 2017-04-23 21:28:54,565 INFO 2: 777 (0.77)
# 2017-04-23 21:28:54,566 INFO 3: 777 (1.51)
# 2017-04-23 21:28:54,567 INFO 4: 777 (1.79)
# 2017-04-23 21:28:54,568 INFO 5: 777 (0.43)
# 2017-04-23 21:28:54,596 INFO source range: 22881-27000 (4119)
# 2017-04-23 21:28:54,597 INFO output range: 26439-31104 (4665)
# 2017-04-23 21:28:54,598 INFO test size=4665 batches=73

# %%
#logger.info('INPUT DATASET DATA')
#dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)
#with h5py.File(input_dataset_path, 'r') as h5file:
#    logger.info('generator')
#    input_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0.001, end_ratio=0.0012, batch_size=64)
#    X, Y = utils.dump_xy_to_array(input_generator.flow(), input_generator.size, x=True, y=True)
#    utils.show_images(X, image_labels=utils.onehot_to_label(Y), group_by_label=False, cols=10, is_bgr=True, size=2)
#
#    logger.info('x ' + str(np.shape(X)))
#    logger.info('y ' + str(np.shape(Y)))
#    logger.info(str(utils.class_distribution(Y)))

logger.info('BALANCE GENERATOR DATA')
#dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)
#X_train, Y_train = utils.dump_xy_to_array(train_generator, train_balance_generator.size, x=False, y=True)
#logger.info('y ' + str(np.shape(Y_train)))
# logger.info(str(utils.class_distribution(Y_train)))

for xs,ys in train_balance_generator.flow():
    utils.show_images(xs, image_labels=utils.onehot_to_label(ys), cols=10, is_bgr=True, size=2)
    break
# Out:
# 2017-04-23 21:28:54,606 INFO BALANCE GENERATOR DATA
# 2017-04-23 21:28:54,608 INFO starting new flow...
# 2017-04-23 21:28:54,679 INFO showing 64 images
# 2017-04-23 21:28:54,681 INFO > [started] generating image patches. rows=7; cols=10...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:608: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-23 21:29:01,628 INFO > [done]    generating image patches. rows=7; cols=10 (6946.860 ms)

# %% [markdown]
# ### Prepare CNN model

# %%
logger.info('Load CNN model')
#model = lions.convnet_alexnet2_lion_keras(IMAGE_DIMS)

model = None
if(LOAD_MODEL_FILE!=None and os.path.isfile(LOAD_MODEL_FILE)):
    with open(LOAD_MODEL_FILE, 'r') as model_file:
        my = model_file.read()
        model = models.model_from_yaml(my)
        logger.info('loaded model from file ' + LOAD_MODEL_FILE)
else:
    model = lions.convnet_simple_lion_keras(IMAGE_DIMS)
    logger.info('loaded model from function simple')
    

if(LOAD_WEIGHTS_FILE!=None and os.path.isfile(LOAD_WEIGHTS_FILE)):
    model.load_weights(LOAD_WEIGHTS_FILE)
    logger.info('Loaded model weights from ' + LOAD_WEIGHTS_FILE)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])    
logger.info('Model prepared')
# Out:
# 2017-04-23 21:29:01,653 INFO Load CNN model
# 2017-04-23 21:29:01,743 INFO loaded model from function simple
# 2017-04-23 21:29:01,769 INFO Model prepared

# %% [markdown]
# ## Train model

# %%
if(RUN_TRAINING):
    logger.info('Starting CNN training...')
    history = model.fit_generator(train_generator,
                  steps_per_epoch = train_balance_generator.nr_batches,
                  nb_epoch = TRAIN_EPOCHS,
                  callbacks = cnn.get_callbacks_keras(model, WEIGHTS_DIR, TF_LOGS_DIR),
                  validation_data = valid_balance_generator.flow(), 
                  validation_steps = valid_balance_generator.nr_batches,
                  verbose = 1)

    if(SAVE_MODEL_FILE!=None):
        with open(SAVE_MODEL_FILE, 'w') as model_file:
            model_file.write(model.to_yaml())
            logger.info('Saved last model to ' + SAVE_MODEL_FILE)
    
    if(SAVE_WEIGHTS_FILE!=None):
        model.save_weights(SAVE_WEIGHTS_FILE)
        logger.info('Saved last weights to ' + SAVE_WEIGHTS_FILE)
# Out:
# 2017-04-23 21:29:01,780 INFO Starting CNN training...
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# 2017-04-23 21:29:02,217 INFO Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# 2017-04-23 21:29:02,222 INFO Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# 2017-04-23 21:29:02,225 INFO Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# 2017-04-23 21:29:02,231 INFO Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# 2017-04-23 21:29:02,236 INFO Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# 2017-04-23 21:29:02,241 INFO Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# 2017-04-23 21:29:02,244 INFO Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# 2017-04-23 21:29:02,249 INFO Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# 2017-04-23 21:29:02,254 INFO Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# 2017-04-23 21:29:02,258 INFO Summary name conv2d_3/kernel:0 is illegal; using conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# 2017-04-23 21:29:02,262 INFO Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# 2017-04-23 21:29:02,267 INFO Summary name conv2d_3/bias:0 is illegal; using conv2d_3/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# 2017-04-23 21:29:02,272 INFO Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# 2017-04-23 21:29:02,281 INFO Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# 2017-04-23 21:29:02,283 INFO Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# 2017-04-23 21:29:02,289 INFO Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# 2017-04-23 21:29:02,293 INFO Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# 2017-04-23 21:29:02,298 INFO Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2017-04-23 21:29:02,301 INFO Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2017-04-23 21:29:02,307 INFO Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# 2017-04-23 21:29:02,311 INFO Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# 2017-04-23 21:29:02,319 INFO Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2017-04-23 21:29:02,321 INFO Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2017-04-23 21:29:02,327 INFO Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:9: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., epochs=2, validation_data=<generator..., steps_per_epoch=341, validation_steps=73, callbacks=[<keras.ca..., verbose=1)`
# 2017-04-23 21:29:02,916 INFO starting new flow...
# Epoch 1/2
# Epoch 1/2
# 340/341 [============================>.] - ETA: 0s - loss: 1.7992 - acc: 0.2061
# 2017-04-23 21:30:02,123 INFO starting new flow...
# Epoch 00000: val_acc improved from -inf to 0.11751, saving model to ../../output/kaggle-sea-lion/05/weights/weights-00-0.12.h5
# 341/341 [==============================] - 66s - loss: 1.7990 - acc: 0.2060 - val_loss: 1.7716 - val_acc: 0.1175
# 341/341 [==============================] - 66s - loss: 1.7990 - acc: 0.2060 - val_loss: 1.7716 - val_acc: 0.1175
# Epoch 2/2
# Epoch 2/2
# Epoch 00001: val_acc improved from 0.11751 to 0.12265, saving model to ../../output/kaggle-sea-lion/05/weights/weights-01-0.12.h5
# 341/341 [==============================] - 64s - loss: 1.7781 - acc: 0.2035 - val_loss: 1.7745 - val_acc: 0.1226
# 341/341 [==============================] - 64s - loss: 1.7781 - acc: 0.2035 - val_loss: 1.7745 - val_acc: 0.1226
# 2017-04-23 21:31:14,414 INFO Saved last model to ../../output/kaggle-sea-lion/05/last-model.yml
# 2017-04-23 21:31:15,083 INFO Saved last weights to ../../output/kaggle-sea-lion/05/last-weights.h5

# %% [markdown]
# ### Epoch accuracy/loss

# %%
if(RUN_TRAINING):
    logger.info('Training info')
    cnn.show_training_info_keras(history)
# Out:
# 2017-04-23 21:31:15,089 INFO Training info

# %% [markdown]
# ### Confusion matrix

# %%
cnn.evaluate_dataset_keras(test_balance_generator.flow(), 
                       test_balance_generator.nr_batches, 
                       test_balance_generator.size, 
                       model, 
                       class_labels=lions.CLASS_LABELS)
# Out:
# 2017-04-23 21:31:15,351 INFO Evaluating model performance (4665 samples)...
# 2017-04-23 21:31:15,353 INFO starting new flow...
# 2017-04-23 21:31:20,127 INFO Accuracy: 0.20676369863 - Loss: 1.76085749881
# 2017-04-23 21:31:20,128 INFO Predicting Y for detailed analysis...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/cnn.py:59: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(self.y_ds==None):
# 2017-04-23 21:31:24,919 INFO Number of test samples: 4665
# 2017-04-23 21:31:24,924 INFO Kappa score: 0.0 (-1 bad; 0 just luck; 1 great)
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2017-04-23 21:31:24,927 INFO
#                  precision    recall  f1-score   support
#
#    0-adult_male       0.00      0.00      0.00       945
# 1-subadult_male       0.00      0.00      0.00       844
#  2-adult_female       0.21      1.00      0.34       969
#      3-juvenile       0.00      0.00      0.00       395
#           4-pup       0.00      0.00      0.00       598
#      5-non lion       0.00      0.00      0.00       914
#
#     avg / total       0.04      0.21      0.07      4665
#
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/cnn.py:102: RuntimeWarning: invalid value encountered in true_divide
#   acc_class = cm.diagonal()/np.sum(cm, axis=0)
# 2017-04-23 21:31:24,928 INFO Accuracy per class:
# 2017-04-23 21:31:24,929 INFO 0-adult_male: nan%
# 2017-04-23 21:31:24,930 INFO 1-subadult_male: nan%
# 2017-04-23 21:31:24,931 INFO 2-adult_female: 20.8%
# 2017-04-23 21:31:24,932 INFO 3-juvenile: nan%
# 2017-04-23 21:31:24,933 INFO 4-pup: nan%
# 2017-04-23 21:31:24,934 INFO 5-non lion: nan%
# 2017-04-23 21:31:24,935 INFO Confusion matrix:
# 2017-04-23 21:31:24,937 INFO
# [[  0   0 945   0   0   0]
#  [  0   0 844   0   0   0]
#  [  0   0 969   0   0   0]
#  [  0   0 395   0   0   0]
#  [  0   0 598   0   0   0]
#  [  0   0 914   0   0   0]]

# %%
a = test_balance_generator.flow()
cnn.show_predictions(a, 50, model)
# Out:
# 2017-04-23 21:31:25,556 INFO > [started] generator dump...
# 2017-04-23 21:31:25,557 INFO starting new flow...
# 64/50
# 2017-04-23 21:31:25,689 INFO > [done]    generator dump (133.517 ms)
# 2017-04-23 21:31:25,767 INFO showing 50 images
# 2017-04-23 21:31:25,769 INFO > [started] generating image patches. rows=5; cols=12...
# 2017-04-23 21:31:30,616 INFO > [done]    generating image patches. rows=5; cols=12 (4847.575 ms)
