# %% [markdown]
# # Export lion patches to training dataset

# %%
INPUT_DIR='../../input/sea-lion/'
OUTPUT_DIR='../../output/sea-lion/02/'
SHOW_IMAGES = True

IMAGE_DIMS = (50,50,3)

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils

# %% [markdown]
# ## Prepare output dataset

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')

x_ds = None
y_ds = None

logger.info('creating dataset')
dataset_path = OUTPUT_DIR + utils.dataset_name('lion-patches', IMAGE_DIMS)
h5file = h5py.File(dataset_path, 'w')
x_ds = h5file.create_dataset('X', (0, IMAGE_DIMS[0], IMAGE_DIMS[1], IMAGE_DIMS[2]), maxshape=(None, IMAGE_DIMS[0], IMAGE_DIMS[1], IMAGE_DIMS[2]), chunks=(1, IMAGE_DIMS[0], IMAGE_DIMS[1], IMAGE_DIMS[2]), dtype='f')
y_ds = h5file.create_dataset('Y', (0, 5), maxshape=(None, 5), dtype='f')
logger.info('done')
# Out:
# 2017-04-01 23:14:17,840 INFO Dir ../../output/sea-lion/02/ created
# 2017-04-01 23:14:17,843 INFO creating dataset
# 2017-04-01 23:14:17,849 INFO done

# %% [markdown]
# ## Process input photos and extract lions patches to dataset

# %% [markdown]
# ### Open csv files

# %%
#from MismatchedTrainImages.txt
MISMATCHED = [3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234, 242, 268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490, 499, 507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721, 767, 779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905, 909, 913, 927, 946]
logger.info('loading train.csv')
train = pd.read_csv(INPUT_DIR + "Train/train.csv")
# Out:
# 2017-04-01 23:14:17,859 INFO loading train.csv

# %% [markdown]
# ### Process each photo

# %%
logger.info('process all photos from train file')
count = 0
total_errors = np.zeros(5)
total_classes = np.zeros(5)
for row in train.itertuples():
    #load images
    train_id = row[1]
    image_raw_file = INPUT_DIR + 'Train/'+ str(train_id) +'.jpg'
    image_dotted_file = INPUT_DIR + 'TrainDotted/'+ str(train_id) +'.jpg'

    if(not os.path.isfile(image_raw_file)):
        logger.warning('file not found. skipping. file=' + image_raw_file)
        continue
    
    t = Timer('processing photo ' + image_raw_file)
    image_raw = cv2.imread(image_raw_file)
    image_dotted = cv2.imread(image_dotted_file)

    classes_count = lions.export_lions(image_raw, image_dotted, x_ds, y_ds, IMAGE_DIMS, patch_size=IMAGE_DIMS[1], debug=True)
    logger.info('detected classes count')
    logger.info(str(classes_count))
    logger.info('-----')
    logger.info('expected classes count')
    logger.info(str(row))
    logger.info('-----')
    logger.info('errors per class')
    error = np.subtract(row[2:], classes_count)
    logger.info(str(error))
    logger.info('acum errors per class')
    total_errors = np.add(total_errors, np.absolute(error))
    logger.info(str(total_errors))
    logger.info('-----')
    logger.info('acum detected classes count')
    total_classes = np.add(total_classes, classes_count)
    logger.info(str(total_classes))
    t.stop()
    
    count = count + 1
    if(count>=1): break

logger.info('ERRORS PER CLASS')
logger.info(str(total_errors))
        
h5file.close()
# Out:
# 2017-04-01 23:14:17,899 INFO process all photos from train file
# 2017-04-01 23:14:17,905 WARNING file not found. skipping. file=../../input/sea-lion/Train/0.jpg
# 2017-04-01 23:14:17,907 WARNING file not found. skipping. file=../../input/sea-lion/Train/1.jpg
# 2017-04-01 23:14:17,908 WARNING file not found. skipping. file=../../input/sea-lion/Train/2.jpg
# 2017-04-01 23:14:17,911 WARNING file not found. skipping. file=../../input/sea-lion/Train/3.jpg
# 2017-04-01 23:14:17,912 WARNING file not found. skipping. file=../../input/sea-lion/Train/4.jpg
# 2017-04-01 23:14:17,914 WARNING file not found. skipping. file=../../input/sea-lion/Train/5.jpg
# 2017-04-01 23:14:17,916 WARNING file not found. skipping. file=../../input/sea-lion/Train/6.jpg
# 2017-04-01 23:14:17,918 WARNING file not found. skipping. file=../../input/sea-lion/Train/7.jpg
# 2017-04-01 23:14:17,919 WARNING file not found. skipping. file=../../input/sea-lion/Train/8.jpg
# 2017-04-01 23:14:17,921 WARNING file not found. skipping. file=../../input/sea-lion/Train/9.jpg
# 2017-04-01 23:14:17,923 WARNING file not found. skipping. file=../../input/sea-lion/Train/10.jpg
# 2017-04-01 23:14:17,926 WARNING file not found. skipping. file=../../input/sea-lion/Train/11.jpg
# 2017-04-01 23:14:17,927 WARNING file not found. skipping. file=../../input/sea-lion/Train/12.jpg
# 2017-04-01 23:14:17,929 WARNING file not found. skipping. file=../../input/sea-lion/Train/13.jpg
# 2017-04-01 23:14:17,931 WARNING file not found. skipping. file=../../input/sea-lion/Train/14.jpg
# 2017-04-01 23:14:17,933 WARNING file not found. skipping. file=../../input/sea-lion/Train/15.jpg
# 2017-04-01 23:14:17,934 WARNING file not found. skipping. file=../../input/sea-lion/Train/16.jpg
# 2017-04-01 23:14:17,936 WARNING file not found. skipping. file=../../input/sea-lion/Train/17.jpg
# 2017-04-01 23:14:17,937 WARNING file not found. skipping. file=../../input/sea-lion/Train/18.jpg
# 2017-04-01 23:14:17,939 WARNING file not found. skipping. file=../../input/sea-lion/Train/19.jpg
# 2017-04-01 23:14:17,940 WARNING file not found. skipping. file=../../input/sea-lion/Train/20.jpg
# 2017-04-01 23:14:17,942 WARNING file not found. skipping. file=../../input/sea-lion/Train/21.jpg
# 2017-04-01 23:14:17,944 WARNING file not found. skipping. file=../../input/sea-lion/Train/22.jpg
# 2017-04-01 23:14:17,946 WARNING file not found. skipping. file=../../input/sea-lion/Train/23.jpg
# 2017-04-01 23:14:17,948 WARNING file not found. skipping. file=../../input/sea-lion/Train/24.jpg
# 2017-04-01 23:14:17,949 WARNING file not found. skipping. file=../../input/sea-lion/Train/25.jpg
