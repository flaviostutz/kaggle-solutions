# %% [markdown]
# # Export lion patches to training dataset

# %%
INPUT_DIR='../../input/kaggle-sea-lion/'
OUTPUT_DIR='../../output/kaggle-sea-lion/02/'

DEBUG = True
FORCE_IMAGE = 5

IMAGE_DIMS = (148,148,3)
LABEL_DIMS = (6,)

#%prun print('test')
#%pdb

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare output dataset

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')

x_ds = None
y_ds = None

logger.info('creating dataset')
dataset_path = OUTPUT_DIR + utils.dataset_name('lion-patches', IMAGE_DIMS)
h5file = h5py.File(dataset_path, 'w')
x_ds, y_ds = utils.create_xy_dataset(h5file, IMAGE_DIMS, LABEL_DIMS)
logger.info('done')
# Out:
# 2017-04-09 04:12:12,852 INFO Dir ../../output/kaggle-sea-lion/02/ created
# 2017-04-09 04:12:12,854 INFO creating dataset
# 2017-04-09 04:12:12,857 INFO done

# %% [markdown]
# ## Process input photos and extract lions patches to dataset

# %% [markdown]
# ### Open csv files

# %%
#from MismatchedTrainImages.txt
MISMATCHED = [3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234, 242, 268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490, 499, 507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721, 767, 779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905, 909, 913, 927, 946]
logger.info('loading train.csv')
train = pd.read_csv(INPUT_DIR + "Train/train.csv")
# Out:
# 2017-04-09 04:12:12,865 INFO loading train.csv

# %% [markdown]
# ### Process each photo

# %%
logger.info('process all photos from train file')
count = 0
total_errors = np.zeros(LABEL_DIMS[0]-1)
total_classes = np.zeros(LABEL_DIMS[0])
total_classes_added = np.zeros(LABEL_DIMS[0])
for row in train.itertuples():
    #load images
    train_id = row[1]
    
    if(FORCE_IMAGE!=None and train_id!=FORCE_IMAGE):
        continue
    
    image_raw_file = INPUT_DIR + 'Train/'+ str(train_id) +'.jpg'
    image_dotted_file = INPUT_DIR + 'TrainDotted/'+ str(train_id) +'.jpg'

    if(train_id in MISMATCHED):
        logger.warning('skipping mismatched train_id ' + str(train_id))
        continue
    
    if(not os.path.isfile(image_raw_file)):
        logger.warning('file not found. skipping. file=' + image_raw_file)
        continue

    t = Timer('processing photo ' + image_raw_file)
    image_raw = cv2.imread(image_raw_file)
    image_dotted = cv2.imread(image_dotted_file)
    
    classes_count_total, classes_count_added = lions.export_lions(image_raw, image_dotted, x_ds, y_ds, IMAGE_DIMS, debug=DEBUG, min_distance_others=50, non_lion_distance=150)
    
    utils.show_image(x_ds[0].astype('uint8'), is_bgr=True, size=2)
    
    logger.info('detected classes count')
    logger.info(str(classes_count_total))
    logger.info('-----')
    logger.info('expected classes count')
    logger.info(str(row))
    logger.info('-----')
    logger.info('errors per class')
    error = np.subtract(row[2:], classes_count_total[0:5])
    logger.info(str(error))
    logger.info('acum errors per class')
    total_errors = np.add(total_errors, np.absolute(error)[0:5])
    logger.info(str(total_errors))
    logger.info('-----')
    logger.info('acum detected classes count total')
    total_classes = np.add(total_classes, classes_count_total)
    logger.info(str(total_classes))
    logger.info('-----')
    logger.info('acum detected classes count added to dataset')
    total_classes_added = np.add(total_classes_added, classes_count_added)
    logger.info(str(total_classes_added))
    t.stop()
    
    count = count + 1

logger.info('ERRORS PER CLASS')
logger.info(str(total_errors))
        
h5file.close()
# Out:
# 2017-04-09 04:12:12,917 INFO process all photos from train file
# 2017-04-09 04:12:12,921 INFO > [started] processing photo ../../input/kaggle-sea-lion/Train/5.jpg...
# 2017-04-09 04:12:13,806 INFO sea lions found: 47
# 2017-04-09 04:12:13,808 INFO sea lions added to dataset: 14
# 2017-04-09 04:12:13,809 INFO non sea lions added to dataset: 6
# 2017-04-09 04:12:13,810 INFO dataset size: 20
# 2017-04-09 04:12:15,845 INFO showing 20 images
# 2017-04-09 04:12:15,861 INFO > [started] generating image patches. rows=3; cols=10...
# 2017-04-09 04:12:18,144 INFO > [done]    generating image patches. rows=3; cols=10 (2283.405 ms)
# 2017-04-09 04:12:18,321 INFO detected classes count
# 2017-04-09 04:12:18,323 INFO [  6.   4.  14.   4.  19.   6.]
# 2017-04-09 04:12:18,325 INFO -----
# 2017-04-09 04:12:18,326 INFO expected classes count
# 2017-04-09 04:12:18,327 INFO Pandas(Index=5, train_id=5, adult_males=6, subadult_males=4, adult_females=14, juveniles=4, pups=19)
# 2017-04-09 04:12:18,328 INFO -----
# 2017-04-09 04:12:18,330 INFO errors per class
# 2017-04-09 04:12:18,331 INFO [ 0.  0.  0.  0.  0.]
# 2017-04-09 04:12:18,333 INFO acum errors per class
# 2017-04-09 04:12:18,335 INFO [ 0.  0.  0.  0.  0.]
# 2017-04-09 04:12:18,336 INFO -----
# 2017-04-09 04:12:18,337 INFO acum detected classes count total
# 2017-04-09 04:12:18,339 INFO [  6.   4.  14.   4.  19.   6.]
# 2017-04-09 04:12:18,340 INFO -----
# 2017-04-09 04:12:18,341 INFO acum detected classes count added to dataset
# 2017-04-09 04:12:18,343 INFO [ 6.  3.  2.  1.  2.  6.]
# 2017-04-09 04:12:18,344 INFO > [done]    processing photo ../../input/kaggle-sea-lion/Train/5.jpg (5422.654 ms)
# 2017-04-09 04:12:18,348 INFO ERRORS PER CLASS
# 2017-04-09 04:12:18,350 INFO [ 0.  0.  0.  0.  0.]

# %% [markdown]
# ### Validate dataset

# %%
dataset_path = OUTPUT_DIR + utils.dataset_name('lion-patches', IMAGE_DIMS)
with h5py.File(dataset_path, 'r') as h5file:
    utils.show_images(h5file['X'][0:].astype('uint8'), image_labels=utils.categorical_to_label(h5file['Y'][0:]), is_bgr=True, cols=12, size=2)
    logger.info('class distribution')
    logger.info(str(utils.class_distribution(h5file['Y'][()])))
# Out:
# 2017-04-09 04:12:18,385 INFO showing 20 images
# 2017-04-09 04:12:18,387 INFO > [started] generating image patches. rows=3; cols=12...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:263: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(group_by_label==True and image_labels!=None):
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:283: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-09 04:12:20,963 INFO > [done]    generating image patches. rows=3; cols=12 (2576.132 ms)
# 2017-04-09 04:12:20,971 INFO class distribution
# 2017-04-09 04:12:20,974 INFO [ 12.   6.   4.   2.   4.  12.]
