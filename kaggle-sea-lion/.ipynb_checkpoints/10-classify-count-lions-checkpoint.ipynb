# %% [markdown]
# ## Classify and count sea lions from image

# %%
INPUT_DIR = '../../input/kaggle-sea-lion/'
OUTPUT_DIR = '../../output/kaggle-sea-lion/10/'
MODEL_FILE='../../output/kaggle-sea-lion/03-ok/tf-checkpoint-best9615'

IMAGE_DIMS = (84,84,3)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import sklearn
import os
import glob

from modules.logging import logger
import modules.utils as utils
from modules.utils import Timer
import modules.logging
import modules.cnn as cnn
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Initialize cnn classifier

# %% [markdown]
# ### Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')
# Out:
# 2017-04-26 22:15:51,979 INFO Dir ../../output/kaggle-sea-lion/10/ created

# %%
#from MismatchedTrainImages.txt
MISMATCHED = [3, 7, 9, 21, 30, 34, 71, 81, 89, 97, 151, 184, 215, 234, 242, 268, 290, 311, 331, 344, 380, 384, 406, 421, 469, 475, 490, 499, 507, 530, 531, 605, 607, 614, 621, 638, 644, 687, 712, 721, 767, 779, 781, 794, 800, 811, 839, 840, 869, 882, 901, 903, 905, 909, 913, 927, 946]

# %% [markdown]
# ### Prepare CNN model

# %%
logger.info('Prepare CNN for training')
network = cnn.net_alexnet_lion(IMAGE_DIMS)
model = cnn.prepare_cnn_model(network, OUTPUT_DIR, model_file=MODEL_FILE)
# Out:
# 2017-04-26 22:15:52,007 INFO Prepare CNN for training
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-6b7878e7650c> in <module>()
#       1 logger.info('Prepare CNN for training')
# ----> 2 network = cnn.net_alexnet_lion(IMAGE_DIMS)
#       3 model = cnn.prepare_cnn_model(network, OUTPUT_DIR, model_file=MODEL_FILE)
#
# AttributeError: module 'modules.cnn' has no attribute 'net_alexnet_lion'

# %% [markdown]
# ## Look for sea lions present in images

# %% [markdown]
# ### Perform a sliding window search

# %% [markdown]
# ## Verify classification/count performance

# %% [markdown]
# ## Explorations with selective search

# %%
import cv2
import matplotlib.pyplot as plt
import skimage.data
import selectivesearch
import modules.utils as utils
import numpy as np

IMAGE_DIMS = (32,32,3)
INPUT_DIR = '../../input/kaggle-sea-lion/'
INPUT_DATASET_NAME = '02/lion-patches-0px'

# %% [markdown]
# ### Explore known lions image in order to identify key characteristics

# %%
input_dataset_path = INPUT_DIR + utils.dataset_name(INPUT_DATASET_NAME, IMAGE_DIMS)
samples = None
with h5py.File(input_dataset_path, 'r') as input_h5:
    samples = input_h5['X'][20:40]
    utils.show_images(samples, cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-26 22:16:05,487 INFO showing 20 images
# 2017-04-26 22:16:05,490 INFO > [started] generating image patches. rows=3; cols=10...
# 2017-04-26 22:16:07,795 INFO > [done]    generating image patches. rows=3; cols=10 (2305.100 ms)

# %% [markdown]
# ## Mask image so only desired lion colors remain

# %%
img_file = INPUT_DIR + 'Train/0.jpg'
im0 = cv2.imread(img_file)
im = im0[2000:3000,3000:4000,:]
utils.show_image(im, is_bgr=True)

# %% [markdown]
# ### Calculage average histogram for random samples

# %%
h5file = h5py.File(input_dataset_path, 'r')
xy_generator = utils.BatchGeneratorXYH5(h5file, start_ratio=0, end_ratio=1)
samples, _ = utils.dump_xy_to_array(xy_generator.flow(), xy_generator.size, x=True, y=False, dtype='uint8', random_skip=0.9)
print(np.shape(samples))
samples_hsv = [cv2.cvtColor(s,cv2.COLOR_BGR2HSV) for s in samples]
# Out:
# 2017-04-26 22:17:43,345 INFO > [started] generator dump...
# Xds
# (0, 32, 32, 3)
# (64, 32, 32, 3)
# 640/133213Xds
# (64, 32, 32, 3)
# (128, 32, 32, 3)
# 1344/133213Xds
# (128, 32, 32, 3)
# (192, 32, 32, 3)
# 1408/133213Xds
# (192, 32, 32, 3)
# (256, 32, 32, 3)
# 2752/133213Xds
# (256, 32, 32, 3)
# (320, 32, 32, 3)
# 3712/133213Xds
# (320, 32, 32, 3)
# (384, 32, 32, 3)
# 4160/133213Xds
# (384, 32, 32, 3)
# (448, 32, 32, 3)
# 4416/133213Xds
# (448, 32, 32, 3)
# (512, 32, 32, 3)
# 4992/133213Xds
# (512, 32, 32, 3)
# (576, 32, 32, 3)
# 5888/133213Xds
# (576, 32, 32, 3)
# (640, 32, 32, 3)
# 7360/133213Xds
# (640, 32, 32, 3)
# (704, 32, 32, 3)
# 7488/133213Xds
# (704, 32, 32, 3)
# (768, 32, 32, 3)
# 7872/133213Xds
# (768, 32, 32, 3)
# (832, 32, 32, 3)
# 8448/133213Xds
# (832, 32, 32, 3)
# (896, 32, 32, 3)
# 8640/133213Xds
# (896, 32, 32, 3)
# (960, 32, 32, 3)
# 8768/133213Xds
# (960, 32, 32, 3)
# (1024, 32, 32, 3)
# 9088/133213Xds
# (1024, 32, 32, 3)
# (1088, 32, 32, 3)
# 9280/133213Xds
# (1088, 32, 32, 3)
# (1152, 32, 32, 3)
# 10112/133213Xds
# (1152, 32, 32, 3)
# (1216, 32, 32, 3)
# 10368/133213Xds
# (1216, 32, 32, 3)
# (1280, 32, 32, 3)
# 11072/133213Xds
# (1280, 32, 32, 3)
# (1344, 32, 32, 3)
# 13696/133213Xds
# (1344, 32, 32, 3)
# (1408, 32, 32, 3)
# 14272/133213Xds
# (1408, 32, 32, 3)
# (1472, 32, 32, 3)
# 14400/133213Xds
# (1472, 32, 32, 3)
# (1536, 32, 32, 3)
# 14656/133213Xds
# (1536, 32, 32, 3)
# (1600, 32, 32, 3)
# 14848/133213Xds
# (1600, 32, 32, 3)
# (1664, 32, 32, 3)
# 15808/133213Xds
# (1664, 32, 32, 3)
# (1728, 32, 32, 3)
# 16064/133213Xds
# (1728, 32, 32, 3)
# (1792, 32, 32, 3)
# 16320/133213Xds
# (1792, 32, 32, 3)
# (1856, 32, 32, 3)
# 16832/133213Xds
# (1856, 32, 32, 3)
# (1920, 32, 32, 3)
# 17984/133213Xds
# (1920, 32, 32, 3)
# (1984, 32, 32, 3)
# 19712/133213Xds
# (1984, 32, 32, 3)
# (2048, 32, 32, 3)
# 20864/133213Xds
# (2048, 32, 32, 3)
# (2112, 32, 32, 3)
# 20928/133213Xds
# (2112, 32, 32, 3)
# (2176, 32, 32, 3)
# 21120/133213Xds
# (2176, 32, 32, 3)
# (2240, 32, 32, 3)
# 21312/133213Xds
# (2240, 32, 32, 3)
# (2304, 32, 32, 3)
# 22592/133213Xds
# (2304, 32, 32, 3)
# (2368, 32, 32, 3)
# 22720/133213Xds
# (2368, 32, 32, 3)
# (2432, 32, 32, 3)
# 23936/133213Xds
# (2432, 32, 32, 3)
# (2496, 32, 32, 3)
# 24128/133213Xds
# (2496, 32, 32, 3)
# (2560, 32, 32, 3)
# 24256/133213Xds
# (2560, 32, 32, 3)
# (2624, 32, 32, 3)
# 24640/133213Xds
# (2624, 32, 32, 3)
# (2688, 32, 32, 3)
# 24768/133213Xds
# (2688, 32, 32, 3)
# (2752, 32, 32, 3)
# 24896/133213Xds
# (2752, 32, 32, 3)
# (2816, 32, 32, 3)
# 26112/133213Xds
# (2816, 32, 32, 3)
# (2880, 32, 32, 3)
# 27264/133213Xds
# (2880, 32, 32, 3)
# (2944, 32, 32, 3)
# 27328/133213Xds
# (2944, 32, 32, 3)
# (3008, 32, 32, 3)
# 29312/133213Xds
# (3008, 32, 32, 3)
# (3072, 32, 32, 3)
# 29568/133213Xds
# (3072, 32, 32, 3)
# (3136, 32, 32, 3)
# 29888/133213Xds
# (3136, 32, 32, 3)
# (3200, 32, 32, 3)
# 30784/133213Xds
# (3200, 32, 32, 3)
# (3264, 32, 32, 3)
# 33664/133213Xds
# (3264, 32, 32, 3)
# (3328, 32, 32, 3)
# 33920/133213Xds
# (3328, 32, 32, 3)
# (3392, 32, 32, 3)
# 34112/133213Xds
# (3392, 32, 32, 3)
# (3456, 32, 32, 3)
# 35648/133213Xds
# (3456, 32, 32, 3)
# (3520, 32, 32, 3)
# 36864/133213Xds
# (3520, 32, 32, 3)
# (3584, 32, 32, 3)
# 38464/133213Xds
# (3584, 32, 32, 3)
# (3648, 32, 32, 3)
# 39040/133213Xds
# (3648, 32, 32, 3)
# (3712, 32, 32, 3)
# 39232/133213Xds
# (3712, 32, 32, 3)
# (3776, 32, 32, 3)
# 39552/133213Xds
# (3776, 32, 32, 3)
# (3840, 32, 32, 3)
# 40576/133213Xds
# (3840, 32, 32, 3)
# (3904, 32, 32, 3)
# 41024/133213Xds
# (3904, 32, 32, 3)
# (3968, 32, 32, 3)
# 42048/133213Xds
# (3968, 32, 32, 3)
# (4032, 32, 32, 3)
# 43136/133213Xds
# (4032, 32, 32, 3)
# (4096, 32, 32, 3)
# 44736/133213Xds
# (4096, 32, 32, 3)
# (4160, 32, 32, 3)
# 47168/133213Xds
# (4160, 32, 32, 3)
# (4224, 32, 32, 3)
# 48448/133213Xds
# (4224, 32, 32, 3)
# (4288, 32, 32, 3)
# 49152/133213Xds
# (4288, 32, 32, 3)
# (4352, 32, 32, 3)
# 49216/133213Xds
# (4352, 32, 32, 3)
# (4416, 32, 32, 3)
# 49536/133213Xds
# (4416, 32, 32, 3)
# (4480, 32, 32, 3)
# 50112/133213Xds
# (4480, 32, 32, 3)
# (4544, 32, 32, 3)
# 50304/133213Xds
# (4544, 32, 32, 3)
# (4608, 32, 32, 3)
# 51392/133213Xds
# (4608, 32, 32, 3)
# (4672, 32, 32, 3)
# 51584/133213Xds
# (4672, 32, 32, 3)
# (4736, 32, 32, 3)
# 51904/133213Xds
# (4736, 32, 32, 3)
# (4800, 32, 32, 3)
# 52416/133213Xds
# (4800, 32, 32, 3)
# (4864, 32, 32, 3)
# 53056/133213Xds
# (4864, 32, 32, 3)
# (4928, 32, 32, 3)
# 53952/133213Xds
# (4928, 32, 32, 3)
# (4992, 32, 32, 3)
# 54400/133213Xds
# (4992, 32, 32, 3)
# (5056, 32, 32, 3)
# 55488/133213Xds
# (5056, 32, 32, 3)
# (5120, 32, 32, 3)
# 55680/133213Xds
# (5120, 32, 32, 3)
# (5184, 32, 32, 3)
# 55744/133213Xds
# (5184, 32, 32, 3)
# (5248, 32, 32, 3)
# 56832/133213Xds
# (5248, 32, 32, 3)
# (5312, 32, 32, 3)
# 57088/133213Xds
# (5312, 32, 32, 3)
# (5376, 32, 32, 3)
# 57792/133213Xds
# (5376, 32, 32, 3)
# (5440, 32, 32, 3)
# 58048/133213Xds
# (5440, 32, 32, 3)
# (5504, 32, 32, 3)
# 58368/133213Xds
# (5504, 32, 32, 3)
# (5568, 32, 32, 3)
# 59264/133213Xds
# (5568, 32, 32, 3)
# (5632, 32, 32, 3)
# 59392/133213Xds
# (5632, 32, 32, 3)
# (5696, 32, 32, 3)
# 61056/133213Xds
# (5696, 32, 32, 3)
# (5760, 32, 32, 3)
# 61568/133213Xds
# (5760, 32, 32, 3)
# (5824, 32, 32, 3)
# 62080/133213Xds
# (5824, 32, 32, 3)
# (5888, 32, 32, 3)
# 62528/133213Xds
# (5888, 32, 32, 3)
# (5952, 32, 32, 3)
# 64000/133213Xds
# (5952, 32, 32, 3)
# (6016, 32, 32, 3)
# 64320/133213Xds
# (6016, 32, 32, 3)
# (6080, 32, 32, 3)
# 64832/133213Xds
# (6080, 32, 32, 3)
# (6144, 32, 32, 3)
# 65344/133213Xds
# (6144, 32, 32, 3)
# (6208, 32, 32, 3)
# 67584/133213Xds
# (6208, 32, 32, 3)
# (6272, 32, 32, 3)
# 67840/133213Xds
# (6272, 32, 32, 3)
# (6336, 32, 32, 3)
# 68288/133213Xds
# (6336, 32, 32, 3)
# (6400, 32, 32, 3)
# 69120/133213Xds
# (6400, 32, 32, 3)
# (6464, 32, 32, 3)
# 69504/133213Xds
# (6464, 32, 32, 3)
# (6528, 32, 32, 3)
# 69632/133213Xds
# (6528, 32, 32, 3)
# (6592, 32, 32, 3)
# 69696/133213Xds
# (6592, 32, 32, 3)
# (6656, 32, 32, 3)
# 70016/133213Xds
# (6656, 32, 32, 3)
# (6720, 32, 32, 3)
# 71488/133213Xds
# (6720, 32, 32, 3)
# (6784, 32, 32, 3)
# 72256/133213Xds
# (6784, 32, 32, 3)
# (6848, 32, 32, 3)
# 72576/133213Xds
# (6848, 32, 32, 3)
# (6912, 32, 32, 3)
# 73344/133213Xds
# (6912, 32, 32, 3)
# (6976, 32, 32, 3)
# 73472/133213Xds
# (6976, 32, 32, 3)
# (7040, 32, 32, 3)
# 73664/133213Xds
# (7040, 32, 32, 3)
# (7104, 32, 32, 3)
# 74688/133213Xds
# (7104, 32, 32, 3)
# (7168, 32, 32, 3)
# 75136/133213Xds
# (7168, 32, 32, 3)
# (7232, 32, 32, 3)
# 75648/133213Xds
# (7232, 32, 32, 3)
# (7296, 32, 32, 3)
# 76096/133213Xds
# (7296, 32, 32, 3)
# (7360, 32, 32, 3)
# 77184/133213Xds
# (7360, 32, 32, 3)
# (7424, 32, 32, 3)
# 77376/133213Xds
# (7424, 32, 32, 3)
# (7488, 32, 32, 3)
# 78208/133213Xds
# (7488, 32, 32, 3)
# (7552, 32, 32, 3)
# 78272/133213Xds
# (7552, 32, 32, 3)
# (7616, 32, 32, 3)
# 78912/133213Xds
# (7616, 32, 32, 3)
# (7680, 32, 32, 3)
# 79680/133213Xds
# (7680, 32, 32, 3)
# (7744, 32, 32, 3)
# 80448/133213Xds
# (7744, 32, 32, 3)
# (7808, 32, 32, 3)
# 80832/133213Xds
# (7808, 32, 32, 3)
# (7872, 32, 32, 3)
# 81216/133213Xds
# (7872, 32, 32, 3)
# (7936, 32, 32, 3)
# 81408/133213Xds
# (7936, 32, 32, 3)
# (8000, 32, 32, 3)
# 82048/133213Xds
# (8000, 32, 32, 3)
# (8064, 32, 32, 3)
# 83328/133213Xds
# (8064, 32, 32, 3)
# (8128, 32, 32, 3)
# 83520/133213Xds
# (8128, 32, 32, 3)
# (8192, 32, 32, 3)
# 84416/133213Xds
# (8192, 32, 32, 3)
# (8256, 32, 32, 3)
# 84736/133213Xds
# (8256, 32, 32, 3)
# (8320, 32, 32, 3)
# 85312/133213Xds
# (8320, 32, 32, 3)
# (8384, 32, 32, 3)
# 85440/133213Xds
# (8384, 32, 32, 3)
# (8448, 32, 32, 3)
# 85568/133213Xds
# (8448, 32, 32, 3)
# (8512, 32, 32, 3)
# 85760/133213Xds
# (8512, 32, 32, 3)
# (8576, 32, 32, 3)
# 86080/133213Xds
# (8576, 32, 32, 3)
# (8640, 32, 32, 3)
# 86272/133213Xds
# (8640, 32, 32, 3)
# (8704, 32, 32, 3)
# 86656/133213Xds
# (8704, 32, 32, 3)
# (8768, 32, 32, 3)
# 86720/133213Xds
# (8768, 32, 32, 3)
# (8832, 32, 32, 3)
# 87360/133213Xds
# (8832, 32, 32, 3)
# (8896, 32, 32, 3)
# 88512/133213Xds
# (8896, 32, 32, 3)
# (8960, 32, 32, 3)
# 89600/133213Xds
# (8960, 32, 32, 3)
# (9024, 32, 32, 3)
# 89920/133213Xds
# (9024, 32, 32, 3)
# (9088, 32, 32, 3)
# 90176/133213Xds
# (9088, 32, 32, 3)
# (9152, 32, 32, 3)
# 90496/133213Xds
# (9152, 32, 32, 3)
# (9216, 32, 32, 3)
# 90816/133213Xds
# (9216, 32, 32, 3)
# (9280, 32, 32, 3)
# 92160/133213Xds
# (9280, 32, 32, 3)
# (9344, 32, 32, 3)
# 92864/133213Xds
# (9344, 32, 32, 3)
# (9408, 32, 32, 3)
# 92992/133213Xds
# (9408, 32, 32, 3)
# (9472, 32, 32, 3)
# 93120/133213Xds
# (9472, 32, 32, 3)
# (9536, 32, 32, 3)
# 94016/133213Xds
# (9536, 32, 32, 3)
# (9600, 32, 32, 3)
# 94208/133213Xds
# (9600, 32, 32, 3)
# (9664, 32, 32, 3)
# 94336/133213Xds
# (9664, 32, 32, 3)
# (9728, 32, 32, 3)
# 95104/133213Xds
# (9728, 32, 32, 3)
# (9792, 32, 32, 3)
# 95488/133213Xds
# (9792, 32, 32, 3)
# (9856, 32, 32, 3)
# 95552/133213Xds
# (9856, 32, 32, 3)
# (9920, 32, 32, 3)
# 96000/133213Xds
# (9920, 32, 32, 3)
# (9984, 32, 32, 3)
# 96576/133213Xds
# (9984, 32, 32, 3)
# (10048, 32, 32, 3)
# 96896/133213Xds
# (10048, 32, 32, 3)
# (10112, 32, 32, 3)
# 97984/133213Xds
# (10112, 32, 32, 3)
# (10176, 32, 32, 3)
# 98368/133213Xds
# (10176, 32, 32, 3)
# (10240, 32, 32, 3)
# 99328/133213Xds
# (10240, 32, 32, 3)
# (10304, 32, 32, 3)
# 100800/133213Xds
# (10304, 32, 32, 3)
# (10368, 32, 32, 3)
# 100864/133213Xds
# (10368, 32, 32, 3)
# (10432, 32, 32, 3)
# 100928/133213Xds
# (10432, 32, 32, 3)
# (10496, 32, 32, 3)
# 101056/133213Xds
# (10496, 32, 32, 3)
# (10560, 32, 32, 3)
# 101696/133213Xds
# (10560, 32, 32, 3)
# (10624, 32, 32, 3)
# 102272/133213Xds
# (10624, 32, 32, 3)
# (10688, 32, 32, 3)
# 102400/133213Xds
# (10688, 32, 32, 3)
# (10752, 32, 32, 3)
# 102464/133213Xds
# (10752, 32, 32, 3)
# (10816, 32, 32, 3)
# 103360/133213Xds
# (10816, 32, 32, 3)
# (10880, 32, 32, 3)
# 103808/133213Xds
# (10880, 32, 32, 3)
# (10944, 32, 32, 3)
# 103872/133213Xds
# (10944, 32, 32, 3)
# (11008, 32, 32, 3)
# 104896/133213Xds
# (11008, 32, 32, 3)
# (11072, 32, 32, 3)
# 107392/133213Xds
# (11072, 32, 32, 3)
# (11136, 32, 32, 3)
# 107584/133213Xds
# (11136, 32, 32, 3)
# (11200, 32, 32, 3)
# 108672/133213Xds
# (11200, 32, 32, 3)
# (11264, 32, 32, 3)
# 109248/133213Xds
# (11264, 32, 32, 3)
# (11328, 32, 32, 3)
# 109504/133213Xds
# (11328, 32, 32, 3)
# (11392, 32, 32, 3)
# 109952/133213Xds
# (11392, 32, 32, 3)
# (11456, 32, 32, 3)
# 110592/133213Xds
# (11456, 32, 32, 3)
# (11520, 32, 32, 3)
# 110848/133213Xds
# (11520, 32, 32, 3)
# (11584, 32, 32, 3)
# 111936/133213Xds
# (11584, 32, 32, 3)
# (11648, 32, 32, 3)
# 112192/133213Xds
# (11648, 32, 32, 3)
# (11712, 32, 32, 3)
# 113088/133213Xds
# (11712, 32, 32, 3)
# (11776, 32, 32, 3)
# 113792/133213Xds
# (11776, 32, 32, 3)
# (11840, 32, 32, 3)
# 115584/133213Xds
# (11840, 32, 32, 3)
# (11904, 32, 32, 3)
# 116672/133213Xds
# (11904, 32, 32, 3)
# (11968, 32, 32, 3)
# 117056/133213Xds
# (11968, 32, 32, 3)
# (12032, 32, 32, 3)
# 117760/133213Xds
# (12032, 32, 32, 3)
# (12096, 32, 32, 3)
# 119424/133213Xds
# (12096, 32, 32, 3)
# (12160, 32, 32, 3)
# 122368/133213Xds
# (12160, 32, 32, 3)
# (12224, 32, 32, 3)
# 123200/133213Xds
# (12224, 32, 32, 3)
# (12288, 32, 32, 3)
# 123520/133213Xds
# (12288, 32, 32, 3)
# (12352, 32, 32, 3)
# 125440/133213Xds
# (12352, 32, 32, 3)
# (12416, 32, 32, 3)
# 126080/133213Xds
# (12416, 32, 32, 3)
# (12480, 32, 32, 3)
# 126592/133213Xds
# (12480, 32, 32, 3)
# (12544, 32, 32, 3)
# 127424/133213Xds
# (12544, 32, 32, 3)
# (12608, 32, 32, 3)
# 127680/133213Xds
# (12608, 32, 32, 3)
# (12672, 32, 32, 3)
# 128128/133213Xds
# (12672, 32, 32, 3)
# (12736, 32, 32, 3)
# 128384/133213Xds
# (12736, 32, 32, 3)
# (12800, 32, 32, 3)
# 128448/133213Xds
# (12800, 32, 32, 3)
# (12864, 32, 32, 3)
# 128704/133213Xds
# (12864, 32, 32, 3)
# (12928, 32, 32, 3)
# 129024/133213Xds
# (12928, 32, 32, 3)
# (12992, 32, 32, 3)
# 129536/133213Xds
# (12992, 32, 32, 3)
# (13056, 32, 32, 3)
# 130496/133213Xds
# (13056, 32, 32, 3)
# (13120, 32, 32, 3)
# 131264/133213Xds
# (13120, 32, 32, 3)
# (13184, 32, 32, 3)
# 131840/133213Xds
# (13184, 32, 32, 3)
# (13248, 32, 32, 3)
# 132224/133213Xds
# (13248, 32, 32, 3)
# (13312, 32, 32, 3)
# 132864/133213Xds
# (13312, 32, 32, 3)
# (13376, 32, 32, 3)
# 133341/133213
# 2017-04-26 22:17:49,322 INFO > [done]    generator dump (5977.146 ms)
# (13376, 32, 32, 3)

# %% [markdown]
# ### Perform histogram backpropagation

# %%
im_hsv = cv2.cvtColor(im,cv2.COLOR_BGR2HSV)

# calculating object histogram
sample_hist = cv2.calcHist(samples_hsv,[0,1], None, [IMAGE_DIMS[0],IMAGE_DIMS[1]], [0, IMAGE_DIMS[0], 0, IMAGE_DIMS[1]])
sample_hist = cv2.normalize(sample_hist,0,255,cv2.NORM_MINMAX)

plt.hist(sample_hist)

#perform back projection of histogram
s = np.shape(im_hsv)
im_back = cv2.calcBackProject([im_hsv],[0,1],sample_hist,[0,s[0],0,s[1]],1)

# %%
# Now convolute with circular disc
disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
im_back_filter = cv2.filter2D(im_back,-1,disc)

# threshold and binary AND
_,mask = cv2.threshold(im_back_filter,50,255,cv2.THRESH_BINARY_INV)

mask = cv2.merge((mask,mask,mask))
utils.show_image(mask, size=6, is_bgr=True)

kernel = np.ones((3,3),np.uint8)
mask = cv2.erode(mask,kernel,iterations = 5)
mask = cv2.dilate(mask,kernel,iterations = 9)
utils.show_image(mask, size=6, is_bgr=True)

im_masked = cv2.bitwise_and(im_hsv,mask)
im_masked = cv2.cvtColor(im_masked,cv2.COLOR_HSV2BGR)

utils.show_image(im, size=6, is_bgr=True)
utils.show_image(im_masked, size=6, is_bgr=True)

# %%
params = cv2.SimpleBlobDetector_Params()
params.minThreshold = 150;
params.maxThreshold = 256;
params.filterByArea = True
params.minArea = 10
params.filterByCircularity = False
params.minCircularity = 0.1
params.filterByConvexity = True
params.minConvexity = 0.5
params.filterByInertia = False
params.minInertiaRatio = 0.5
detector = cv2.SimpleBlobDetector_create(params)
keypoints = detector.detect(im_masked)

im_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
utils.show_image(im_keypoints, size=12, is_bgr=True)

# %% [markdown]
# ### Find candidate areas by Selective Search

# %%
import skimage
regions = skimage.segmentation.felzenszwalb(im_masked, scale=100, sigma=0.5, min_size=10)
utils.show_image(regions, size=6)

# %%
print('selectivesearch')
img_lbl, regions = selectivesearch.selective_search(im_masked, scale=100, sigma=0.5, min_size=10)

print('filtering')
regions2 = []
for a in regions:
    size = a['size']
    r = a['rect']
    regions2 = regions2 + [r]

# %%
print('showing')
im2 = im.copy()
print(len(regions2))
count = 0
for r in regions2:
    x, y, w, h = r
    if(w==0 or h==0):
        continue
    if(20<w<120 and 20<h<120 and 0.7<(w/h)<1.3):
        cv2.rectangle(im2, (x, y), (x+w, y+h), (0,255,0), 2)
        count += 1
print(count)
utils.show_image(im2, is_bgr=True, size=14)
