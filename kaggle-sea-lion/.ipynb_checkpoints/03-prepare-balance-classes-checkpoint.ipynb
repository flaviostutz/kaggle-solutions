# %% [markdown]
# # Analyse and balance classes from dataset

# %%
INPUT_DIR='../../input/kaggle-sea-lion/02/'
OUTPUT_DIR='../../output/kaggle-sea-lion/03/'

INPUT_NAME='lion-patches-0px'

SHOW_IMAGES = True
MAX_IMAGES = 1

#IMAGE_DIMS = (148,148,3)
IMAGE_DIMS = (84,84,3)
#IMAGE_DIMS = (32,32,3)

RANDOM_SEED = 1

#%prun print('test')
#%pdb

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os
import random
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils

random.seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')
# Out:
# 2017-04-10 23:53:21,542 INFO Dir ../../output/kaggle-sea-lion/03/ created

# %% [markdown]
# ## Rebalance dataset classes

# %%
input_h5file_path = INPUT_DIR + utils.dataset_name(INPUT_NAME, IMAGE_DIMS)
output_h5file_path = OUTPUT_DIR + utils.dataset_name(INPUT_NAME + '-balanced', IMAGE_DIMS)

logger.info('loading input dataset ' + input_h5file_path)
input_h5file = h5py.File(input_h5file_path, 'r')
with input_h5file:
    logger.info('creating output dataset ' + output_h5file_path)
    output_h5file = h5py.File(output_h5file_path, 'w')
    with output_h5file:
        logger.info('balancing classes')
        utils.dataset_xy_balance_classes_image(input_h5file, output_h5file, max_augmentation_ratio=0, max_undersampling_ratio=1, classes_distribution_weight=(1,0,0,0,0,1))
# Out:
# 2017-04-10 23:53:21,557 INFO loading input dataset ../../input/kaggle-sea-lion/02/lion-patches-0px-84-84.h5
# 2017-04-10 23:53:21,559 INFO creating output dataset ../../output/kaggle-sea-lion/03/lion-patches-0px-balanced-84-84.h5
# 2017-04-10 23:53:21,561 INFO balancing classes
# 2017-04-10 23:53:21,563 INFO > [started] traversing entire dataset in order to extract population classes distribution...
# 2017-04-10 23:53:21,631 INFO > [done]    traversing entire dataset in order to extract population classes distribution (67.634 ms)
# 2017-04-10 23:53:21,632 INFO population distribution
# 2017-04-10 23:53:21,634 INFO 0: 4930.0
# 2017-04-10 23:53:21,635 INFO 1: 3902.0
# 2017-04-10 23:53:21,636 INFO 2: 33128.0
# 2017-04-10 23:53:21,638 INFO 3: 17819.0
# 2017-04-10 23:53:21,639 INFO 4: 14882.0
# 2017-04-10 23:53:21,640 INFO 5: 60401.0
# 2017-04-10 23:53:21,641 INFO targeting items per class: 3902.0
# 2017-04-10 23:53:21,643 INFO augmentation/undersampling ratio per class
# 2017-04-10 23:53:21,645 INFO 0: 0.791480730223
# 2017-04-10 23:53:21,646 INFO 1: 0.0
# 2017-04-10 23:53:21,647 INFO 2: 0.0
# 2017-04-10 23:53:21,648 INFO 3: 0.0
# 2017-04-10 23:53:21,650 INFO 4: 0.0
# 2017-04-10 23:53:21,651 INFO 5: 0.064601579444
# 2017-04-10 23:53:21,653 INFO iterating over input dataset for generating a new balanced dataset using undersampling and/or augmentation
# 2017-04-10 23:53:21,664 INFO > [started] balancing dataset...
# 1600/135062 [>.........................] 1% 5s
# 2017-04-10 23:53:26,273 INFO > [done]    balancing dataset (4608.987 ms)
# 2017-04-10 23:53:26,274 INFO done
# REACHED MAX!

# %% [markdown]
# ### Validate dataset

# %%
logger.info('class distribution BEFORE balancing')
with h5py.File(input_h5file_path, 'r') as input_h5:
    y = input_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-10 23:53:26,283 INFO class distribution BEFORE balancing
# 2017-04-10 23:53:26,352 INFO [  4930.   3902.  33128.  17819.  14882.  60401.]

# %%
logger.info('class distribution AFTER balancing')
with h5py.File(output_h5file_path, 'r') as output_h5:
    y = output_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-10 23:53:26,359 INFO class distribution AFTER balancing
# 2017-04-10 23:53:26,364 INFO [ 64.   0.   0.   0.   0.  36.]

# %%
with h5py.File(input_h5file_path, 'r') as input_h5:
    utils.show_images(input_h5['X'][0:10], cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-10 23:53:26,381 INFO showing 10 images
# 2017-04-10 23:53:26,384 INFO > [started] generating image patches. rows=2; cols=10...
# 2017-04-10 23:53:27,583 INFO > [done]    generating image patches. rows=2; cols=10 (1198.740 ms)

# %%
with h5py.File(output_h5file_path, 'r') as output_h5:
    utils.show_images(output_h5['X'][0:100], image_labels=utils.categorical_to_label(output_h5['Y'][0:100]), cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-10 23:53:27,619 INFO showing 100 images
# 2017-04-10 23:53:27,621 INFO > [started] generating image patches. rows=11; cols=10...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:388: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(group_by_label==True and image_labels!=None):
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:408: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-10 23:53:40,317 INFO > [done]    generating image patches. rows=11; cols=10 (12695.786 ms)
