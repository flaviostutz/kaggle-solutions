# %% [markdown]
# # Analyse and balance classes from dataset

# %%
INPUT_DIR='../../input/kaggle-sea-lion/02/'
OUTPUT_DIR='../../output/kaggle-sea-lion/03/'

SHOW_IMAGES = True
MAX_IMAGES = 1

IMAGE_DIMS = (148,148,3)

RANDOM_SEED = 1

#%prun print('test')
#%pdb

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os
import random
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils

random.seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')
# Out:
# 2017-04-07 02:27:19,081 INFO Dir ../../output/kaggle-sea-lion/03/ created

# %% [markdown]
# ## Rebalance dataset classes

# %%
from sklearn import preprocessing

def add_sample_to_dataset(x_ds, y_ds, x_data, y_data):
    x_shape = np.array(x_ds.shape)
    x_shape[0] = x_shape[0] + 1
    x_shape = list(x_shape)
    x_ds.resize(x_shape)
    x_ds[x_shape[0]-1] = x_data
    
    y_shape = np.array(y_ds.shape)
    y_shape[0] = y_shape[0] + 1
    y_shape = list(y_shape)
    y_ds.resize(y_shape)
    y_ds[y_shape[0]-1] = y_data

#convert from categorical to label
#Y_categorical: numpy array with one hot encoding data (ex.: 0,0,1,0,0)
def categorical_to_label(Y_categorical):
    nr_classes = Y_categorical.shape[1]
    lb = preprocessing.LabelBinarizer()
    lb.fit(np.array(range(nr_classes)))
    return lb.inverse_transform(Y_categorical)

def class_distribution(Y_categorical):
    nr_classes = Y_categorical.shape[1]
    count_classes = np.zeros(nr_classes)
    labels = categorical_to_label(Y_categorical)
    for y in labels:
        count_classes[y] = count_classes[y] + 1
    return count_classes

#max_augmentation_rotation=20, max_augmentation_shift=0, max_augmentation_scale=1, augmentation_flip_leftright=True, augmentation_flip_updown=True
def dataset_xy_balance_classes_image(input_h5file_path, output_h5file_path, max_augmentation_ratio=10, max_undersampling_ratio=0, classes_weight=1, image_data_generator=None):
    if(os.path.isfile(output_h5file_path)):
        raise Exception('Output file already exists. file=' + output_h5file_path)

    if(image_data_generator==None):
        image_data_generator = ImageDataGenerator(
            rotation_range=180.,
            fill_mode='nearest',
            cval=127.,
            horizontal_flip=True,
            vertical_flip=True,
            data_format=K.image_data_format())
        
    logger.info('loading input dataset ' + input_h5file_path)
    input_h5 = h5py.File(input_h5file_path, 'r')
    with input_h5:
        input_x_ds = input_h5['X'][50:80]#FIXME remove later
        input_y_ds = input_h5['Y'][50:80]#FIXME remove later
        x_dims = input_x_ds.shape
        y_dims = input_y_ds.shape

        nr_classes = input_y_ds.shape[1]

        t = Timer('traversing entire dataset in order to extract population classes distribution')
        count_classes = class_distribution(input_y_ds[()])
        t.stop()

        logger.info('population distribution')
        smallest_class = None
        smallest_qtty = 999999999
        largest_class = None
        largest_qtty = 0
        for i,c in enumerate(count_classes):
            logger.info(str(i) + ': ' + str(c))
            if(c<smallest_qtty):
                smallest_qtty = c
                smallest_class = i
            if(c>largest_qtty):
                largest_qtty = c
                largest_class = i

        qtty_per_class = min(smallest_qtty*max_augmentation_ratio, largest_qtty)
        logger.info('targeting items per class: ' + str(qtty_per_class))

        logger.info('augmentation/undersampling ratio per class')
        ratio_classes = np.zeros(nr_classes)
        for i,c in enumerate(count_classes):
            if(c==0):
                raise Exception('Class ' + str(i) + ' has zero samples. Aborting class balancing')
            ratio_classes[i] = qtty_per_class/c
            logger.info(str(i) + ': ' + str(ratio_classes[i]))

        ratio_classes = classes_weight * ratio_classes
            
        logger.info('creating output dataset ' + output_h5file_path)
        output_h5 = h5py.File(output_h5file_path, 'w')
        with output_h5:
            x_dims_zero = list(x_dims)
            x_dims_zero[0] = 0
            x_dims_none = list(x_dims)
            x_dims_none[0] = None

            y_dims_zero = list(y_dims)
            y_dims_zero[0] = 0
            y_dims_none = list(y_dims)
            y_dims_none[0] = None

            output_x_ds = output_h5.create_dataset('X', x_dims_zero, maxshape=x_dims_none, chunks=True, dtype='f')
            output_y_ds = output_h5.create_dataset('Y', y_dims_zero, maxshape=y_dims_none, chunks=True, dtype='f')

            logger.info('iterating over input dataset for generating a new balanced dataset using undersampling and/or augmentation')
            y_labels = categorical_to_label(input_y_ds)
            
            pending_augmentations = np.zeros(nr_classes)
            
            for i,x in enumerate(input_x_ds):
                y = input_y_ds[i]
                #x = input_x_ds[i]
                label = y_labels[i]
                r = ratio_classes[label]

                x = np.array(cv2.cvtColor(x, cv2.COLOR_BGR2RGB))
                
                #undersample
                if(r<=1):

                    #accept sample at the rate it should so we balance classes
                    rdm = random.random()
                    if(rdm<=r):
                        x1 = np.array(cv2.cvtColor(x, cv2.COLOR_RGB2BGR))
                        add_sample_to_dataset(output_x_ds, output_y_ds, x1, y)

                #augmentation
                elif(r>1):

                    #accept sample
                    x1 = np.array(cv2.cvtColor(x, cv2.COLOR_RGB2BGR))
                    add_sample_to_dataset(output_x_ds, output_y_ds, x1, y)
                    pending_augmentations[label] = pending_augmentations[label] + r

                    x_orig = [x]
                    y_data = [y]

                    pending = int(round(pending_augmentations[label]))

                    #generate augmented copies of images so we balance classes
                    if(pending>0):
                        ir = image_data_generator.flow(x_orig, y_data, batch_size=1)
                        for i in range(pending):
                            it = ir.next()
                            x1 = np.array(cv2.cvtColor(it[0], cv2.COLOR_RGB2BGR))
                            add_sample_to_dataset(output_x_ds, output_y_ds, x1, it[1])

                    pending_augmentations[label] = pending_augmentations[label] - pending
                        
    logger.info('done')

# %%
input_h5file_path = INPUT_DIR + utils.dataset_name('lion-patches-full', IMAGE_DIMS)
output_h5file_path = OUTPUT_DIR + utils.dataset_name('lion-patches', IMAGE_DIMS)

dataset_xy_balance_classes_image(input_h5file_path, output_h5file_path)

logger.info('class distribution after balancing')
with h5py.File(output_h5file_path, 'r') as output_h5:
    count_classes = class_distribution(output_h5['Y'][()])
    logger.info(str(count_classes))
    
    utils.show_images(output_h5['X'], cols=10, is_bgr=False, size=3)
# Out:
# 2017-04-07 02:27:19,442 INFO loading input dataset ../../input/kaggle-sea-lion/02/lion-patches-full-148-148.h5
# 2017-04-07 02:27:19,449 INFO > [started] traversing entire dataset in order to extract population classes distribution...
# 2017-04-07 02:27:19,450 INFO > [done]    traversing entire dataset in order to extract population classes distribution (1.691 ms)
# 2017-04-07 02:27:19,451 INFO population distribution
# 2017-04-07 02:27:19,453 INFO 0: 3.0
# 2017-04-07 02:27:19,454 INFO 1: 1.0
# 2017-04-07 02:27:19,455 INFO 2: 9.0
# 2017-04-07 02:27:19,457 INFO 3: 3.0
# 2017-04-07 02:27:19,458 INFO 4: 4.0
# 2017-04-07 02:27:19,460 INFO targeting items per class: 9.0
# 2017-04-07 02:27:19,461 INFO augmentation/undersampling ratio per class
# 2017-04-07 02:27:19,462 INFO 0: 3.0
# 2017-04-07 02:27:19,463 INFO 1: 9.0
# 2017-04-07 02:27:19,465 INFO 2: 1.0
# 2017-04-07 02:27:19,466 INFO 3: 3.0
# 2017-04-07 02:27:19,467 INFO 4: 2.25
# ...

# %% [markdown]
# ### Validate dataset
