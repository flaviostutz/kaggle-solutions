# %% [markdown]
# # Analyse and balance classes from dataset

# %%
INPUT_DIR='../../input/kaggle-sea-lion/02/'
OUTPUT_DIR='../../output/kaggle-sea-lion/03/'

INPUT_NAME='lion-patches-40px'

SHOW_IMAGES = True
MAX_IMAGES = 1

#IMAGE_DIMS = (148,148,3)
IMAGE_DIMS = (84,84,3)

RANDOM_SEED = 1

#%prun print('test')
#%pdb

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os
import random
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils

random.seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')
# Out:
# 2017-04-09 19:38:22,074 INFO Dir ../../output/kaggle-sea-lion/03/ created

# %% [markdown]
# ## Rebalance dataset classes

# %%
input_h5file_path = INPUT_DIR + utils.dataset_name(INPUT_NAME, IMAGE_DIMS)
output_h5file_path = OUTPUT_DIR + utils.dataset_name(INPUT_NAME + '-balanced', IMAGE_DIMS)

logger.info('loading input dataset ' + input_h5file_path)
input_h5file = h5py.File(input_h5file_path, 'r')
with input_h5file:
    logger.info('creating output dataset ' + output_h5file_path)
    output_h5file = h5py.File(output_h5file_path, 'w')
    with output_h5file:
        logger.info('balancing classes')
        utils.dataset_xy_balance_classes_image(input_h5file, output_h5file, max_augmentation_ratio=1, max_undersampling_ratio=1, classes_distribution_weight=(1,1,1,1,1,1), enforce_max_ratios=True)
# Out:
# 2017-04-09 19:38:22,085 INFO loading input dataset ../../input/kaggle-sea-lion/02/lion-patches-40px-148-148.h5
# 2017-04-09 19:38:22,088 INFO creating output dataset ../../output/kaggle-sea-lion/03/lion-patches-40px-balanced-148-148.h5
# 2017-04-09 19:38:22,089 INFO balancing classes
# 2017-04-09 19:38:22,091 INFO > [started] traversing entire dataset in order to extract population classes distribution...
# 2017-04-09 19:38:22,121 INFO > [done]    traversing entire dataset in order to extract population classes distribution (29.926 ms)
# 2017-04-09 19:38:22,122 INFO population distribution
# 2017-04-09 19:38:22,124 INFO 0: 4294.0
# 2017-04-09 19:38:22,125 INFO 1: 3202.0
# 2017-04-09 19:38:22,126 INFO 2: 11849.0
# 2017-04-09 19:38:22,127 INFO 3: 5350.0
# 2017-04-09 19:38:22,129 INFO 4: 3968.0
# 2017-04-09 19:38:22,130 INFO 5: 14198.0
# 2017-04-09 19:38:22,131 INFO targeting items per class: 6404.0
# 2017-04-09 19:38:22,132 INFO augmentation/undersampling ratio per class
# 2017-04-09 19:38:22,134 INFO 0: 1.49138332557
# 2017-04-09 19:38:22,135 INFO 1: 2.0
# 2017-04-09 19:38:22,136 INFO 2: 0.540467550004
# 2017-04-09 19:38:22,138 INFO 3: 1.19700934579
# 2017-04-09 19:38:22,139 INFO 4: 1.61391129032
# 2017-04-09 19:38:22,140 INFO 5: 0.451049443584
# 2017-04-09 19:38:22,142 INFO 5: 0.451049443584
# 2017-04-09 19:38:22,144 INFO iterating over input dataset for generating a new balanced dataset using undersampling and/or augmentation
# 2017-04-09 19:38:22,148 INFO > [started] balancing dataset...
# |#########################| 42600/42861 99% 726s
# 2017-04-09 19:50:33,767 INFO > [done]    balancing dataset (731618.762 ms)
# 2017-04-09 19:50:33,769 INFO done

# %% [markdown]
# ### Validate dataset

# %%
logger.info('class distribution BEFORE balancing')
with h5py.File(input_h5file_path, 'r') as input_h5:
    y = input_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-09 19:50:33,856 INFO class distribution BEFORE balancing
# 2017-04-09 19:50:33,978 INFO [  4294.   3202.  11849.   5350.   3968.  14198.]

# %%
logger.info('class distribution AFTER balancing')
with h5py.File(output_h5file_path, 'r') as output_h5:
    y = output_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-09 19:50:33,989 INFO class distribution AFTER balancing
# 2017-04-09 19:50:34,034 INFO [ 6404.  6404.  6375.  6404.  6404.  6436.]

# %%
with h5py.File(input_h5file_path, 'r') as input_h5:
    utils.show_images(input_h5['X'][0:10], cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-09 19:50:34,409 INFO showing 10 images
# 2017-04-09 19:50:34,411 INFO > [started] generating image patches. rows=2; cols=10...
# 2017-04-09 19:50:35,646 INFO > [done]    generating image patches. rows=2; cols=10 (1234.861 ms)

# %%
with h5py.File(output_h5file_path, 'r') as output_h5:
    utils.show_images(output_h5['X'][0:10], image_labels=utils.categorical_to_label(output_h5['Y'][0:10]), cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-09 19:50:35,959 INFO showing 10 images
# 2017-04-09 19:50:35,962 INFO > [started] generating image patches. rows=2; cols=10...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:291: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(group_by_label==True and image_labels!=None):
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:311: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-09 19:50:37,300 INFO > [done]    generating image patches. rows=2; cols=10 (1338.201 ms)
