# %% [markdown]
# # Analyse and balance classes from dataset

# %%
INPUT_DIR='../../input/kaggle-sea-lion/02/'
OUTPUT_DIR='../../output/kaggle-sea-lion/03/'

SHOW_IMAGES = True
MAX_IMAGES = 1

IMAGE_DIMS = (148,148,3)

RANDOM_SEED = 1

#%prun print('test')
#%pdb

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import os
import random
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

import modules.logging
from modules.logging import logger
import modules.lions as lions
from modules.utils import Timer
import modules.utils as utils

random.seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Prepare output dir

# %%
utils.mkdirs(OUTPUT_DIR, recreate=True)
modules.logging.setup_file_logger(OUTPUT_DIR + 'out.log')
logger.info('Dir ' + OUTPUT_DIR + ' created')
# Out:
# 2017-04-08 22:47:05,933 INFO Dir ../../output/kaggle-sea-lion/03/ created

# %% [markdown]
# ## Rebalance dataset classes

# %%
input_h5file_path = INPUT_DIR + utils.dataset_name('lion-patches-full', IMAGE_DIMS)
output_h5file_path = OUTPUT_DIR + utils.dataset_name('lion-patches', IMAGE_DIMS)

logger.info('loading input dataset ' + input_h5file_path)
input_h5file = h5py.File(input_h5file_path, 'r')
with input_h5file:
    logger.info('creating output dataset ' + output_h5file_path)
    output_h5file = h5py.File(output_h5file_path, 'w')
    with output_h5file:
        logger.info('balancing classes')
        utils.dataset_xy_balance_classes_image(input_h5file, output_h5file, max_augmentation_ratio=1, max_undersampling_ratio=1, classes_distribution_weight=(1,1,1,1,1), enforce_max_ratios=True)
# Out:
# 2017-04-08 22:47:05,943 INFO loading input dataset ../../input/kaggle-sea-lion/02/lion-patches-full-148-148.h5
# 2017-04-08 22:47:05,946 INFO creating output dataset ../../output/kaggle-sea-lion/03/lion-patches-148-148.h5
# 2017-04-08 22:47:05,947 INFO balancing classes
# 2017-04-08 22:47:05,949 INFO > [started] traversing entire dataset in order to extract population classes distribution...
# 2017-04-08 22:47:05,952 INFO > [done]    traversing entire dataset in order to extract population classes distribution (3.284 ms)
# 2017-04-08 22:47:05,954 INFO population distribution
# 2017-04-08 22:47:05,955 INFO 0: 14.0
# 2017-04-08 22:47:05,956 INFO 1: 8.0
# 2017-04-08 22:47:05,958 INFO 2: 58.0
# 2017-04-08 22:47:05,959 INFO 3: 12.0
# 2017-04-08 22:47:05,960 INFO 4: 48.0
# 2017-04-08 22:47:05,962 INFO targeting items per class: 16.0
# 2017-04-08 22:47:05,963 INFO augmentation/undersampling ratio per class
# 2017-04-08 22:47:05,964 INFO 0: 1.14285714286
# 2017-04-08 22:47:05,966 INFO 1: 2.0
# 2017-04-08 22:47:05,968 INFO 2: 0.275862068966
# 2017-04-08 22:47:05,969 INFO 3: 1.33333333333
# 2017-04-08 22:47:05,970 INFO 4: 0.333333333333
# 2017-04-08 22:47:05,971 INFO 4: 0.333333333333
# 2017-04-08 22:47:05,974 INFO iterating over input dataset for generating a new balanced dataset using undersampling and/or augmentation
# 2017-04-08 22:47:06,613 INFO done

# %% [markdown]
# ### Validate dataset

# %%
logger.info('class distribution BEFORE balancing')
with h5py.File(input_h5file_path, 'r') as input_h5:
    y = input_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-08 22:47:06,622 INFO class distribution BEFORE balancing
# 2017-04-08 22:47:06,625 INFO [ 14.   8.  58.  12.  48.]

# %%
logger.info('class distribution AFTER balancing')
with h5py.File(output_h5file_path, 'r') as output_h5:
    y = output_h5['Y'][()]
    count_classes = utils.class_distribution(y)
    logger.info(str(count_classes))
# Out:
# 2017-04-08 22:47:06,632 INFO class distribution AFTER balancing
# 2017-04-08 22:47:06,636 INFO [ 16.  32.  20.  32.  16.]

# %%
with h5py.File(input_h5file_path, 'r') as input_h5:
    utils.show_images(input_h5['X'], cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-08 22:47:06,643 INFO showing 70 images
# 2017-04-08 22:47:06,646 INFO > [started] generating image patches. rows=8; cols=10...
# 2017-04-08 22:47:15,169 INFO > [done]    generating image patches. rows=8; cols=10 (8522.823 ms)

# %%
with h5py.File(output_h5file_path, 'r') as output_h5:
    utils.show_images(output_h5['X'], image_labels=utils.categorical_to_label(output_h5['Y'][()]), cols=10, is_bgr=True, size=2)
# Out:
# 2017-04-08 22:47:15,192 INFO showing 58 images
# 2017-04-08 22:47:15,202 INFO > [started] generating image patches. rows=7; cols=10...
# /notebooks/datascience-snippets/kaggle-sea-lion/modules/utils.py:254: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if(image_labels!=None):
# 2017-04-08 22:47:22,846 INFO > [done]    generating image patches. rows=7; cols=10 (7643.561 ms)
