# %%
INPUT_IMAGE_W = 224
INPUT_IMAGE_H = 152
INPUT_IMAGE_D = 224

# OUTPUT_IMAGE_W = 112
# OUTPUT_IMAGE_H = 76
# OUTPUT_IMAGE_D = 112

OUTPUT_IMAGE_W = 50
OUTPUT_IMAGE_H = 34
OUTPUT_IMAGE_D = 50

SAVE_IMAGES = True

INPUT_FOLDER = '../../output/step4/'
OUTPUT_FOLDER = '../../output/step5/'

# %%
import sys
import h5py
from random import shuffle
import numpy as np
from numpy import ndarray
import pandas as pd
import statistics
import csv
import dicom
import math
from time import time
import os
import shutil
import scipy.ndimage
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.ndimage as ndimage
from scipy.ndimage.interpolation import rotate
from scipy.ndimage.interpolation import shift
import itertools
from itertools import product, combinations
from skimage import measure, morphology, transform
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import datetime
import logging

# %%
class Timer:
    def __init__(self, name, debug=True):
        self._name = name
        self._debug = debug
        self.start()
    
    def start(self):
        self._start = time()
        if(self._debug):
            logger.info('> [started] ' + self._name + '...')

    def stop(self):
        self._lastElapsed = (time()-self._start)
        if(self._debug):
            logger.info('> [done]    {} ({:.3f} ms)'.format(self._name, self._lastElapsed*1000))
            
    def elapsed(self):
        if(self._lastElapsed != None):
            return (self._lastElapsed)
        else:
            return (time()-self._start)

# %%
logger = logging.getLogger()
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
sh = logging.StreamHandler()
sh.setLevel(logging.INFO)
sh.setFormatter(formatter)
logger.addHandler(sh)

def setup_file_logger(log_file):
    hdlr = logging.FileHandler(log_file)
    hdlr.setLevel(logging.DEBUG)
    hdlr.setFormatter(formatter)
    logger.addHandler(hdlr) 
    logger.setLevel(logging.DEBUG)

# %%
def show_image(pixels, slice_pos, patient_id):
    fig1, ax1 = plt.subplots(1)
    fig1.set_size_inches(4,4)
    ax1.imshow(pixels[round(np.shape(pixels)[0]*(slice_pos-1))], cmap=plt.cm.gray)
    
    if(SAVE_IMAGES):
        file = OUTPUT_FOLDER + 'images/' + patient_id + '-' + 'slice-' + str(slice_pos) + '.jpg'
        plt.savefig(file)
        plt.close(fig1)
    else:
        plt.show()

# %%
def show_slices(pixels, patient_id, nr_slices=12, cols=4):
    fig = plt.figure()
    slice_depth = round(np.shape(pixels)[0]/nr_slices)
    rows = round(nr_slices/cols)+1
    fig.set_size_inches(cols*10, rows*10)
    for i in range(nr_slices):
        slice_pos = int(slice_depth*i)
        y = fig.add_subplot(rows,cols,i+1)
        y.imshow(pixels[slice_pos][:,:,0], cmap='gray')
        
    if(SAVE_IMAGES):
        file = OUTPUT_FOLDER + 'images/' + patient_id + '-' + 'slices.jpg'
        plt.savefig(file)
        plt.close(fig)
    else:
        plt.show()

# %%
def validate_dataset(dataset_file):
    logger.info('VALIDATING OUTPUT DATASET ' + dataset_file)

    with h5py.File(dataset_file, 'r') as h5f:
        x_ds = h5f['X']
        y_ds = h5f['Y']

        if(len(x_ds) != len(y_ds)):
            logger.error('VALIDATION ERROR: x and y datasets with different lengths')

        for px in range(len(x_ds)):
            arr = np.array(x_ds[px])
            if(not np.any(arr)):
                logger.error('VALIDATION ERROR: No image found index=' + str(px))

        for py in range(len(y_ds)):
            arr = np.array(y_ds[py])
            if(not np.any(arr)):
                logger.error('VALIDATION ERROR: No label found index=' + str(py) + 'label=' + str(arr))

        logger.info('X shape=' + str(x_ds.shape))
        logger.info('Y shape=' + str(y_ds.shape))

        logger.info('Taking some shots from the output sample for later verification')
        size = len(x_ds)
        qtty = min(10, size)
        f = size/qtty
        for i in range(qtty):
            pi = round(i*f)
            logger.info('patient_index ' + str(pi))
            logger.info('x=')
            show_slices(x_ds[pi], 'validation-' + str(pi))
            logger.info('y=' + str(y_ds[pi]))

# %%
def start_processing(input_dir, input_image_w, input_image_h, input_image_d, output_image_w, output_image_h, output_image_d, output_dir):
    logger.info('Resizing images. input_dir='+ str(input_dir) + ' output_dir=' + output_dir)
    
    t = Timer('Preparing output dir')
    shutil.rmtree(output_dir, True)
    try:
        os.makedirs(output_dir + 'images')
    except:
        logger.warning('Ops! Couldnt create output dir')
        pass
    t.stop()

    setup_file_logger(output_dir + 'out.log')

    t = Timer('Starting to resize dataset')
    resize_factor = (output_image_d/input_image_d, output_image_h/input_image_h, output_image_w/input_image_w, 1)
    dataset_file = input_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(input_image_w, input_image_h, input_image_d)
    with h5py.File(dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        len_input_x_ds = len(input_x_ds)
        len_input_y_ds = len(input_y_ds)

        output_dataset_file = output_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(output_image_w, output_image_h, output_image_d)
        with h5py.File(output_dataset_file, 'w') as output_h5f:
            output_x_ds = output_h5f.create_dataset('X', (len_input_x_ds, output_image_d, output_image_h, output_image_w, 1), chunks=(1, output_image_d, output_image_h, output_image_w, 1), dtype='f')
            output_y_ds = output_h5f.create_dataset('Y', (len_input_y_ds, 2), dtype='f')

            for pi in range(len_input_x_ds):
                ts = Timer('Resizing patient index ' + str(pi))
                image_pixels = input_x_ds[pi]
                image_pixels = scipy.ndimage.interpolation.zoom(image_pixels, resize_factor)
                logger.info('resized shape=' + str(np.shape(image_pixels)))
                output_x_ds[pi] = image_pixels
                output_y_ds[pi] = input_y_ds[pi]
                ts.stop()
    t.stop()
            
    t = Timer('Output dataset validations')
    validate_dataset(output_dataset_file)
    t.stop()

# %%
logger.info('==== PROCESSING SHARDS MERGE ====')
start_processing(INPUT_FOLDER, INPUT_IMAGE_W, INPUT_IMAGE_H, INPUT_IMAGE_D, OUTPUT_IMAGE_W, OUTPUT_IMAGE_H, OUTPUT_IMAGE_D, OUTPUT_FOLDER)
logger.info('==== ALL DONE ====')
# Out:
# 2017-02-19 19:57:27,352 INFO > [started] Starting to resize dataset...
# 2017-02-19 19:57:27,354 INFO input x shape=(38, 224, 152, 224, 1)
# 2017-02-19 19:57:27,358 INFO > [started] Resizing patient index 0...
# 2017-02-19 19:57:28,023 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:28,025 INFO > [done]    Resizing patient index 0 (667.095 ms)
# 2017-02-19 19:57:28,026 INFO > [started] Resizing patient index 1...
# 2017-02-19 19:57:28,663 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:28,665 INFO > [done]    Resizing patient index 1 (638.986 ms)
# 2017-02-19 19:57:28,666 INFO > [started] Resizing patient index 2...
# 2017-02-19 19:57:29,324 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:29,326 INFO > [done]    Resizing patient index 2 (659.935 ms)
# 2017-02-19 19:57:29,327 INFO > [started] Resizing patient index 3...
# 2017-02-19 19:57:29,985 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:29,987 INFO > [done]    Resizing patient index 3 (660.517 ms)
# 2017-02-19 19:57:29,988 INFO > [started] Resizing patient index 4...
# 2017-02-19 19:57:30,638 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:30,640 INFO > [done]    Resizing patient index 4 (651.519 ms)
# 2017-02-19 19:57:30,641 INFO > [started] Resizing patient index 5...
# 2017-02-19 19:57:31,272 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:31,274 INFO > [done]    Resizing patient index 5 (633.126 ms)
# 2017-02-19 19:57:31,275 INFO > [started] Resizing patient index 6...
# 2017-02-19 19:57:31,935 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:31,937 INFO > [done]    Resizing patient index 6 (661.967 ms)
# 2017-02-19 19:57:31,938 INFO > [started] Resizing patient index 7...
# 2017-02-19 19:57:32,587 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:32,590 INFO > [done]    Resizing patient index 7 (652.212 ms)
# 2017-02-19 19:57:32,591 INFO > [started] Resizing patient index 8...
# 2017-02-19 19:57:33,210 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:33,213 INFO > [done]    Resizing patient index 8 (621.560 ms)
# 2017-02-19 19:57:33,214 INFO > [started] Resizing patient index 9...
# 2017-02-19 19:57:33,898 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:33,900 INFO > [done]    Resizing patient index 9 (686.062 ms)
# 2017-02-19 19:57:33,901 INFO > [started] Resizing patient index 10...
# 2017-02-19 19:57:34,541 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:34,543 INFO > [done]    Resizing patient index 10 (642.659 ms)
# 2017-02-19 19:57:34,544 INFO > [started] Resizing patient index 11...
# 2017-02-19 19:57:35,194 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:35,196 INFO > [done]    Resizing patient index 11 (651.111 ms)
# 2017-02-19 19:57:35,196 INFO > [started] Resizing patient index 12...
# 2017-02-19 19:57:35,841 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:35,843 INFO > [done]    Resizing patient index 12 (646.559 ms)
# 2017-02-19 19:57:35,844 INFO > [started] Resizing patient index 13...
# 2017-02-19 19:57:36,469 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:36,471 INFO > [done]    Resizing patient index 13 (627.312 ms)
# 2017-02-19 19:57:36,472 INFO > [started] Resizing patient index 14...
# 2017-02-19 19:57:37,124 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:37,126 INFO > [done]    Resizing patient index 14 (654.209 ms)
# 2017-02-19 19:57:37,127 INFO > [started] Resizing patient index 15...
# 2017-02-19 19:57:37,756 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:37,758 INFO > [done]    Resizing patient index 15 (630.671 ms)
# 2017-02-19 19:57:37,758 INFO > [started] Resizing patient index 16...
# 2017-02-19 19:57:38,412 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:38,414 INFO > [done]    Resizing patient index 16 (655.559 ms)
# 2017-02-19 19:57:38,415 INFO > [started] Resizing patient index 17...
# 2017-02-19 19:57:39,061 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:39,063 INFO > [done]    Resizing patient index 17 (648.349 ms)
# 2017-02-19 19:57:39,064 INFO > [started] Resizing patient index 18...
# 2017-02-19 19:57:39,733 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:39,735 INFO > [done]    Resizing patient index 18 (670.389 ms)
# 2017-02-19 19:57:39,735 INFO > [started] Resizing patient index 19...
# 2017-02-19 19:57:40,386 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:40,388 INFO > [done]    Resizing patient index 19 (652.656 ms)
# 2017-02-19 19:57:40,389 INFO > [started] Resizing patient index 20...
# 2017-02-19 19:57:41,047 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:41,049 INFO > [done]    Resizing patient index 20 (659.525 ms)
# 2017-02-19 19:57:41,049 INFO > [started] Resizing patient index 21...
# 2017-02-19 19:57:41,711 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:41,712 INFO > [done]    Resizing patient index 21 (662.981 ms)
# 2017-02-19 19:57:41,713 INFO > [started] Resizing patient index 22...
# 2017-02-19 19:57:42,345 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:42,347 INFO > [done]    Resizing patient index 22 (633.488 ms)
# 2017-02-19 19:57:42,348 INFO > [started] Resizing patient index 23...
# 2017-02-19 19:57:42,973 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:42,975 INFO > [done]    Resizing patient index 23 (627.427 ms)
# 2017-02-19 19:57:42,976 INFO > [started] Resizing patient index 24...
# 2017-02-19 19:57:43,634 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:43,636 INFO > [done]    Resizing patient index 24 (660.272 ms)
# 2017-02-19 19:57:43,637 INFO > [started] Resizing patient index 25...
# 2017-02-19 19:57:44,342 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:44,344 INFO > [done]    Resizing patient index 25 (707.213 ms)
# 2017-02-19 19:57:44,346 INFO > [started] Resizing patient index 26...
# 2017-02-19 19:57:44,996 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:44,999 INFO > [done]    Resizing patient index 26 (652.416 ms)
# 2017-02-19 19:57:44,999 INFO > [started] Resizing patient index 27...
# 2017-02-19 19:57:45,729 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:45,732 INFO > [done]    Resizing patient index 27 (732.218 ms)
# 2017-02-19 19:57:45,733 INFO > [started] Resizing patient index 28...
# 2017-02-19 19:57:46,405 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:46,407 INFO > [done]    Resizing patient index 28 (674.244 ms)
# 2017-02-19 19:57:46,408 INFO > [started] Resizing patient index 29...
# 2017-02-19 19:57:47,052 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:47,054 INFO > [done]    Resizing patient index 29 (646.056 ms)
# 2017-02-19 19:57:47,054 INFO > [started] Resizing patient index 30...
# 2017-02-19 19:57:47,688 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:47,690 INFO > [done]    Resizing patient index 30 (635.169 ms)
# 2017-02-19 19:57:47,690 INFO > [started] Resizing patient index 31...
# 2017-02-19 19:57:48,346 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:48,348 INFO > [done]    Resizing patient index 31 (657.662 ms)
# 2017-02-19 19:57:48,351 INFO > [started] Resizing patient index 32...
# 2017-02-19 19:57:49,006 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:49,008 INFO > [done]    Resizing patient index 32 (657.625 ms)
# 2017-02-19 19:57:49,009 INFO > [started] Resizing patient index 33...
# 2017-02-19 19:57:49,673 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:49,675 INFO > [done]    Resizing patient index 33 (665.745 ms)
# 2017-02-19 19:57:49,676 INFO > [started] Resizing patient index 34...
# 2017-02-19 19:57:50,334 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:50,336 INFO > [done]    Resizing patient index 34 (660.530 ms)
# 2017-02-19 19:57:50,337 INFO > [started] Resizing patient index 35...
# 2017-02-19 19:57:50,958 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:50,960 INFO > [done]    Resizing patient index 35 (622.366 ms)
# 2017-02-19 19:57:50,961 INFO > [started] Resizing patient index 36...
# 2017-02-19 19:57:51,615 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:51,617 INFO > [done]    Resizing patient index 36 (656.506 ms)
# 2017-02-19 19:57:51,618 INFO > [started] Resizing patient index 37...
# 2017-02-19 19:57:52,252 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 19:57:52,254 INFO > [done]    Resizing patient index 37 (635.915 ms)
# 2017-02-19 19:57:52,256 INFO > [done]    Starting to resize dataset (24904.035 ms)
# 2017-02-19 19:57:52,257 INFO > [started] Output dataset validations...
# 2017-02-19 19:57:52,258 INFO VALIDATING OUTPUT DATASET ../../output/step5/data-centered-rotated-50-34-50.h5
# 2017-02-19 19:57:52,280 INFO X shape=(38, 50, 34, 50, 1)
# 2017-02-19 19:57:52,281 INFO Y shape=(38, 2)
# 2017-02-19 19:57:52,282 INFO Taking some shots from the output sample for later verification
# 2017-02-19 19:57:52,283 INFO patient_index 0
# 2017-02-19 19:57:52,284 INFO x=
# 2017-02-19 19:57:54,086 INFO y=[ 1.  0.]
# 2017-02-19 19:57:54,087 INFO patient_index 4
# 2017-02-19 19:57:54,089 INFO x=
# 2017-02-19 19:57:55,896 INFO y=[ 0.  1.]
# 2017-02-19 19:57:55,897 INFO patient_index 8
# 2017-02-19 19:57:55,899 INFO x=
# 2017-02-19 19:57:57,793 INFO y=[ 1.  0.]
# 2017-02-19 19:57:57,796 INFO patient_index 11
# 2017-02-19 19:57:57,796 INFO x=
# 2017-02-19 19:57:59,731 INFO y=[ 0.  1.]
# 2017-02-19 19:57:59,732 INFO patient_index 15
# 2017-02-19 19:57:59,733 INFO x=
# 2017-02-19 19:58:01,593 INFO y=[ 0.  1.]
# 2017-02-19 19:58:01,595 INFO patient_index 19
# 2017-02-19 19:58:01,595 INFO x=
# 2017-02-19 19:58:03,623 INFO y=[ 1.  0.]
# 2017-02-19 19:58:03,623 INFO patient_index 23
# 2017-02-19 19:58:03,624 INFO x=
# 2017-02-19 19:58:05,636 INFO y=[ 0.  1.]
# 2017-02-19 19:58:05,636 INFO patient_index 27
# 2017-02-19 19:58:05,637 INFO x=
# 2017-02-19 19:58:07,499 INFO y=[ 1.  0.]
# 2017-02-19 19:58:07,500 INFO patient_index 30
# 2017-02-19 19:58:07,500 INFO x=
# 2017-02-19 19:58:09,552 INFO y=[ 0.  1.]
# 2017-02-19 19:58:09,553 INFO patient_index 34
# 2017-02-19 19:58:09,554 INFO x=
# 2017-02-19 19:58:11,410 INFO y=[ 0.  1.]
# 2017-02-19 19:58:11,412 INFO > [done]    Output dataset validations (19154.875 ms)
# 2017-02-19 19:58:11,413 INFO ==== ALL DONE ====
