# %%
INPUT_IMAGE_DIMS = (224, 152, 224, 1)
OUTPUT_IMAGE_DIMS = (112, 76, 112, 1)

DATASET_NAME = '-centered-rotated'

INPUT_FOLDER = '../../../output/kaggle-bowl/step4/'
OUTPUT_FOLDER = '../../../output/kaggle-bowl/step5/'

# %%
import sys
import h5py
import numpy as np
import shutil
import os
from scipy.ndimage.interpolation import rotate
from scipy.ndimage.interpolation import shift
import scipy
import datetime
import logging

from modules.logging import logger
import modules.logging
import modules.lungprepare as lungprepare
import modules.utils as utils
from modules.utils import Timer
import modules.logging

# %%
def create_xy_datasets(output_dir, name, image_dims, size):
    dataset_file = utils.dataset_path(output_dir, name, image_dims)
    h5f = h5py.File(dataset_file, 'w')
    x_ds = h5f.create_dataset('X', (size, image_dims[0], image_dims[1], image_dims[2], 1), chunks=(1, image_dims[0], image_dims[1], image_dims[2], 1), dtype='f')
    y_ds = h5f.create_dataset('Y', (size, 2), dtype='f')

    logger.debug('input x shape={}'.format(h5f['X'].shape))
    x_ds = h5f['X']
    y_ds = h5f['Y']
    
    return h5f, x_ds, y_ds

# %%
def distribute(input_x_ds, input_y_ds, output_x_ds, output_y_ds, qtty_label0, qtty_label1, non_usable_patients, resize_factor):
    count_label0 = 0
    count_label1 = 0
    output_index = 0
    for i in range(len(input_x_ds)):

        if((count_label0+count_label1)>=len(output_x_ds)):
            logger.warning('Reached max elements in output dataset. Stopping distribution')
            break
        
        if(i in non_usable_patients):
            continue
        
        label = input_y_ds[i]
        valid = False
        
        #distribute label0 sample
        if(label[0]==1 and count_label0<qtty_label0):
            count_label0 = count_label0 + 1
            valid = True

        #distribute label1 sample
        elif(label[1]==1 and count_label1<qtty_label1):
            count_label1 = count_label1 + 1
            valid = True
                           
        if(valid):
            ts = Timer('Resizing patient pixels ' + str(i))
            image_pixels = scipy.ndimage.interpolation.zoom(input_x_ds[i], resize_factor)
            ts.stop()
            output_x_ds[output_index] = image_pixels
            output_y_ds[output_index] = label
            output_index = output_index + 1
            non_usable_patients.append(i)

# %%
def start_processing(input_dir, input_image_dims, output_image_dims, output_dir):
    logger.info('Resizing images. input_dir='+ str(input_dir) + ' output_dir=' + output_dir)
    
    logger.info('Preparing output dir')
    utils.mkdirs(output_dir, dirs=['images'], recreate=True)

    modules.logging.setup_file_logger(output_dir + 'out.log')

    t = Timer('Distributing input dataset among train, validate and test datasets')
    len_input_x_ds = None
    resize_factor = (output_image_dims[0]/input_image_dims[0], output_image_dims[1]/input_image_dims[1], output_image_dims[2]/input_image_dims[2], output_image_dims[3]/input_image_dims[3])
    dataset_file = input_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(input_image_dims[0], input_image_dims[1], input_image_dims[2])
    with h5py.File(dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        len_input_x_ds = len(input_x_ds)
        len_input_y_ds = len(input_y_ds)
        
        if(len_input_x_ds!=len_input_y_ds):
            raise Error('X and Y datasets have different sizes!')

        logger.info('Calculating label 0|1 proportion')
        label_total = np.array([[0,0]])
        for pi in range(len_input_x_ds):
            label_total = np.array(input_y_ds[pi]) + label_total

        label0_total = label_total[0][0]
        label1_total = label_total[0][1]
        
        label0_ratio = label0_total/len_input_y_ds    
        label1_ratio = label1_total/len_input_y_ds   

        logger.info('Y: total: ' + str(len_input_y_ds))
        logger.info('Y: label 0: ' + str(label_total[0][0]) + ' ' + str(100*label0_ratio) + '%')
        logger.info('Y: label 1: ' + str(label_total[0][1]) + ' ' + str(100*label1_ratio) + '%')
        
        logger.info('Calculate patient distribution among datasets')

        distributed_patients = []
        total_patients = len_input_x_ds
        
        
        #DISTRIBUTE TO TRAIN DATASET
        dataset_name = 'train' + DATASET_NAME
        t = Timer('Distribute to train dataset')
        train_qtty = round(min(min(label0_total*0.75, label1_total*0.75)*2, total_patients*0.75))
        qtty_label0 = round(train_qtty/2)
        qtty_label1 = train_qtty - qtty_label0
        logger.debug('train_qtty=' + str(train_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, train_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()

        total_patients = total_patients - train_qtty
        label0_total = label0_total - qtty_label0
        label1_total = label1_total - qtty_label1
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

        #DISTRIBUTE TO VALIDATE DATASET
        dataset_name = 'validate' + DATASET_NAME
        t = Timer('Distribute to validate dataset')
        validate_qtty = round(min(min(label0_total*0.5, label1_total*0.5)*2, total_patients*0.5))
        qtty_label0 = round(validate_qtty/2)
        qtty_label1 = validate_qtty - qtty_label0
        logger.debug('validate_qtty=' + str(validate_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, validate_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

        total_patients = total_patients - validate_qtty
        
        #DISTRIBUTE REMAINING TO TEST DATASET
        dataset_name = 'test' + DATASET_NAME
        t = Timer('Distribute to test dataset')
        test_qtty = total_patients
        qtty_label0 = test_qtty
        qtty_label1 = test_qtty
        logger.debug('test_qtty=' + str(test_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, test_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

    t.stop()

# %%
logger.info('==== PROCESSING SHARDS MERGE ====')
start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
logger.info('==== ALL DONE ====')
# Out:
# 2017-03-07 18:32:27,919 INFO ==== PROCESSING SHARDS MERGE ====
# 2017-03-07 18:32:27,921 INFO Resizing images. input_dir=../../../output/kaggle-bowl/step4/ output_dir=../../../output/kaggle-bowl/step5/
# 2017-03-07 18:32:27,922 INFO Preparing output dir
# 2017-03-07 18:32:28,072 INFO > [started] Distributing input dataset among train, validate and test datasets...
# 2017-03-07 18:32:28,122 INFO input x shape=(1392, 224, 152, 224, 1)
# 2017-03-07 18:32:28,123 INFO Calculating label 0|1 proportion
# 2017-03-07 18:32:28,309 INFO Y: total: 1392
# 2017-03-07 18:32:28,311 INFO Y: label 0: 1033.0 74.2097701149%
# 2017-03-07 18:32:28,311 INFO Y: label 1: 359.0 25.7902298851%
# 2017-03-07 18:32:28,312 INFO Calculate patient distribution among datasets
# 2017-03-07 18:32:28,313 INFO > [started] Distribute to train dataset...
# 2017-03-07 18:32:28,314 DEBUG train_qtty=538.0 qtty_label0=269.0 qtty_label1=269.0
# 2017-03-07 18:32:28,316 DEBUG input x shape=(538, 112, 76, 112, 1)
# 2017-03-07 18:32:28,318 INFO > [started] Resizing patient pixels 0...
# /usr/local/lib/python3.5/dist-packages/scipy/ndimage/interpolation.py:571: RuntimeWarning: invalid value encountered in true_divide
#   zoom = (numpy.array(input.shape) - 1) / zoom_div
# 2017-03-07 18:32:33,359 INFO > [done]    Resizing patient pixels 0 (5041.009 ms)
# 2017-03-07 18:32:33,365 INFO > [started] Resizing patient pixels 1...
# 2017-03-07 18:32:38,165 INFO > [done]    Resizing patient pixels 1 (4800.119 ms)
# 2017-03-07 18:32:38,170 INFO > [started] Resizing patient pixels 2...
# 2017-03-07 18:32:43,056 INFO > [done]    Resizing patient pixels 2 (4885.971 ms)
# 2017-03-07 18:32:43,062 INFO > [started] Resizing patient pixels 3...
# 2017-03-07 18:32:47,800 INFO > [done]    Resizing patient pixels 3 (4737.664 ms)
# 2017-03-07 18:32:47,805 INFO > [started] Resizing patient pixels 4...
# 2017-03-07 18:32:52,708 INFO > [done]    Resizing patient pixels 4 (4902.662 ms)
# 2017-03-07 18:32:52,713 INFO > [started] Resizing patient pixels 5...
# 2017-03-07 18:32:57,733 INFO > [done]    Resizing patient pixels 5 (5019.815 ms)
# 2017-03-07 18:32:57,738 INFO > [started] Resizing patient pixels 6...
# 2017-03-07 18:33:02,654 INFO > [done]    Resizing patient pixels 6 (4916.067 ms)
# 2017-03-07 18:33:02,660 INFO > [started] Resizing patient pixels 7...
# 2017-03-07 18:33:07,487 INFO > [done]    Resizing patient pixels 7 (4826.894 ms)
# 2017-03-07 18:33:07,492 INFO > [started] Resizing patient pixels 8...
# 2017-03-07 18:33:12,559 INFO > [done]    Resizing patient pixels 8 (5067.132 ms)
# 2017-03-07 18:33:12,564 INFO > [started] Resizing patient pixels 9...
# 2017-03-07 18:33:17,861 INFO > [done]    Resizing patient pixels 9 (5296.685 ms)
# 2017-03-07 18:33:17,866 INFO > [started] Resizing patient pixels 10...
# 2017-03-07 18:33:22,728 INFO > [done]    Resizing patient pixels 10 (4861.984 ms)
# 2017-03-07 18:33:22,733 INFO > [started] Resizing patient pixels 11...
# 2017-03-07 18:33:27,560 INFO > [done]    Resizing patient pixels 11 (4827.553 ms)
# 2017-03-07 18:33:27,566 INFO > [started] Resizing patient pixels 12...
# 2017-03-07 18:33:32,443 INFO > [done]    Resizing patient pixels 12 (4877.158 ms)
# 2017-03-07 18:33:32,448 INFO > [started] Resizing patient pixels 13...
# 2017-03-07 18:33:37,272 INFO > [done]    Resizing patient pixels 13 (4823.139 ms)
# 2017-03-07 18:33:37,278 INFO > [started] Resizing patient pixels 14...
# 2017-03-07 18:33:42,026 INFO > [done]    Resizing patient pixels 14 (4748.175 ms)
# 2017-03-07 18:33:42,031 INFO > [started] Resizing patient pixels 15...
# 2017-03-07 18:33:46,863 INFO > [done]    Resizing patient pixels 15 (4831.667 ms)
# 2017-03-07 18:33:46,868 INFO > [started] Resizing patient pixels 16...
# 2017-03-07 18:33:51,736 INFO > [done]    Resizing patient pixels 16 (4868.120 ms)
# 2017-03-07 18:33:51,741 INFO > [started] Resizing patient pixels 17...
# 2017-03-07 18:33:56,481 INFO > [done]    Resizing patient pixels 17 (4739.314 ms)
# 2017-03-07 18:33:56,486 INFO > [started] Resizing patient pixels 18...
# 2017-03-07 18:34:01,275 INFO > [done]    Resizing patient pixels 18 (4789.236 ms)
# 2017-03-07 18:34:01,280 INFO > [started] Resizing patient pixels 19...
# 2017-03-07 18:34:06,095 INFO > [done]    Resizing patient pixels 19 (4814.530 ms)
# 2017-03-07 18:34:06,100 INFO > [started] Resizing patient pixels 20...
# 2017-03-07 18:34:10,794 INFO > [done]    Resizing patient pixels 20 (4693.509 ms)
# 2017-03-07 18:34:10,799 INFO > [started] Resizing patient pixels 21...
# 2017-03-07 18:34:15,574 INFO > [done]    Resizing patient pixels 21 (4774.430 ms)
# 2017-03-07 18:34:15,579 INFO > [started] Resizing patient pixels 22...
# 2017-03-07 18:34:20,269 INFO > [done]    Resizing patient pixels 22 (4689.796 ms)
# 2017-03-07 18:34:20,275 INFO > [started] Resizing patient pixels 23...
# 2017-03-07 18:34:24,981 INFO > [done]    Resizing patient pixels 23 (4705.827 ms)
# 2017-03-07 18:34:24,986 INFO > [started] Resizing patient pixels 24...
# 2017-03-07 18:34:29,793 INFO > [done]    Resizing patient pixels 24 (4806.492 ms)
# 2017-03-07 18:34:29,798 INFO > [started] Resizing patient pixels 25...
# 2017-03-07 18:34:34,761 INFO > [done]    Resizing patient pixels 25 (4963.510 ms)
# 2017-03-07 18:34:34,766 INFO > [started] Resizing patient pixels 26...
# 2017-03-07 18:34:39,509 INFO > [done]    Resizing patient pixels 26 (4742.067 ms)
# 2017-03-07 18:34:39,514 INFO > [started] Resizing patient pixels 27...
# 2017-03-07 18:34:44,299 INFO > [done]    Resizing patient pixels 27 (4785.239 ms)
# 2017-03-07 18:34:44,305 INFO > [started] Resizing patient pixels 28...
# 2017-03-07 18:34:49,098 INFO > [done]    Resizing patient pixels 28 (4793.408 ms)
# 2017-03-07 18:34:49,104 INFO > [started] Resizing patient pixels 29...
# 2017-03-07 18:34:54,097 INFO > [done]    Resizing patient pixels 29 (4993.397 ms)
# 2017-03-07 18:34:54,102 INFO > [started] Resizing patient pixels 30...
# 2017-03-07 18:34:58,943 INFO > [done]    Resizing patient pixels 30 (4840.710 ms)
# 2017-03-07 18:34:58,948 INFO > [started] Resizing patient pixels 31...
# 2017-03-07 18:35:03,836 INFO > [done]    Resizing patient pixels 31 (4888.154 ms)
# 2017-03-07 18:35:03,842 INFO > [started] Resizing patient pixels 32...
# 2017-03-07 18:35:08,647 INFO > [done]    Resizing patient pixels 32 (4805.685 ms)
# 2017-03-07 18:35:08,652 INFO > [started] Resizing patient pixels 33...
# 2017-03-07 18:35:13,622 INFO > [done]    Resizing patient pixels 33 (4969.032 ms)
# 2017-03-07 18:35:13,627 INFO > [started] Resizing patient pixels 34...
# 2017-03-07 18:35:18,435 INFO > [done]    Resizing patient pixels 34 (4808.022 ms)
# 2017-03-07 18:35:18,440 INFO > [started] Resizing patient pixels 35...
# 2017-03-07 18:35:23,198 INFO > [done]    Resizing patient pixels 35 (4758.074 ms)
# 2017-03-07 18:35:23,204 INFO > [started] Resizing patient pixels 36...
# 2017-03-07 18:35:27,948 INFO > [done]    Resizing patient pixels 36 (4744.104 ms)
# 2017-03-07 18:35:27,953 INFO > [started] Resizing patient pixels 37...
# 2017-03-07 18:35:32,925 INFO > [done]    Resizing patient pixels 37 (4971.701 ms)
# 2017-03-07 18:35:32,930 INFO > [started] Resizing patient pixels 38...
# 2017-03-07 18:35:37,815 INFO > [done]    Resizing patient pixels 38 (4885.429 ms)
# 2017-03-07 18:35:37,821 INFO > [started] Resizing patient pixels 39...
# 2017-03-07 18:35:42,608 INFO > [done]    Resizing patient pixels 39 (4787.632 ms)
# 2017-03-07 18:35:42,614 INFO > [started] Resizing patient pixels 40...
# 2017-03-07 18:35:47,597 INFO > [done]    Resizing patient pixels 40 (4982.832 ms)
# 2017-03-07 18:35:47,602 INFO > [started] Resizing patient pixels 41...
# 2017-03-07 18:35:52,494 INFO > [done]    Resizing patient pixels 41 (4891.563 ms)
# 2017-03-07 18:35:52,499 INFO > [started] Resizing patient pixels 42...
# 2017-03-07 18:35:57,370 INFO > [done]    Resizing patient pixels 42 (4870.787 ms)
# 2017-03-07 18:35:57,375 INFO > [started] Resizing patient pixels 43...
# 2017-03-07 18:36:02,311 INFO > [done]    Resizing patient pixels 43 (4935.959 ms)
# 2017-03-07 18:36:02,316 INFO > [started] Resizing patient pixels 44...
# 2017-03-07 18:36:07,121 INFO > [done]    Resizing patient pixels 44 (4804.969 ms)
# 2017-03-07 18:36:07,126 INFO > [started] Resizing patient pixels 45...
# 2017-03-07 18:36:11,827 INFO > [done]    Resizing patient pixels 45 (4700.538 ms)
# 2017-03-07 18:36:11,832 INFO > [started] Resizing patient pixels 46...
# 2017-03-07 18:36:16,671 INFO > [done]    Resizing patient pixels 46 (4838.926 ms)
# 2017-03-07 18:36:16,676 INFO > [started] Resizing patient pixels 47...
# 2017-03-07 18:36:21,493 INFO > [done]    Resizing patient pixels 47 (4817.393 ms)
# 2017-03-07 18:36:21,499 INFO > [started] Resizing patient pixels 48...
# 2017-03-07 18:36:26,279 INFO > [done]    Resizing patient pixels 48 (4779.910 ms)
# 2017-03-07 18:36:26,284 INFO > [started] Resizing patient pixels 49...
# 2017-03-07 18:36:31,173 INFO > [done]    Resizing patient pixels 49 (4889.034 ms)
# 2017-03-07 18:36:31,178 INFO > [started] Resizing patient pixels 50...
# 2017-03-07 18:36:35,997 INFO > [done]    Resizing patient pixels 50 (4819.173 ms)
# 2017-03-07 18:36:36,002 INFO > [started] Resizing patient pixels 51...
# 2017-03-07 18:36:40,885 INFO > [done]    Resizing patient pixels 51 (4882.628 ms)
# 2017-03-07 18:36:40,890 INFO > [started] Resizing patient pixels 52...
# 2017-03-07 18:36:45,808 INFO > [done]    Resizing patient pixels 52 (4918.335 ms)
# 2017-03-07 18:36:45,814 INFO > [started] Resizing patient pixels 53...
# 2017-03-07 18:36:50,570 INFO > [done]    Resizing patient pixels 53 (4756.236 ms)
# 2017-03-07 18:36:50,576 INFO > [started] Resizing patient pixels 54...
# 2017-03-07 18:36:55,388 INFO > [done]    Resizing patient pixels 54 (4812.566 ms)
# 2017-03-07 18:36:55,393 INFO > [started] Resizing patient pixels 55...
# 2017-03-07 18:37:00,288 INFO > [done]    Resizing patient pixels 55 (4894.519 ms)
# 2017-03-07 18:37:00,293 INFO > [started] Resizing patient pixels 56...
# 2017-03-07 18:37:05,146 INFO > [done]    Resizing patient pixels 56 (4852.639 ms)
# 2017-03-07 18:37:05,151 INFO > [started] Resizing patient pixels 57...
# 2017-03-07 18:37:09,983 INFO > [done]    Resizing patient pixels 57 (4831.264 ms)
# 2017-03-07 18:37:09,988 INFO > [started] Resizing patient pixels 58...
# 2017-03-07 18:37:14,843 INFO > [done]    Resizing patient pixels 58 (4854.882 ms)
# 2017-03-07 18:37:14,848 INFO > [started] Resizing patient pixels 59...
# 2017-03-07 18:37:19,692 INFO > [done]    Resizing patient pixels 59 (4844.263 ms)
# 2017-03-07 18:37:19,697 INFO > [started] Resizing patient pixels 60...
# 2017-03-07 18:37:24,661 INFO > [done]    Resizing patient pixels 60 (4963.670 ms)
# 2017-03-07 18:37:24,666 INFO > [started] Resizing patient pixels 61...
# 2017-03-07 18:37:29,558 INFO > [done]    Resizing patient pixels 61 (4892.397 ms)
# 2017-03-07 18:37:29,563 INFO > [started] Resizing patient pixels 62...
# 2017-03-07 18:37:34,558 INFO > [done]    Resizing patient pixels 62 (4994.337 ms)
# 2017-03-07 18:37:34,563 INFO > [started] Resizing patient pixels 63...
# 2017-03-07 18:37:39,344 INFO > [done]    Resizing patient pixels 63 (4780.787 ms)
# 2017-03-07 18:37:39,349 INFO > [started] Resizing patient pixels 64...
# 2017-03-07 18:37:44,272 INFO > [done]    Resizing patient pixels 64 (4923.094 ms)
# 2017-03-07 18:37:44,278 INFO > [started] Resizing patient pixels 65...
# 2017-03-07 18:37:49,301 INFO > [done]    Resizing patient pixels 65 (5023.677 ms)
# 2017-03-07 18:37:49,307 INFO > [started] Resizing patient pixels 66...
# 2017-03-07 18:37:54,229 INFO > [done]    Resizing patient pixels 66 (4921.706 ms)
# 2017-03-07 18:37:54,234 INFO > [started] Resizing patient pixels 67...
# 2017-03-07 18:37:59,040 INFO > [done]    Resizing patient pixels 67 (4805.827 ms)
# 2017-03-07 18:37:59,045 INFO > [started] Resizing patient pixels 68...
# 2017-03-07 18:38:03,905 INFO > [done]    Resizing patient pixels 68 (4859.622 ms)
# 2017-03-07 18:38:03,910 INFO > [started] Resizing patient pixels 69...
# 2017-03-07 18:38:09,042 INFO > [done]    Resizing patient pixels 69 (5132.200 ms)
# 2017-03-07 18:38:09,047 INFO > [started] Resizing patient pixels 70...
# 2017-03-07 18:38:13,891 INFO > [done]    Resizing patient pixels 70 (4843.531 ms)
# 2017-03-07 18:38:13,896 INFO > [started] Resizing patient pixels 71...
# 2017-03-07 18:38:18,706 INFO > [done]    Resizing patient pixels 71 (4809.711 ms)
# 2017-03-07 18:38:18,712 INFO > [started] Resizing patient pixels 72...
# 2017-03-07 18:38:23,660 INFO > [done]    Resizing patient pixels 72 (4948.728 ms)
# 2017-03-07 18:38:23,666 INFO > [started] Resizing patient pixels 73...
# 2017-03-07 18:38:28,461 INFO > [done]    Resizing patient pixels 73 (4795.112 ms)
# 2017-03-07 18:38:28,466 INFO > [started] Resizing patient pixels 74...
# 2017-03-07 18:38:33,335 INFO > [done]    Resizing patient pixels 74 (4868.010 ms)
# 2017-03-07 18:38:33,339 INFO > [started] Resizing patient pixels 75...
# 2017-03-07 18:38:39,061 INFO > [done]    Resizing patient pixels 75 (5721.059 ms)
# 2017-03-07 18:38:39,066 INFO > [started] Resizing patient pixels 76...
# 2017-03-07 18:38:44,032 INFO > [done]    Resizing patient pixels 76 (4966.350 ms)
# 2017-03-07 18:38:44,038 INFO > [started] Resizing patient pixels 77...
# 2017-03-07 18:38:49,054 INFO > [done]    Resizing patient pixels 77 (5015.975 ms)
# 2017-03-07 18:38:49,059 INFO > [started] Resizing patient pixels 78...
# 2017-03-07 18:38:53,796 INFO > [done]    Resizing patient pixels 78 (4737.027 ms)
# 2017-03-07 18:38:53,802 INFO > [started] Resizing patient pixels 79...
# 2017-03-07 18:38:58,631 INFO > [done]    Resizing patient pixels 79 (4829.583 ms)
# 2017-03-07 18:38:58,636 INFO > [started] Resizing patient pixels 80...
# 2017-03-07 18:39:03,486 INFO > [done]    Resizing patient pixels 80 (4850.254 ms)
# 2017-03-07 18:39:03,492 INFO > [started] Resizing patient pixels 81...
# 2017-03-07 18:39:08,184 INFO > [done]    Resizing patient pixels 81 (4692.450 ms)
# 2017-03-07 18:39:08,189 INFO > [started] Resizing patient pixels 82...
# 2017-03-07 18:39:13,062 INFO > [done]    Resizing patient pixels 82 (4872.965 ms)
# 2017-03-07 18:39:13,067 INFO > [started] Resizing patient pixels 83...
# 2017-03-07 18:39:17,969 INFO > [done]    Resizing patient pixels 83 (4901.405 ms)
# 2017-03-07 18:39:17,974 INFO > [started] Resizing patient pixels 84...
# 2017-03-07 18:39:22,901 INFO > [done]    Resizing patient pixels 84 (4927.127 ms)
# 2017-03-07 18:39:22,907 INFO > [started] Resizing patient pixels 85...
# 2017-03-07 18:39:27,630 INFO > [done]    Resizing patient pixels 85 (4723.099 ms)
# 2017-03-07 18:39:27,635 INFO > [started] Resizing patient pixels 86...
# 2017-03-07 18:39:32,551 INFO > [done]    Resizing patient pixels 86 (4916.040 ms)
# 2017-03-07 18:39:32,557 INFO > [started] Resizing patient pixels 87...
# 2017-03-07 18:39:37,389 INFO > [done]    Resizing patient pixels 87 (4832.392 ms)
# 2017-03-07 18:39:37,394 INFO > [started] Resizing patient pixels 88...
# 2017-03-07 18:39:42,144 INFO > [done]    Resizing patient pixels 88 (4749.544 ms)
# 2017-03-07 18:39:42,149 INFO > [started] Resizing patient pixels 89...
# 2017-03-07 18:39:46,970 INFO > [done]    Resizing patient pixels 89 (4820.427 ms)
# 2017-03-07 18:39:46,975 INFO > [started] Resizing patient pixels 90...
# 2017-03-07 18:39:52,178 INFO > [done]    Resizing patient pixels 90 (5202.985 ms)
# 2017-03-07 18:39:52,183 INFO > [started] Resizing patient pixels 91...
# 2017-03-07 18:39:57,008 INFO > [done]    Resizing patient pixels 91 (4824.933 ms)
# 2017-03-07 18:39:57,014 INFO > [started] Resizing patient pixels 92...
# 2017-03-07 18:40:01,907 INFO > [done]    Resizing patient pixels 92 (4893.458 ms)
# 2017-03-07 18:40:01,912 INFO > [started] Resizing patient pixels 93...
# 2017-03-07 18:40:06,773 INFO > [done]    Resizing patient pixels 93 (4860.448 ms)
# 2017-03-07 18:40:06,778 INFO > [started] Resizing patient pixels 94...
# 2017-03-07 18:40:11,705 INFO > [done]    Resizing patient pixels 94 (4926.791 ms)
# 2017-03-07 18:40:11,710 INFO > [started] Resizing patient pixels 95...
# 2017-03-07 18:40:16,578 INFO > [done]    Resizing patient pixels 95 (4867.660 ms)
# 2017-03-07 18:40:16,583 INFO > [started] Resizing patient pixels 96...
# 2017-03-07 18:40:21,532 INFO > [done]    Resizing patient pixels 96 (4949.489 ms)
# 2017-03-07 18:40:21,538 INFO > [started] Resizing patient pixels 97...
# 2017-03-07 18:40:26,574 INFO > [done]    Resizing patient pixels 97 (5036.488 ms)
# 2017-03-07 18:40:26,580 INFO > [started] Resizing patient pixels 98...
# 2017-03-07 18:40:31,457 INFO > [done]    Resizing patient pixels 98 (4876.786 ms)
# 2017-03-07 18:40:31,462 INFO > [started] Resizing patient pixels 99...
# 2017-03-07 18:40:36,493 INFO > [done]    Resizing patient pixels 99 (5030.975 ms)
# 2017-03-07 18:40:36,499 INFO > [started] Resizing patient pixels 100...
# 2017-03-07 18:40:41,335 INFO > [done]    Resizing patient pixels 100 (4836.866 ms)
# 2017-03-07 18:40:41,340 INFO > [started] Resizing patient pixels 101...
# 2017-03-07 18:40:46,277 INFO > [done]    Resizing patient pixels 101 (4936.471 ms)
# 2017-03-07 18:40:46,282 INFO > [started] Resizing patient pixels 102...
# 2017-03-07 18:40:51,056 INFO > [done]    Resizing patient pixels 102 (4773.561 ms)
# 2017-03-07 18:40:51,061 INFO > [started] Resizing patient pixels 103...
# 2017-03-07 18:40:55,952 INFO > [done]    Resizing patient pixels 103 (4891.502 ms)
# 2017-03-07 18:40:55,958 INFO > [started] Resizing patient pixels 104...
# 2017-03-07 18:41:00,801 INFO > [done]    Resizing patient pixels 104 (4843.118 ms)
# 2017-03-07 18:41:00,806 INFO > [started] Resizing patient pixels 105...
# 2017-03-07 18:41:05,639 INFO > [done]    Resizing patient pixels 105 (4832.802 ms)
# 2017-03-07 18:41:05,644 INFO > [started] Resizing patient pixels 106...
# 2017-03-07 18:41:10,471 INFO > [done]    Resizing patient pixels 106 (4826.837 ms)
# 2017-03-07 18:41:10,476 INFO > [started] Resizing patient pixels 107...
# 2017-03-07 18:41:15,298 INFO > [done]    Resizing patient pixels 107 (4822.329 ms)
# 2017-03-07 18:41:15,304 INFO > [started] Resizing patient pixels 108...
# 2017-03-07 18:41:20,101 INFO > [done]    Resizing patient pixels 108 (4797.756 ms)
# 2017-03-07 18:41:20,107 INFO > [started] Resizing patient pixels 109...
# 2017-03-07 18:41:24,907 INFO > [done]    Resizing patient pixels 109 (4800.427 ms)
# 2017-03-07 18:41:24,912 INFO > [started] Resizing patient pixels 110...
# 2017-03-07 18:41:29,694 INFO > [done]    Resizing patient pixels 110 (4781.666 ms)
# 2017-03-07 18:41:29,699 INFO > [started] Resizing patient pixels 111...
# 2017-03-07 18:41:34,353 INFO > [done]    Resizing patient pixels 111 (4654.182 ms)
# 2017-03-07 18:41:34,358 INFO > [started] Resizing patient pixels 112...
# 2017-03-07 18:41:39,218 INFO > [done]    Resizing patient pixels 112 (4859.930 ms)
# 2017-03-07 18:41:39,224 INFO > [started] Resizing patient pixels 113...
# 2017-03-07 18:41:44,286 INFO > [done]    Resizing patient pixels 113 (5062.115 ms)
# 2017-03-07 18:41:44,291 INFO > [started] Resizing patient pixels 114...
# 2017-03-07 18:41:49,200 INFO > [done]    Resizing patient pixels 114 (4908.895 ms)
# 2017-03-07 18:41:49,206 INFO > [started] Resizing patient pixels 115...
# 2017-03-07 18:41:54,134 INFO > [done]    Resizing patient pixels 115 (4927.913 ms)
# 2017-03-07 18:41:54,139 INFO > [started] Resizing patient pixels 116...
# 2017-03-07 18:41:58,968 INFO > [done]    Resizing patient pixels 116 (4828.937 ms)
# 2017-03-07 18:41:58,973 INFO > [started] Resizing patient pixels 117...
# 2017-03-07 18:42:03,945 INFO > [done]    Resizing patient pixels 117 (4971.396 ms)
# 2017-03-07 18:42:03,950 INFO > [started] Resizing patient pixels 118...
# 2017-03-07 18:42:08,724 INFO > [done]    Resizing patient pixels 118 (4773.809 ms)
# 2017-03-07 18:42:08,729 INFO > [started] Resizing patient pixels 119...
# 2017-03-07 18:42:13,628 INFO > [done]    Resizing patient pixels 119 (4899.706 ms)
# 2017-03-07 18:42:13,633 INFO > [started] Resizing patient pixels 120...
# 2017-03-07 18:42:18,487 INFO > [done]    Resizing patient pixels 120 (4853.034 ms)
# 2017-03-07 18:42:18,492 INFO > [started] Resizing patient pixels 121...
# 2017-03-07 18:42:23,372 INFO > [done]    Resizing patient pixels 121 (4879.860 ms)
# 2017-03-07 18:42:23,377 INFO > [started] Resizing patient pixels 122...
# 2017-03-07 18:42:28,170 INFO > [done]    Resizing patient pixels 122 (4793.272 ms)
# 2017-03-07 18:42:28,175 INFO > [started] Resizing patient pixels 123...
# 2017-03-07 18:42:32,956 INFO > [done]    Resizing patient pixels 123 (4780.902 ms)
# 2017-03-07 18:42:32,961 INFO > [started] Resizing patient pixels 124...
# 2017-03-07 18:42:37,879 INFO > [done]    Resizing patient pixels 124 (4917.454 ms)
# 2017-03-07 18:42:37,884 INFO > [started] Resizing patient pixels 125...
# 2017-03-07 18:42:42,725 INFO > [done]    Resizing patient pixels 125 (4841.149 ms)
# 2017-03-07 18:42:42,730 INFO > [started] Resizing patient pixels 126...
# 2017-03-07 18:42:47,460 INFO > [done]    Resizing patient pixels 126 (4730.064 ms)
# 2017-03-07 18:42:47,465 INFO > [started] Resizing patient pixels 127...
# 2017-03-07 18:42:52,239 INFO > [done]    Resizing patient pixels 127 (4774.151 ms)
# 2017-03-07 18:42:52,245 INFO > [started] Resizing patient pixels 128...
# 2017-03-07 18:42:57,093 INFO > [done]    Resizing patient pixels 128 (4847.638 ms)
# 2017-03-07 18:42:57,098 INFO > [started] Resizing patient pixels 129...
# 2017-03-07 18:43:02,007 INFO > [done]    Resizing patient pixels 129 (4909.693 ms)
# 2017-03-07 18:43:02,013 INFO > [started] Resizing patient pixels 130...
# 2017-03-07 18:43:06,841 INFO > [done]    Resizing patient pixels 130 (4827.944 ms)
# 2017-03-07 18:43:06,847 INFO > [started] Resizing patient pixels 131...
# 2017-03-07 18:43:11,794 INFO > [done]    Resizing patient pixels 131 (4947.730 ms)
# 2017-03-07 18:43:11,799 INFO > [started] Resizing patient pixels 132...
# 2017-03-07 18:43:16,677 INFO > [done]    Resizing patient pixels 132 (4877.260 ms)
# 2017-03-07 18:43:16,682 INFO > [started] Resizing patient pixels 133...
# 2017-03-07 18:43:21,583 INFO > [done]    Resizing patient pixels 133 (4901.073 ms)
# 2017-03-07 18:43:21,588 INFO > [started] Resizing patient pixels 134...
# 2017-03-07 18:43:26,501 INFO > [done]    Resizing patient pixels 134 (4912.930 ms)
# 2017-03-07 18:43:26,506 INFO > [started] Resizing patient pixels 135...
# 2017-03-07 18:43:31,519 INFO > [done]    Resizing patient pixels 135 (5012.703 ms)
# 2017-03-07 18:43:31,525 INFO > [started] Resizing patient pixels 136...
# 2017-03-07 18:43:36,419 INFO > [done]    Resizing patient pixels 136 (4894.626 ms)
# 2017-03-07 18:43:36,424 INFO > [started] Resizing patient pixels 137...
# 2017-03-07 18:43:41,185 INFO > [done]    Resizing patient pixels 137 (4760.170 ms)
# 2017-03-07 18:43:41,190 INFO > [started] Resizing patient pixels 138...
# 2017-03-07 18:43:45,994 INFO > [done]    Resizing patient pixels 138 (4803.644 ms)
# 2017-03-07 18:43:45,999 INFO > [started] Resizing patient pixels 139...
# 2017-03-07 18:43:50,841 INFO > [done]    Resizing patient pixels 139 (4842.628 ms)
# 2017-03-07 18:43:50,847 INFO > [started] Resizing patient pixels 140...
# 2017-03-07 18:43:55,649 INFO > [done]    Resizing patient pixels 140 (4802.135 ms)
# 2017-03-07 18:43:55,654 INFO > [started] Resizing patient pixels 141...
# 2017-03-07 18:44:00,421 INFO > [done]    Resizing patient pixels 141 (4766.674 ms)
# 2017-03-07 18:44:00,426 INFO > [started] Resizing patient pixels 142...
# 2017-03-07 18:44:05,247 INFO > [done]    Resizing patient pixels 142 (4821.084 ms)
# 2017-03-07 18:44:05,252 INFO > [started] Resizing patient pixels 143...
# 2017-03-07 18:44:10,033 INFO > [done]    Resizing patient pixels 143 (4781.372 ms)
# 2017-03-07 18:44:10,039 INFO > [started] Resizing patient pixels 144...
# 2017-03-07 18:44:14,859 INFO > [done]    Resizing patient pixels 144 (4820.794 ms)
# 2017-03-07 18:44:14,865 INFO > [started] Resizing patient pixels 145...
# 2017-03-07 18:44:19,779 INFO > [done]    Resizing patient pixels 145 (4914.720 ms)
# 2017-03-07 18:44:19,784 INFO > [started] Resizing patient pixels 146...
# 2017-03-07 18:44:24,577 INFO > [done]    Resizing patient pixels 146 (4792.564 ms)
# 2017-03-07 18:44:24,582 INFO > [started] Resizing patient pixels 147...
# 2017-03-07 18:44:29,464 INFO > [done]    Resizing patient pixels 147 (4882.283 ms)
# 2017-03-07 18:44:29,469 INFO > [started] Resizing patient pixels 148...
# 2017-03-07 18:44:34,344 INFO > [done]    Resizing patient pixels 148 (4874.441 ms)
# 2017-03-07 18:44:34,349 INFO > [started] Resizing patient pixels 149...
# 2017-03-07 18:44:39,333 INFO > [done]    Resizing patient pixels 149 (4984.134 ms)
# 2017-03-07 18:44:39,339 INFO > [started] Resizing patient pixels 150...
# 2017-03-07 18:44:44,175 INFO > [done]    Resizing patient pixels 150 (4836.204 ms)
# 2017-03-07 18:44:44,180 INFO > [started] Resizing patient pixels 151...
# 2017-03-07 18:44:48,977 INFO > [done]    Resizing patient pixels 151 (4796.936 ms)
# 2017-03-07 18:44:48,982 INFO > [started] Resizing patient pixels 152...
# 2017-03-07 18:44:53,920 INFO > [done]    Resizing patient pixels 152 (4937.483 ms)
# 2017-03-07 18:44:53,925 INFO > [started] Resizing patient pixels 153...
# 2017-03-07 18:44:58,813 INFO > [done]    Resizing patient pixels 153 (4887.966 ms)
# 2017-03-07 18:44:58,818 INFO > [started] Resizing patient pixels 154...
# 2017-03-07 18:45:03,655 INFO > [done]    Resizing patient pixels 154 (4836.504 ms)
# 2017-03-07 18:45:03,660 INFO > [started] Resizing patient pixels 155...
# 2017-03-07 18:45:08,556 INFO > [done]    Resizing patient pixels 155 (4895.917 ms)
# 2017-03-07 18:45:08,562 INFO > [started] Resizing patient pixels 156...
# 2017-03-07 18:45:13,500 INFO > [done]    Resizing patient pixels 156 (4937.870 ms)
# 2017-03-07 18:45:13,505 INFO > [started] Resizing patient pixels 157...
# 2017-03-07 18:45:18,448 INFO > [done]    Resizing patient pixels 157 (4942.693 ms)
# 2017-03-07 18:45:18,453 INFO > [started] Resizing patient pixels 158...
# 2017-03-07 18:45:23,255 INFO > [done]    Resizing patient pixels 158 (4801.844 ms)
# 2017-03-07 18:45:23,260 INFO > [started] Resizing patient pixels 159...
# 2017-03-07 18:45:28,001 INFO > [done]    Resizing patient pixels 159 (4740.583 ms)
# 2017-03-07 18:45:28,006 INFO > [started] Resizing patient pixels 160...
# 2017-03-07 18:45:32,874 INFO > [done]    Resizing patient pixels 160 (4867.922 ms)
# 2017-03-07 18:45:32,879 INFO > [started] Resizing patient pixels 161...
# 2017-03-07 18:45:37,776 INFO > [done]    Resizing patient pixels 161 (4897.213 ms)
# 2017-03-07 18:45:37,781 INFO > [started] Resizing patient pixels 162...
# 2017-03-07 18:45:42,660 INFO > [done]    Resizing patient pixels 162 (4878.285 ms)
# 2017-03-07 18:45:42,665 INFO > [started] Resizing patient pixels 163...
# 2017-03-07 18:45:47,584 INFO > [done]    Resizing patient pixels 163 (4919.469 ms)
# 2017-03-07 18:45:47,590 INFO > [started] Resizing patient pixels 164...
# 2017-03-07 18:45:52,494 INFO > [done]    Resizing patient pixels 164 (4904.174 ms)
# 2017-03-07 18:45:52,499 INFO > [started] Resizing patient pixels 165...
# 2017-03-07 18:45:57,416 INFO > [done]    Resizing patient pixels 165 (4916.628 ms)
# 2017-03-07 18:45:57,421 INFO > [started] Resizing patient pixels 166...
# 2017-03-07 18:46:02,328 INFO > [done]    Resizing patient pixels 166 (4907.640 ms)
# 2017-03-07 18:46:02,334 INFO > [started] Resizing patient pixels 167...
# 2017-03-07 18:46:07,212 INFO > [done]    Resizing patient pixels 167 (4877.935 ms)
# 2017-03-07 18:46:07,217 INFO > [started] Resizing patient pixels 168...
# 2017-03-07 18:46:12,401 INFO > [done]    Resizing patient pixels 168 (5183.855 ms)
# 2017-03-07 18:46:12,406 INFO > [started] Resizing patient pixels 169...
# 2017-03-07 18:46:17,183 INFO > [done]    Resizing patient pixels 169 (4777.005 ms)
# 2017-03-07 18:46:17,188 INFO > [started] Resizing patient pixels 170...
# 2017-03-07 18:46:21,860 INFO > [done]    Resizing patient pixels 170 (4672.287 ms)
# 2017-03-07 18:46:21,866 INFO > [started] Resizing patient pixels 171...
# 2017-03-07 18:46:26,810 INFO > [done]    Resizing patient pixels 171 (4944.338 ms)
# 2017-03-07 18:46:26,815 INFO > [started] Resizing patient pixels 172...
# 2017-03-07 18:46:31,592 INFO > [done]    Resizing patient pixels 172 (4776.373 ms)
# 2017-03-07 18:46:31,596 INFO > [started] Resizing patient pixels 173...
# 2017-03-07 18:46:36,349 INFO > [done]    Resizing patient pixels 173 (4752.776 ms)
# 2017-03-07 18:46:36,354 INFO > [started] Resizing patient pixels 174...
# 2017-03-07 18:46:41,326 INFO > [done]    Resizing patient pixels 174 (4972.086 ms)
# 2017-03-07 18:46:41,332 INFO > [started] Resizing patient pixels 175...
# 2017-03-07 18:46:46,188 INFO > [done]    Resizing patient pixels 175 (4856.730 ms)
# 2017-03-07 18:46:46,193 INFO > [started] Resizing patient pixels 176...
# 2017-03-07 18:46:51,012 INFO > [done]    Resizing patient pixels 176 (4818.892 ms)
# 2017-03-07 18:46:51,017 INFO > [started] Resizing patient pixels 177...
# 2017-03-07 18:46:55,811 INFO > [done]    Resizing patient pixels 177 (4793.222 ms)
# 2017-03-07 18:46:55,816 INFO > [started] Resizing patient pixels 178...
# 2017-03-07 18:47:00,622 INFO > [done]    Resizing patient pixels 178 (4806.616 ms)
# 2017-03-07 18:47:00,627 INFO > [started] Resizing patient pixels 179...
# 2017-03-07 18:47:05,554 INFO > [done]    Resizing patient pixels 179 (4926.873 ms)
# 2017-03-07 18:47:05,559 INFO > [started] Resizing patient pixels 180...
# 2017-03-07 18:47:10,352 INFO > [done]    Resizing patient pixels 180 (4792.026 ms)
# 2017-03-07 18:47:10,357 INFO > [started] Resizing patient pixels 181...
# 2017-03-07 18:47:15,205 INFO > [done]    Resizing patient pixels 181 (4848.685 ms)
# 2017-03-07 18:47:15,210 INFO > [started] Resizing patient pixels 182...
# 2017-03-07 18:47:19,952 INFO > [done]    Resizing patient pixels 182 (4741.301 ms)
# 2017-03-07 18:47:19,957 INFO > [started] Resizing patient pixels 183...
# 2017-03-07 18:47:24,918 INFO > [done]    Resizing patient pixels 183 (4960.586 ms)
# 2017-03-07 18:47:24,923 INFO > [started] Resizing patient pixels 184...
# 2017-03-07 18:47:29,714 INFO > [done]    Resizing patient pixels 184 (4790.956 ms)
# 2017-03-07 18:47:29,720 INFO > [started] Resizing patient pixels 185...
# 2017-03-07 18:47:34,557 INFO > [done]    Resizing patient pixels 185 (4837.162 ms)
# 2017-03-07 18:47:34,562 INFO > [started] Resizing patient pixels 186...
# 2017-03-07 18:47:39,458 INFO > [done]    Resizing patient pixels 186 (4895.433 ms)
# 2017-03-07 18:47:39,463 INFO > [started] Resizing patient pixels 187...
# 2017-03-07 18:47:44,338 INFO > [done]    Resizing patient pixels 187 (4875.271 ms)
# 2017-03-07 18:47:44,343 INFO > [started] Resizing patient pixels 188...
# 2017-03-07 18:47:49,268 INFO > [done]    Resizing patient pixels 188 (4924.831 ms)
# 2017-03-07 18:47:49,274 INFO > [started] Resizing patient pixels 189...
# 2017-03-07 18:47:54,129 INFO > [done]    Resizing patient pixels 189 (4855.345 ms)
# 2017-03-07 18:47:54,134 INFO > [started] Resizing patient pixels 190...
# 2017-03-07 18:47:58,860 INFO > [done]    Resizing patient pixels 190 (4725.630 ms)
# 2017-03-07 18:47:58,865 INFO > [started] Resizing patient pixels 191...
# 2017-03-07 18:48:03,596 INFO > [done]    Resizing patient pixels 191 (4730.492 ms)
# 2017-03-07 18:48:03,601 INFO > [started] Resizing patient pixels 192...
# 2017-03-07 18:48:08,373 INFO > [done]    Resizing patient pixels 192 (4772.069 ms)
# 2017-03-07 18:48:08,378 INFO > [started] Resizing patient pixels 193...
# 2017-03-07 18:48:13,263 INFO > [done]    Resizing patient pixels 193 (4885.082 ms)
# 2017-03-07 18:48:13,268 INFO > [started] Resizing patient pixels 194...
# 2017-03-07 18:48:18,192 INFO > [done]    Resizing patient pixels 194 (4923.474 ms)
# 2017-03-07 18:48:18,197 INFO > [started] Resizing patient pixels 195...
# 2017-03-07 18:48:23,521 INFO > [done]    Resizing patient pixels 195 (5324.178 ms)
# 2017-03-07 18:48:23,527 INFO > [started] Resizing patient pixels 196...
# 2017-03-07 18:48:28,518 INFO > [done]    Resizing patient pixels 196 (4991.758 ms)
# 2017-03-07 18:48:28,524 INFO > [started] Resizing patient pixels 197...
# 2017-03-07 18:48:33,473 INFO > [done]    Resizing patient pixels 197 (4949.231 ms)
# 2017-03-07 18:48:33,478 INFO > [started] Resizing patient pixels 198...
# 2017-03-07 18:48:38,361 INFO > [done]    Resizing patient pixels 198 (4882.744 ms)
# 2017-03-07 18:48:38,366 INFO > [started] Resizing patient pixels 199...
# 2017-03-07 18:48:43,301 INFO > [done]    Resizing patient pixels 199 (4934.237 ms)
# 2017-03-07 18:48:43,306 INFO > [started] Resizing patient pixels 200...
# 2017-03-07 18:48:48,018 INFO > [done]    Resizing patient pixels 200 (4712.406 ms)
# 2017-03-07 18:48:48,023 INFO > [started] Resizing patient pixels 201...
# 2017-03-07 18:48:53,034 INFO > [done]    Resizing patient pixels 201 (5011.003 ms)
# 2017-03-07 18:48:53,039 INFO > [started] Resizing patient pixels 202...
# 2017-03-07 18:48:57,909 INFO > [done]    Resizing patient pixels 202 (4869.971 ms)
# 2017-03-07 18:48:57,914 INFO > [started] Resizing patient pixels 203...
# 2017-03-07 18:49:02,850 INFO > [done]    Resizing patient pixels 203 (4935.627 ms)
# 2017-03-07 18:49:02,855 INFO > [started] Resizing patient pixels 204...
# 2017-03-07 18:49:07,751 INFO > [done]    Resizing patient pixels 204 (4895.507 ms)
# 2017-03-07 18:49:07,756 INFO > [started] Resizing patient pixels 205...
# 2017-03-07 18:49:12,636 INFO > [done]    Resizing patient pixels 205 (4880.198 ms)
# 2017-03-07 18:49:12,641 INFO > [started] Resizing patient pixels 206...
