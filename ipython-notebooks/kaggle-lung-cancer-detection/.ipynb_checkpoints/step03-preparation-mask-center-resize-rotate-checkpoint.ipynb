# %%
IMAGE_DIMS = (224, 152, 224, 1)

NR_SHARDS = 50
RANDOM_SEED = 0.1
SAVE_IMAGES = True

#Patient DICOM images folder
INPUT_FOLDER = '../../../input/kaggle-bowl/stage1_images/'
LABELS_FILE = '../../../input/kaggle-bowl/stage1_labels.csv'

BASE_OUTPUT_FOLDER = '../../../output/kaggle-bowl/step3/'

# %%
import csv
import sys
import h5py
import pandas as pd
import os
import numpy as np # linear algebra
from numpy import ndarray
from random import shuffle
import csv
import os

from modules.logging import logger
import modules.logging
import modules.lungprepare as lungprepare
import modules.utils as utils
from modules.utils import Timer
import modules.logging

from multiprocessing import Pool
import multiprocessing as mp

# %%
def get_patient_ids(shard_id, input_dir):
    shard_patients = []
    
    file = csv.DictReader(open(LABELS_FILE))    
    for row in file:
        p = row['id']
        if(int(p,16)%NR_SHARDS == (shard_id-1)):
            shard_patients.append(p)
    logger.info('found {} patients for shard {}'.format(len(shard_patients), shard_id))
    shuffle(shard_patients, lambda: RANDOM_SEED)
    return shard_patients

#     force ids
#     return ['0c37613214faddf8701ca41e6d43f56e', '0a0c32c9e08cc2ea76a71649de56be6d', '0a38e7597ca26f9374f8ea2770ba870d']
#     return ['0c37613214faddf8701ca41e6d43f56e']

# %%
def patient_label(input_dir, patient_id):
    labels = pd.read_csv(LABELS_FILE, index_col=0)
    value = labels.get_value(patient_id, 'cancer')
    #one-hot encoding
    label = np.array([0,1])
    if(value == 0): label = np.array([1,0])
    return label

# %%
def start_processing(input_dir, shard_id, max_patients, image_dims, base_output_dir):
    t = Timer('shard', debug=False)
    output_dir = base_output_dir + str(shard_id) + '/'
    logger.info('Processing patients. shard_id=' + str(shard_id) + ' max_patients='+ str(max_patients) + ' input_dir=' + input_dir + ' output_dir=' + output_dir)
    
    #check if this shard was already processed
    file_done = output_dir + 'done'
    if(os.path.isfile(file_done)):
        logger.warning('Shard ' + str(shard_id) + ' already processed. Skipping it.')
        return 'shard ' + str(shard_id) + ': SKIPPED'

    logger.info('Gathering patient ids for this shard')
    patient_ids = get_patient_ids(shard_id, input_dir)
    total_patients = len(patient_ids)
    
    dataset_name = 'data-centered-rotated'

    logger.info('Preparing output dir')
    utils.mkdirs(output_dir, dirs=['images'], recreate=True)

    modules.logging.setup_file_logger(base_output_dir + 'out.log')

    logger.info('Creating datasets')
    dataset_file = utils.dataset_path(output_dir, dataset_name, image_dims)
    with h5py.File(dataset_file, 'w') as h5f:
        x_ds = h5f.create_dataset('X', (total_patients, image_dims[0], image_dims[1], image_dims[2], image_dims[3]), chunks=(1, image_dims[0], image_dims[1], image_dims[2], image_dims[3]), dtype='f')
        y_ds = h5f.create_dataset('Y', (total_patients, 2), dtype='f')

        logger.info('Starting to process each patient (count={})'.format(len(patient_ids)))
        count = 0
        record_row = 0

        for patient_id in patient_ids:
            if(count>(max_patients-1)):
                break

            t = Timer('>>> PATIENT PROCESSING ' + patient_id + ' (count=' + str(count) + '; output_dir=' + output_dir + ')')
            patient_pixels = lungprepare.process_patient_images(input_dir + patient_id, image_dims)
            if(patient_pixels != None):
                if(not np.any(patient_pixels)):
                    logger.error('Patient pixels returned with zero values patient_id=' + patient_id)
                logger.info('Recording patient pixels to output dataset count=' + str(count))
                x_ds[record_row] = patient_pixels
                label = patient_label(input_dir, patient_id)
                y_ds[record_row] = label
                record_row = record_row + 1
            else:
                logger.warning('Patient lung not found. Skipping.')   

            t.stop()
            count = count + 1

    if(not utils.validate_dataset(output_dir, dataset_name, image_dims, save_dir=output_dir + 'images/')):
        logger.error('Validation ERROR on shard ' + str(shard_id))
        return 'shard ' + str(shard_id) + ': ERROR ' + str(t.elapsed()*1000) + 'ms'

    logger.info('Marking shard as processed')
    f = open(file_done, 'w')
    f.write('OK')
    f.close()
    
    return 'shard ' + str(shard_id) + ': OK ' + str(t.elapsed()*1000) + 'ms'

# %%
logger.info('==== PROCESSING SHARDS IN PARALLEL ====')

def process_shard(shard_id):
    return start_processing(INPUT_FOLDER, shard_id, 1, IMAGE_DIMS, BASE_OUTPUT_FOLDER)

#mp.set_start_method('spawn')
n_processes = mp.cpu_count()
#n_processes = 1
logger.info('Using ' + str(n_processes) + ' parallel tasks')

with Pool(n_processes) as p:
    shards = list(range(1,NR_SHARDS+1))
    shuffle(shards)
    #http://stackoverflow.com/questions/26520781/multiprocessing-pool-whats-the-difference-between-map-async-and-imap
    for i in p.imap_unordered(process_shard, shards):
        print(i)

logger.info('==== ALL DONE ====')
# Out:
# 2017-02-28 00:23:05,401 INFO ==== PROCESSING SHARDS IN PARALLEL ====
# 2017-02-28 00:23:05,403 INFO Using 1 parallel tasks
# 2017-02-28 00:23:05,413 INFO Processing patients. shard_id=47 max_patients=1 input_dir=../../../input/kaggle-bowl/stage1_images/ output_dir=../../../output/kaggle-bowl/step3/47/
# 2017-02-28 00:23:05,417 INFO Gathering patient ids for this shard
# 2017-02-28 00:23:05,422 INFO found 25 patients for shard 47
# 2017-02-28 00:23:05,424 INFO Preparing output dir
# 2017-02-28 00:23:05,425 INFO Creating datasets
# 2017-02-28 00:23:05,428 INFO Starting to process each patient (count=25)
# 2017-02-28 00:23:05,430 INFO > [started] >>> PATIENT PROCESSING 4d8f4de444a1f453e7ad32d067b0f630 (count=0; output_dir=../../../output/kaggle-bowl/step3/47/)...
# 2017-02-28 00:23:05,431 INFO > [started] load_scan ../../../input/kaggle-bowl/stage1_images/4d8f4de444a1f453e7ad32d067b0f630...
# 2017-02-28 00:23:09,175 INFO > [done]    load_scan ../../../input/kaggle-bowl/stage1_images/4d8f4de444a1f453e7ad32d067b0f630 (3744.068 ms)
# 2017-02-28 00:23:09,391 INFO > [started] resample...
# 2017-02-28 00:23:21,618 INFO > [done]    resample (12226.974 ms)
# 2017-02-28 00:23:21,620 INFO > [started] segment_lung_mask...
# 2017-02-28 00:23:25,160 DEBUG bgs[0, 1, 1, 1, 1, 1, 1, 10, 12, 2]
# 2017-02-28 00:23:25,243 DEBUG lung_label52
# 2017-02-28 00:23:25,245 DEBUG remove non lung structures
# 2017-02-28 00:23:38,182 INFO Summary
# 2017-02-28 00:23:38,183 INFO X shape=(25, 224, 152, 224, 1)
# 2017-02-28 00:23:38,184 INFO Y shape=(25, 2)
# 2017-02-28 00:23:38,186 INFO Y: total: 25
# 2017-02-28 00:23:38,187 INFO Y: label 0: 1.0 4.0%
# 2017-02-28 00:23:38,188 INFO Y: label 1: 0.0 0.0%
# 2017-02-28 00:23:38,190 INFO Recording sample data
# 2017-02-28 00:23:38,191 INFO patient_index 0
# 2017-02-28 00:23:38,192 INFO x=
# 2017-02-28 00:23:39,963 INFO y=[ 1.  0.]
# 2017-02-28 00:23:39,965 INFO patient_index 8
# 2017-02-28 00:23:39,967 INFO x=
# 2017-02-28 00:23:41,770 INFO y=[ 0.  0.]
# 2017-02-28 00:23:41,773 INFO patient_index 17
# 2017-02-28 00:23:41,774 INFO x=
# 2017-02-28 00:23:43,573 INFO y=[ 0.  0.]
# 2017-02-28 00:23:43,575 ERROR Validation ERROR on shard 47
# 2017-02-28 00:23:43,577 INFO Processing patients. shard_id=11 max_patients=1 input_dir=../../../input/kaggle-bowl/stage1_images/ output_dir=../../../output/kaggle-bowl/step3/11/
# 2017-02-28 00:23:43,579 INFO Gathering patient ids for this shard
# 2017-02-28 00:23:43,584 INFO found 29 patients for shard 11
# 2017-02-28 00:23:43,586 INFO Preparing output dir
# 2017-02-28 00:23:43,587 INFO Creating datasets
# 2017-02-28 00:23:43,589 INFO Starting to process each patient (count=29)
# 2017-02-28 00:23:43,591 INFO > [started] >>> PATIENT PROCESSING 7b4d476d9414c9339269efe47840d2da (count=0; output_dir=../../../output/kaggle-bowl/step3/11/)...
# 2017-02-28 00:23:43,592 INFO > [started] load_scan ../../../input/kaggle-bowl/stage1_images/7b4d476d9414c9339269efe47840d2da...
# shard 47: ERROR 32320.928812026978ms
# 2017-02-28 00:23:51,797 INFO > [done]    load_scan ../../../input/kaggle-bowl/stage1_images/7b4d476d9414c9339269efe47840d2da (8204.308 ms)
# 2017-02-28 00:23:52,188 INFO > [started] resample...
# 2017-02-28 00:24:08,451 INFO > [done]    resample (16263.237 ms)
# 2017-02-28 00:24:08,459 INFO > [started] segment_lung_mask...
# 2017-02-28 00:24:12,027 DEBUG bgs[0, 1, 1, 9, 7, 1, 1, 9, 7, 2]
# 2017-02-28 00:24:12,104 DEBUG lung_label20
# 2017-02-28 00:24:12,106 DEBUG remove non lung structures
# 2017-02-28 00:24:13,199 DEBUG fill_lung_structures
# 2017-02-28 00:24:13,673 INFO > [done]    segment_lung_mask (5213.916 ms)
# 2017-02-28 00:24:13,682 INFO > [started] apply lung mask to image volume...
# 2017-02-28 00:24:13,904 INFO > [done]    apply lung mask to image volume (221.524 ms)
# 2017-02-28 00:24:13,906 INFO > [started] rotate image for optimal pose...
# 2017-02-28 00:24:19,293 INFO > [done]    rotate image for optimal pose (5387.041 ms)
# 2017-02-28 00:24:19,295 INFO > [started] resize image volume to 224x152x224...
# 2017-02-28 00:24:25,773 WARNING VALIDATION ERROR: Invalid label found at index=27 label=[ 0.  0.]
# 2017-02-28 00:24:25,775 WARNING VALIDATION ERROR: Invalid label found at index=28 label=[ 0.  0.]
# 2017-02-28 00:24:25,777 INFO Summary
# 2017-02-28 00:24:25,778 INFO X shape=(29, 224, 152, 224, 1)
# 2017-02-28 00:24:25,780 INFO Y shape=(29, 2)
# 2017-02-28 00:24:25,781 INFO Y: total: 29
# 2017-02-28 00:24:25,783 INFO Y: label 0: 1.0 3.44827586207%
# 2017-02-28 00:24:25,784 INFO Y: label 1: 0.0 0.0%
# 2017-02-28 00:24:25,785 INFO Recording sample data
# 2017-02-28 00:24:25,787 INFO patient_index 0
# 2017-02-28 00:24:25,788 INFO x=
# 2017-02-28 00:24:27,574 INFO y=[ 1.  0.]
# 2017-02-28 00:24:27,576 INFO patient_index 10
# 2017-02-28 00:24:27,578 INFO x=
# 2017-02-28 00:24:29,397 INFO y=[ 0.  0.]
# 2017-02-28 00:24:29,399 INFO patient_index 19
# 2017-02-28 00:24:29,401 INFO x=
# 2017-02-28 00:24:31,131 INFO y=[ 0.  0.]
# 2017-02-28 00:24:31,133 ERROR Validation ERROR on shard 11
# 2017-02-28 00:24:31,135 INFO Processing patients. shard_id=4 max_patients=1 input_dir=../../../input/kaggle-bowl/stage1_images/ output_dir=../../../output/kaggle-bowl/step3/4/
# 2017-02-28 00:24:31,138 INFO Gathering patient ids for this shard
# 2017-02-28 00:24:31,143 INFO found 40 patients for shard 4
# 2017-02-28 00:24:31,145 INFO Preparing output dir
# 2017-02-28 00:24:31,148 INFO Creating datasets
# 2017-02-28 00:24:31,150 INFO Starting to process each patient (count=40)
# 2017-02-28 00:24:31,151 INFO > [started] >>> PATIENT PROCESSING 30b8aa7f5688cab5ff0964f34b715c4d (count=0; output_dir=../../../output/kaggle-bowl/step3/4/)...
# 2017-02-28 00:24:31,152 INFO > [started] load_scan ../../../input/kaggle-bowl/stage1_images/30b8aa7f5688cab5ff0964f34b715c4d...
# shard 11: ERROR 41688.48490715027ms
# 2017-02-28 00:24:34,386 INFO > [done]    load_scan ../../../input/kaggle-bowl/stage1_images/30b8aa7f5688cab5ff0964f34b715c4d (3233.577 ms)
# 2017-02-28 00:24:34,554 INFO > [started] resample...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/lib/python3.4/multiprocessing/pool.py in next(self, timeout)
#     671             try:
# --> 672                 item = self._items.popleft()
#     673             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cbb938d3f34b> in <module>()
#      13     shuffle(shards)
#      14     #http://stackoverflow.com/questions/26520781/multiprocessing-pool-whats-the-difference-between-map-async-and-imap
# ---> 15     for i in p.imap_unordered(process_shard, shards):
#      16         print(i)
#      17
#
# /usr/lib/python3.4/multiprocessing/pool.py in next(self, timeout)
#     674                 if self._index == self._length:
#     675                     raise StopIteration
# --> 676                 self._cond.wait(timeout)
#     677                 try:
#     678                     item = self._items.popleft()
#
# /usr/lib/python3.4/threading.py in wait(self, timeout)
#     288         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     289             if timeout is None:
# --> 290                 waiter.acquire()
#     291                 gotit = True
#     292             else:
#
# KeyboardInterrupt:
