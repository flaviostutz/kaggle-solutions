# %%
INPUT_IMAGE_DIMS = (224, 152, 224, 1)
OUTPUT_IMAGE_DIMS = (50, 34, 50, 1)

DATASET_NAME = '-centered-rotated'

INPUT_FOLDER = '../../input/stage1_some/'
OUTPUT_FOLDER = '../../output/step5/'

# %%
import sys
import h5py
import numpy as np
import shutil
import os
from scipy.ndimage.interpolation import rotate
from scipy.ndimage.interpolation import shift
import scipy
import datetime
import logging

from modules.logging import logger
import modules.logging
import modules.lungprepare as lungprepare
import modules.utils as utils
from modules.utils import Timer
import modules.logging

# %%
def create_xy_datasets(output_dir, name, image_dims, size):
    dataset_file = utils.dataset_path(output_dir, name, image_dims)
    h5f = h5py.File(dataset_file, 'w')
    x_ds = h5f.create_dataset('X', (size, image_dims[0], image_dims[1], image_dims[2], 1), chunks=(1, image_dims[0], image_dims[1], image_dims[2], 1), dtype='f')
    y_ds = h5f.create_dataset('Y', (size, 2), dtype='f')

    logger.debug('input x shape={}'.format(h5f['X'].shape))
    x_ds = h5f['X']
    y_ds = h5f['Y']
    
    return h5f, x_ds, y_ds

# %%
def distribute(input_x_ds, input_y_ds, output_x_ds, output_y_ds, qtty_label0, qtty_label1, non_usable_patients, resize_factor):
    count_label0 = 0
    count_label1 = 0
    output_index = 0
    for i in range(len(input_x_ds)):

        if((count_label0+count_label1)>=len(output_x_ds)):
            logger.warning('Reached max elements in output dataset. Stopping distribution')
            break
        
        if(i in non_usable_patients):
            continue
        
        label = input_y_ds[i]
        valid = False
        
        #distribute label0 sample
        if(label[0]==1 and count_label0<qtty_label0):
            count_label0 = count_label0 + 1
            valid = True

        #distribute label1 sample
        elif(label[1]==1 and count_label1<qtty_label1):
            count_label1 = count_label1 + 1
            valid = True
                           
        if(valid):
            ts = Timer('Resizing patient pixels ' + str(i))
            resize_factor = resize_factor[0:3]#REMOVE LATER
            image_pixels = scipy.ndimage.interpolation.zoom(input_x_ds[i], resize_factor)
            ts.stop()
            image_pixels = np.expand_dims(image_pixels, axis=3)#REMOVE LATER
            output_x_ds[output_index] = image_pixels
            output_y_ds[output_index] = label
            output_index = output_index + 1
            non_usable_patients.append(i)

# %%
def start_processing(input_dir, input_image_dims, output_image_dims, output_dir):
    logger.info('Resizing images. input_dir='+ str(input_dir) + ' output_dir=' + output_dir)
    
    logger.info('Preparing output dir')
    utils.mkdirs(output_dir, dirs=['images'], recreate=True)

    modules.logging.setup_file_logger(output_dir + 'out.log')

    t = Timer('Distributing input dataset among train, validate and test datasets')
    len_input_x_ds = None
    resize_factor = (output_image_dims[0]/input_image_dims[0], output_image_dims[1]/input_image_dims[1], output_image_dims[2]/input_image_dims[2], output_image_dims[3]/input_image_dims[3])
    dataset_file = input_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(input_image_dims[0], input_image_dims[1], input_image_dims[2])
    with h5py.File(dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        len_input_x_ds = len(input_x_ds)
        len_input_y_ds = len(input_y_ds)
        
        if(len_input_x_ds!=len_input_y_ds):
            raise Error('X and Y datasets have different sizes!')

        logger.info('Calculating label 0|1 proportion')
        label_total = np.array([[0,0]])
        for pi in range(len_input_x_ds):
            label_total = np.array(input_y_ds[pi]) + label_total

        label0_total = label_total[0][0]
        label1_total = label_total[0][1]
        
        label0_ratio = label0_total/len_input_y_ds    
        label1_ratio = label1_total/len_input_y_ds   

        logger.info('Y: total: ' + str(len_input_y_ds))
        logger.info('Y: label 0: ' + str(label_total[0][0]) + ' ' + str(100*label0_ratio) + '%')
        logger.info('Y: label 1: ' + str(label_total[0][1]) + ' ' + str(100*label1_ratio) + '%')
        
        logger.info('Calculate patient distribution among datasets')

        distributed_patients = []
#         total_patients = round(len_input_x_ds*0.2)#REMOVE 0.3 LATER
        total_patients = len_input_x_ds
        
        
        #DISTRIBUTE TO TRAIN DATASET
        dataset_name = 'train' + DATASET_NAME
        t = Timer('Distribute to train dataset')
        train_qtty = round(min(min(label0_total*0.85, label1_total*0.85)*2, total_patients*0.8))
        qtty_label0 = round(train_qtty/2)
        qtty_label1 = train_qtty - qtty_label0
        logger.debug('train_qtty=' + str(train_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, train_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()

        total_patients = total_patients - train_qtty
        label0_total = label0_total - qtty_label0
        label1_total = label1_total - qtty_label1
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, output_dir + 'images')

        #DISTRIBUTE TO VALIDATE DATASET
        dataset_name = 'validate' + DATASET_NAME
        t = Timer('Distribute to validate dataset')
        validate_qtty = round(min(min(label0_total*0.5, label1_total*0.5)*2, total_patients*0.5))
        qtty_label0 = round(validate_qtty/2)
        qtty_label1 = validate_qtty - qtty_label0
        logger.debug('validate_qtty=' + str(validate_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, validate_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, output_dir + 'images')

        total_patients = total_patients - validate_qtty
        
        #DISTRIBUTE REMAINING TO TEST DATASET
        dataset_name = 'test' + DATASET_NAME
        t = Timer('Distribute to test dataset')
        test_qtty = total_patients
        qtty_label0 = test_qtty
        qtty_label1 = test_qtty
        logger.debug('test_qtty=' + str(test_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, test_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images')

    t.stop()

# %%
logger.info('==== PROCESSING SHARDS MERGE ====')
start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
logger.info('==== ALL DONE ====')
# Out:
# 2017-02-22 02:35:57,989 INFO ==== PROCESSING SHARDS MERGE ====
# 2017-02-22 02:35:57,991 INFO Resizing images. input_dir=../../input/stage1_some/ output_dir=../../output/step5/
# 2017-02-22 02:35:57,993 INFO Preparing output dir
# 2017-02-22 02:35:58,259 INFO > [started] Distributing input dataset among train, validate and test datasets...
# 2017-02-22 02:35:58,262 INFO input x shape=(231, 224, 152, 224)
# 2017-02-22 02:35:58,264 INFO Calculating label 0|1 proportion
# 2017-02-22 02:35:58,292 INFO Y: total: 231
# 2017-02-22 02:35:58,293 INFO Y: label 0: 166.0 71.8614718615%
# 2017-02-22 02:35:58,294 INFO Y: label 1: 65.0 28.1385281385%
# 2017-02-22 02:35:58,295 INFO Calculate patient distribution among datasets
# 2017-02-22 02:35:58,296 INFO > [started] Distribute to train dataset...
# 2017-02-22 02:35:58,298 DEBUG train_qtty=110.0 qtty_label0=55.0 qtty_label1=55.0
# 2017-02-22 02:35:58,303 DEBUG input x shape=(110, 50, 34, 50, 1)
# 2017-02-22 02:35:58,305 INFO > [started] Resizing patient pixels 0...
# 2017-02-22 02:35:59,034 INFO > [done]    Resizing patient pixels 0 (729.645 ms)
# 2017-02-22 02:35:59,036 INFO > [started] Resizing patient pixels 1...
# 2017-02-22 02:35:59,451 INFO > [done]    Resizing patient pixels 1 (414.225 ms)
# 2017-02-22 02:35:59,452 INFO > [started] Resizing patient pixels 2...
# 2017-02-22 02:35:59,811 INFO > [done]    Resizing patient pixels 2 (358.253 ms)
# 2017-02-22 02:35:59,813 INFO > [started] Resizing patient pixels 3...
# 2017-02-22 02:36:00,167 INFO > [done]    Resizing patient pixels 3 (354.405 ms)
# 2017-02-22 02:36:00,169 INFO > [started] Resizing patient pixels 4...
# 2017-02-22 02:36:00,507 INFO > [done]    Resizing patient pixels 4 (337.829 ms)
# 2017-02-22 02:36:00,509 INFO > [started] Resizing patient pixels 5...
# 2017-02-22 02:36:00,848 INFO > [done]    Resizing patient pixels 5 (338.932 ms)
# 2017-02-22 02:36:00,851 INFO > [started] Resizing patient pixels 6...
# 2017-02-22 02:36:01,150 INFO > [done]    Resizing patient pixels 6 (299.617 ms)
# 2017-02-22 02:36:01,152 INFO > [started] Resizing patient pixels 7...
# 2017-02-22 02:36:01,455 INFO > [done]    Resizing patient pixels 7 (303.159 ms)
# 2017-02-22 02:36:01,457 INFO > [started] Resizing patient pixels 8...
# 2017-02-22 02:36:01,744 INFO > [done]    Resizing patient pixels 8 (286.283 ms)
# 2017-02-22 02:36:01,746 INFO > [started] Resizing patient pixels 9...
# 2017-02-22 02:36:02,034 INFO > [done]    Resizing patient pixels 9 (288.112 ms)
# 2017-02-22 02:36:02,036 INFO > [started] Resizing patient pixels 10...
# 2017-02-22 02:36:02,333 INFO > [done]    Resizing patient pixels 10 (296.851 ms)
# 2017-02-22 02:36:02,335 INFO > [started] Resizing patient pixels 11...
# 2017-02-22 02:36:02,638 INFO > [done]    Resizing patient pixels 11 (302.957 ms)
# 2017-02-22 02:36:02,640 INFO > [started] Resizing patient pixels 12...
# 2017-02-22 02:36:02,917 INFO > [done]    Resizing patient pixels 12 (277.084 ms)
# 2017-02-22 02:36:02,919 INFO > [started] Resizing patient pixels 13...
# 2017-02-22 02:36:03,230 INFO > [done]    Resizing patient pixels 13 (310.926 ms)
# 2017-02-22 02:36:03,232 INFO > [started] Resizing patient pixels 14...
# 2017-02-22 02:36:03,557 INFO > [done]    Resizing patient pixels 14 (324.738 ms)
# 2017-02-22 02:36:03,559 INFO > [started] Resizing patient pixels 15...
# 2017-02-22 02:36:03,880 INFO > [done]    Resizing patient pixels 15 (321.102 ms)
# 2017-02-22 02:36:03,882 INFO > [started] Resizing patient pixels 16...
# 2017-02-22 02:36:04,190 INFO > [done]    Resizing patient pixels 16 (307.338 ms)
# 2017-02-22 02:36:04,192 INFO > [started] Resizing patient pixels 17...
# 2017-02-22 02:36:04,542 INFO > [done]    Resizing patient pixels 17 (349.965 ms)
# 2017-02-22 02:36:04,544 INFO > [started] Resizing patient pixels 18...
# 2017-02-22 02:36:04,872 INFO > [done]    Resizing patient pixels 18 (328.154 ms)
# 2017-02-22 02:36:04,874 INFO > [started] Resizing patient pixels 19...
# 2017-02-22 02:36:05,211 INFO > [done]    Resizing patient pixels 19 (336.786 ms)
# 2017-02-22 02:36:05,213 INFO > [started] Resizing patient pixels 20...
# 2017-02-22 02:36:05,587 INFO > [done]    Resizing patient pixels 20 (373.772 ms)
# 2017-02-22 02:36:05,589 INFO > [started] Resizing patient pixels 21...
# 2017-02-22 02:36:05,938 INFO > [done]    Resizing patient pixels 21 (349.369 ms)
# 2017-02-22 02:36:05,941 INFO > [started] Resizing patient pixels 22...
# 2017-02-22 02:36:06,264 INFO > [done]    Resizing patient pixels 22 (323.097 ms)
# 2017-02-22 02:36:06,267 INFO > [started] Resizing patient pixels 23...
# 2017-02-22 02:36:06,597 INFO > [done]    Resizing patient pixels 23 (329.766 ms)
# 2017-02-22 02:36:06,598 INFO > [started] Resizing patient pixels 24...
# 2017-02-22 02:36:06,926 INFO > [done]    Resizing patient pixels 24 (327.878 ms)
# 2017-02-22 02:36:06,928 INFO > [started] Resizing patient pixels 25...
# 2017-02-22 02:36:07,271 INFO > [done]    Resizing patient pixels 25 (342.750 ms)
# 2017-02-22 02:36:07,273 INFO > [started] Resizing patient pixels 26...
# 2017-02-22 02:36:07,600 INFO > [done]    Resizing patient pixels 26 (326.576 ms)
# 2017-02-22 02:36:07,602 INFO > [started] Resizing patient pixels 27...
# 2017-02-22 02:36:07,940 INFO > [done]    Resizing patient pixels 27 (338.096 ms)
# 2017-02-22 02:36:07,942 INFO > [started] Resizing patient pixels 28...
# 2017-02-22 02:36:08,247 INFO > [done]    Resizing patient pixels 28 (305.074 ms)
# 2017-02-22 02:36:08,249 INFO > [started] Resizing patient pixels 29...
# 2017-02-22 02:36:08,533 INFO > [done]    Resizing patient pixels 29 (283.556 ms)
# 2017-02-22 02:36:08,535 INFO > [started] Resizing patient pixels 30...
# 2017-02-22 02:36:08,851 INFO > [done]    Resizing patient pixels 30 (316.421 ms)
# 2017-02-22 02:36:08,853 INFO > [started] Resizing patient pixels 31...
# 2017-02-22 02:36:09,262 INFO > [done]    Resizing patient pixels 31 (408.890 ms)
# 2017-02-22 02:36:09,264 INFO > [started] Resizing patient pixels 32...
# 2017-02-22 02:36:09,669 INFO > [done]    Resizing patient pixels 32 (404.860 ms)
# 2017-02-22 02:36:09,671 INFO > [started] Resizing patient pixels 33...
# 2017-02-22 02:36:09,954 INFO > [done]    Resizing patient pixels 33 (282.812 ms)
# 2017-02-22 02:36:09,956 INFO > [started] Resizing patient pixels 34...
# 2017-02-22 02:36:10,238 INFO > [done]    Resizing patient pixels 34 (282.168 ms)
# 2017-02-22 02:36:10,240 INFO > [started] Resizing patient pixels 35...
# 2017-02-22 02:36:10,513 INFO > [done]    Resizing patient pixels 35 (272.353 ms)
# 2017-02-22 02:36:10,515 INFO > [started] Resizing patient pixels 36...
# 2017-02-22 02:36:10,865 INFO > [done]    Resizing patient pixels 36 (350.362 ms)
# 2017-02-22 02:36:10,868 INFO > [started] Resizing patient pixels 37...
# 2017-02-22 02:36:11,279 INFO > [done]    Resizing patient pixels 37 (411.238 ms)
# 2017-02-22 02:36:11,281 INFO > [started] Resizing patient pixels 38...
# 2017-02-22 02:36:11,557 INFO > [done]    Resizing patient pixels 38 (275.491 ms)
# 2017-02-22 02:36:11,559 INFO > [started] Resizing patient pixels 39...
# 2017-02-22 02:36:11,853 INFO > [done]    Resizing patient pixels 39 (293.655 ms)
# 2017-02-22 02:36:11,855 INFO > [started] Resizing patient pixels 40...
# 2017-02-22 02:36:12,176 INFO > [done]    Resizing patient pixels 40 (321.253 ms)
# 2017-02-22 02:36:12,178 INFO > [started] Resizing patient pixels 41...
# 2017-02-22 02:36:12,514 INFO > [done]    Resizing patient pixels 41 (335.119 ms)
# 2017-02-22 02:36:12,516 INFO > [started] Resizing patient pixels 42...
# 2017-02-22 02:36:13,037 INFO > [done]    Resizing patient pixels 42 (520.878 ms)
# 2017-02-22 02:36:13,039 INFO > [started] Resizing patient pixels 43...
# 2017-02-22 02:36:13,501 INFO > [done]    Resizing patient pixels 43 (462.224 ms)
# 2017-02-22 02:36:13,503 INFO > [started] Resizing patient pixels 44...
# 2017-02-22 02:36:13,979 INFO > [done]    Resizing patient pixels 44 (475.982 ms)
# 2017-02-22 02:36:13,981 INFO > [started] Resizing patient pixels 45...
# 2017-02-22 02:36:14,314 INFO > [done]    Resizing patient pixels 45 (332.334 ms)
# 2017-02-22 02:36:14,316 INFO > [started] Resizing patient pixels 46...
# 2017-02-22 02:36:14,685 INFO > [done]    Resizing patient pixels 46 (369.029 ms)
# 2017-02-22 02:36:14,687 INFO > [started] Resizing patient pixels 47...
# 2017-02-22 02:36:14,996 INFO > [done]    Resizing patient pixels 47 (308.875 ms)
# 2017-02-22 02:36:14,998 INFO > [started] Resizing patient pixels 48...
# 2017-02-22 02:36:16,170 INFO > [done]    Resizing patient pixels 48 (1172.658 ms)
# 2017-02-22 02:36:16,172 INFO > [started] Resizing patient pixels 49...
# 2017-02-22 02:36:16,680 INFO > [done]    Resizing patient pixels 49 (507.807 ms)
# 2017-02-22 02:36:16,683 INFO > [started] Resizing patient pixels 50...
# 2017-02-22 02:36:17,096 INFO > [done]    Resizing patient pixels 50 (413.068 ms)
# 2017-02-22 02:36:17,098 INFO > [started] Resizing patient pixels 51...
# 2017-02-22 02:36:17,408 INFO > [done]    Resizing patient pixels 51 (310.202 ms)
# 2017-02-22 02:36:17,410 INFO > [started] Resizing patient pixels 52...
# 2017-02-22 02:36:17,716 INFO > [done]    Resizing patient pixels 52 (306.038 ms)
# 2017-02-22 02:36:17,718 INFO > [started] Resizing patient pixels 53...
# 2017-02-22 02:36:18,113 INFO > [done]    Resizing patient pixels 53 (394.951 ms)
# 2017-02-22 02:36:18,115 INFO > [started] Resizing patient pixels 54...
# 2017-02-22 02:36:18,529 INFO > [done]    Resizing patient pixels 54 (414.652 ms)
# 2017-02-22 02:36:18,531 INFO > [started] Resizing patient pixels 55...
# 2017-02-22 02:36:18,813 INFO > [done]    Resizing patient pixels 55 (281.848 ms)
# 2017-02-22 02:36:18,815 INFO > [started] Resizing patient pixels 56...
# 2017-02-22 02:36:19,097 INFO > [done]    Resizing patient pixels 56 (281.459 ms)
# 2017-02-22 02:36:19,099 INFO > [started] Resizing patient pixels 57...
# 2017-02-22 02:36:19,424 INFO > [done]    Resizing patient pixels 57 (325.327 ms)
# 2017-02-22 02:36:19,426 INFO > [started] Resizing patient pixels 58...
# 2017-02-22 02:36:19,709 INFO > [done]    Resizing patient pixels 58 (283.102 ms)
# 2017-02-22 02:36:19,711 INFO > [started] Resizing patient pixels 59...
# 2017-02-22 02:36:20,068 INFO > [done]    Resizing patient pixels 59 (356.771 ms)
# 2017-02-22 02:36:20,070 INFO > [started] Resizing patient pixels 60...
# 2017-02-22 02:36:20,365 INFO > [done]    Resizing patient pixels 60 (294.722 ms)
# 2017-02-22 02:36:20,367 INFO > [started] Resizing patient pixels 61...
# 2017-02-22 02:36:20,654 INFO > [done]    Resizing patient pixels 61 (287.219 ms)
# 2017-02-22 02:36:20,656 INFO > [started] Resizing patient pixels 62...
# 2017-02-22 02:36:20,970 INFO > [done]    Resizing patient pixels 62 (313.787 ms)
# 2017-02-22 02:36:20,972 INFO > [started] Resizing patient pixels 63...
# 2017-02-22 02:36:21,406 INFO > [done]    Resizing patient pixels 63 (433.844 ms)
# 2017-02-22 02:36:21,408 INFO > [started] Resizing patient pixels 64...
# 2017-02-22 02:36:21,827 INFO > [done]    Resizing patient pixels 64 (418.846 ms)
# 2017-02-22 02:36:21,829 INFO > [started] Resizing patient pixels 65...
# 2017-02-22 02:36:22,265 INFO > [done]    Resizing patient pixels 65 (435.349 ms)
# 2017-02-22 02:36:22,267 INFO > [started] Resizing patient pixels 66...
# 2017-02-22 02:36:22,663 INFO > [done]    Resizing patient pixels 66 (396.317 ms)
# 2017-02-22 02:36:22,665 INFO > [started] Resizing patient pixels 67...
# 2017-02-22 02:36:23,054 INFO > [done]    Resizing patient pixels 67 (389.078 ms)
# 2017-02-22 02:36:23,056 INFO > [started] Resizing patient pixels 68...
# 2017-02-22 02:36:23,380 INFO > [done]    Resizing patient pixels 68 (323.569 ms)
# 2017-02-22 02:36:23,382 INFO > [started] Resizing patient pixels 69...
# 2017-02-22 02:36:23,760 INFO > [done]    Resizing patient pixels 69 (378.171 ms)
# 2017-02-22 02:36:23,762 INFO > [started] Resizing patient pixels 70...
# 2017-02-22 02:36:24,060 INFO > [done]    Resizing patient pixels 70 (297.964 ms)
# 2017-02-22 02:36:24,062 INFO > [started] Resizing patient pixels 71...
# 2017-02-22 02:36:24,360 INFO > [done]    Resizing patient pixels 71 (297.618 ms)
# 2017-02-22 02:36:24,363 INFO > [started] Resizing patient pixels 72...
# 2017-02-22 02:36:24,673 INFO > [done]    Resizing patient pixels 72 (310.735 ms)
# 2017-02-22 02:36:24,676 INFO > [started] Resizing patient pixels 73...
# 2017-02-22 02:36:24,971 INFO > [done]    Resizing patient pixels 73 (294.616 ms)
# 2017-02-22 02:36:24,973 INFO > [started] Resizing patient pixels 74...
# 2017-02-22 02:36:25,296 INFO > [done]    Resizing patient pixels 74 (322.976 ms)
# 2017-02-22 02:36:25,298 INFO > [started] Resizing patient pixels 75...
# 2017-02-22 02:36:25,677 INFO > [done]    Resizing patient pixels 75 (378.530 ms)
# 2017-02-22 02:36:25,679 INFO > [started] Resizing patient pixels 76...
# 2017-02-22 02:36:25,996 INFO > [done]    Resizing patient pixels 76 (317.093 ms)
# 2017-02-22 02:36:25,998 INFO > [started] Resizing patient pixels 77...
# 2017-02-22 02:36:26,303 INFO > [done]    Resizing patient pixels 77 (304.296 ms)
# 2017-02-22 02:36:26,305 INFO > [started] Resizing patient pixels 78...
# 2017-02-22 02:36:26,639 INFO > [done]    Resizing patient pixels 78 (334.336 ms)
# 2017-02-22 02:36:26,641 INFO > [started] Resizing patient pixels 79...
# 2017-02-22 02:36:26,939 INFO > [done]    Resizing patient pixels 79 (298.101 ms)
# 2017-02-22 02:36:26,942 INFO > [started] Resizing patient pixels 82...
# 2017-02-22 02:36:27,241 INFO > [done]    Resizing patient pixels 82 (298.695 ms)
# 2017-02-22 02:36:27,245 INFO > [started] Resizing patient pixels 97...
# 2017-02-22 02:36:27,619 INFO > [done]    Resizing patient pixels 97 (373.586 ms)
# 2017-02-22 02:36:27,622 INFO > [started] Resizing patient pixels 107...
# 2017-02-22 02:36:27,991 INFO > [done]    Resizing patient pixels 107 (369.184 ms)
# 2017-02-22 02:36:27,993 INFO > [started] Resizing patient pixels 108...
# 2017-02-22 02:36:28,514 INFO > [done]    Resizing patient pixels 108 (520.358 ms)
# 2017-02-22 02:36:28,516 INFO > [started] Resizing patient pixels 109...
# 2017-02-22 02:36:28,847 INFO > [done]    Resizing patient pixels 109 (330.961 ms)
# 2017-02-22 02:36:28,849 INFO > [started] Resizing patient pixels 111...
# 2017-02-22 02:36:29,198 INFO > [done]    Resizing patient pixels 111 (348.648 ms)
# 2017-02-22 02:36:29,200 INFO > [started] Resizing patient pixels 112...
# 2017-02-22 02:36:29,498 INFO > [done]    Resizing patient pixels 112 (298.856 ms)
# 2017-02-22 02:36:29,501 INFO > [started] Resizing patient pixels 115...
# 2017-02-22 02:36:29,802 INFO > [done]    Resizing patient pixels 115 (300.807 ms)
# 2017-02-22 02:36:29,804 INFO > [started] Resizing patient pixels 116...
# 2017-02-22 02:36:30,199 INFO > [done]    Resizing patient pixels 116 (395.073 ms)
# 2017-02-22 02:36:30,201 INFO > [started] Resizing patient pixels 117...
# 2017-02-22 02:36:30,601 INFO > [done]    Resizing patient pixels 117 (399.605 ms)
# 2017-02-22 02:36:30,603 INFO > [started] Resizing patient pixels 118...
# 2017-02-22 02:36:30,903 INFO > [done]    Resizing patient pixels 118 (300.817 ms)
# 2017-02-22 02:36:30,906 INFO > [started] Resizing patient pixels 120...
# 2017-02-22 02:36:31,208 INFO > [done]    Resizing patient pixels 120 (302.169 ms)
# 2017-02-22 02:36:31,212 INFO > [started] Resizing patient pixels 124...
# 2017-02-22 02:36:31,526 INFO > [done]    Resizing patient pixels 124 (314.297 ms)
# 2017-02-22 02:36:31,528 INFO > [started] Resizing patient pixels 127...
# 2017-02-22 02:36:31,819 INFO > [done]    Resizing patient pixels 127 (290.952 ms)
# 2017-02-22 02:36:31,822 INFO > [started] Resizing patient pixels 131...
# 2017-02-22 02:36:32,214 INFO > [done]    Resizing patient pixels 131 (392.252 ms)
# 2017-02-22 02:36:32,218 INFO > [started] Resizing patient pixels 136...
# 2017-02-22 02:36:32,554 INFO > [done]    Resizing patient pixels 136 (335.830 ms)
# 2017-02-22 02:36:32,556 INFO > [started] Resizing patient pixels 138...
# 2017-02-22 02:36:33,142 INFO > [done]    Resizing patient pixels 138 (585.415 ms)
# 2017-02-22 02:36:33,145 INFO > [started] Resizing patient pixels 141...
# 2017-02-22 02:36:33,438 INFO > [done]    Resizing patient pixels 141 (293.114 ms)
# 2017-02-22 02:36:33,440 INFO > [started] Resizing patient pixels 145...
# 2017-02-22 02:36:33,781 INFO > [done]    Resizing patient pixels 145 (339.999 ms)
# 2017-02-22 02:36:33,783 INFO > [started] Resizing patient pixels 150...
# 2017-02-22 02:36:34,085 INFO > [done]    Resizing patient pixels 150 (301.697 ms)
# 2017-02-22 02:36:34,087 INFO > [started] Resizing patient pixels 151...
# 2017-02-22 02:36:34,526 INFO > [done]    Resizing patient pixels 151 (438.764 ms)
# 2017-02-22 02:36:34,528 INFO > [started] Resizing patient pixels 153...
# 2017-02-22 02:36:35,438 INFO > [done]    Resizing patient pixels 153 (909.551 ms)
# 2017-02-22 02:36:35,441 INFO > [started] Resizing patient pixels 156...
# 2017-02-22 02:36:35,803 INFO > [done]    Resizing patient pixels 156 (362.365 ms)
# 2017-02-22 02:36:35,805 INFO > [started] Resizing patient pixels 160...
# 2017-02-22 02:36:36,131 INFO > [done]    Resizing patient pixels 160 (325.349 ms)
# 2017-02-22 02:36:36,133 INFO > [started] Resizing patient pixels 161...
# 2017-02-22 02:36:36,431 INFO > [done]    Resizing patient pixels 161 (297.885 ms)
# 2017-02-22 02:36:36,433 INFO > [started] Resizing patient pixels 166...
# 2017-02-22 02:36:36,737 INFO > [done]    Resizing patient pixels 166 (303.966 ms)
# 2017-02-22 02:36:36,742 INFO > [started] Resizing patient pixels 172...
# 2017-02-22 02:36:37,087 INFO > [done]    Resizing patient pixels 172 (344.687 ms)
# 2017-02-22 02:36:37,089 INFO > [started] Resizing patient pixels 174...
# 2017-02-22 02:36:37,483 INFO > [done]    Resizing patient pixels 174 (394.464 ms)
# 2017-02-22 02:36:37,486 INFO > [started] Resizing patient pixels 176...
# 2017-02-22 02:36:37,827 INFO > [done]    Resizing patient pixels 176 (341.226 ms)
# 2017-02-22 02:36:37,830 INFO > [started] Resizing patient pixels 177...
# 2017-02-22 02:36:38,383 INFO > [done]    Resizing patient pixels 177 (553.336 ms)
# 2017-02-22 02:36:38,385 WARNING Reached max elements in output dataset. Stopping distribution
# 2017-02-22 02:36:38,387 INFO > [done]    Distribute to train dataset (40090.710 ms)
# 2017-02-22 02:36:38,387 INFO VALIDATING DATASET ../../output/step5/train-centered-rotated-50-34-50.h5
# 2017-02-22 02:36:38,442 INFO Summary
# 2017-02-22 02:36:38,443 INFO X shape=(110, 50, 34, 50, 1)
# 2017-02-22 02:36:38,444 INFO Y shape=(110, 2)
# 2017-02-22 02:36:38,446 INFO Y: total: 110
# 2017-02-22 02:36:38,447 INFO Y: label 0: 55.0 50.0%
# 2017-02-22 02:36:38,448 INFO Y: label 1: 55.0 50.0%
# 2017-02-22 02:36:38,449 INFO Recording sample data
# 2017-02-22 02:36:38,450 INFO patient_index 0
# 2017-02-22 02:36:38,451 INFO x=
# TypeErrorTraceback (most recent call last)
# <ipython-input-8-9bbcde270ee2> in <module>()
#       1 logger.info('==== PROCESSING SHARDS MERGE ====')
# ----> 2 start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
#       3 logger.info('==== ALL DONE ====')
#
# <ipython-input-7-fe2dc34aecf7> in start_processing(input_dir, input_image_dims, output_image_dims, output_dir)
#      58         label0_total = label0_total - qtty_label0
#      59         label1_total = label1_total - qtty_label1
# ---> 60         utils.validate_dataset(output_dir, dataset_name, output_image_dims, output_dir + 'images')
#      61
#      62         #DISTRIBUTE TO VALIDATE DATASET
#
# /root/workspace/kaggle-lung-cancer-detection/modules/utils.py in validate_dataset(dataset_dir, name, image_dims, save_slices, save_dir)
#      94                 show_slices(x_ds[pi], name + '(' + pi + ')', save_dir)
#      95                 logger.info('y=' + str(y_ds[pi]))
# ---> 96     return ok
#      97
#      98 def dataset_path(dataset_dir, name, image_dims):
#
# TypeError: Can't convert 'int' object to str implicitly
