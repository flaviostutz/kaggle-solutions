# %%
INPUT_IMAGE_DIMS = (224, 152, 224, 1)
OUTPUT_IMAGE_DIMS = (224, 152, 224, 1)
#OUTPUT_IMAGE_DIMS = (112, 76, 112, 1)

DATASET_NAME = '-centered-rotated'

INPUT_FOLDER = '../../../output/kaggle-bowl/step4/'
OUTPUT_FOLDER = '../../../output/kaggle-bowl/step5/'

# %%
import sys
import h5py
import numpy as np
import shutil
import os
from scipy.ndimage.interpolation import rotate
from scipy.ndimage.interpolation import shift
import scipy
import datetime
import logging

from modules.logging import logger
import modules.logging
import modules.lungprepare as lungprepare
import modules.utils as utils
from modules.utils import Timer
import modules.logging

# %%
def create_xy_datasets(output_dir, name, image_dims, size):
    dataset_file = utils.dataset_path(output_dir, name, image_dims)
    h5f = h5py.File(dataset_file, 'w')
    x_ds = h5f.create_dataset('X', (size, image_dims[0], image_dims[1], image_dims[2], 1), chunks=(1, image_dims[0], image_dims[1], image_dims[2], 1), dtype='f')
    y_ds = h5f.create_dataset('Y', (size, 2), dtype='f')

    logger.debug('input x shape={}'.format(h5f['X'].shape))
    x_ds = h5f['X']
    y_ds = h5f['Y']
    
    return h5f, x_ds, y_ds

# %%
def distribute(input_x_ds, input_y_ds, output_x_ds, output_y_ds, qtty_label0, qtty_label1, non_usable_patients, resize_factor):
    count_label0 = 0
    count_label1 = 0
    output_index = 0
    for i in range(len(input_x_ds)):

        if((count_label0+count_label1)>=len(output_x_ds)):
            logger.warning('Reached max elements in output dataset. Stopping distribution')
            break
        
        if(i in non_usable_patients):
            continue
        
        label = input_y_ds[i]
        valid = False
        
        #distribute label0 sample
        if(label[0]==1 and count_label0<qtty_label0):
            count_label0 = count_label0 + 1
            valid = True

        #distribute label1 sample
        elif(label[1]==1 and count_label1<qtty_label1):
            count_label1 = count_label1 + 1
            valid = True
                           
        if(valid):
            ts = Timer('Resizing patient pixels ' + str(i))
#            image_pixels = scipy.ndimage.interpolation.zoom(input_x_ds[i], resize_factor)
            image_pixels = input_x_ds[i]
            ts.stop()
            output_x_ds[output_index] = image_pixels
            output_y_ds[output_index] = label
            output_index = output_index + 1
            non_usable_patients.append(i)

# %%
def start_processing(input_dir, input_image_dims, output_image_dims, output_dir):
    logger.info('Resizing images. input_dir='+ str(input_dir) + ' output_dir=' + output_dir)
    
    logger.info('Preparing output dir')
    utils.mkdirs(output_dir, dirs=['images'], recreate=True)

    modules.logging.setup_file_logger(output_dir + 'out.log')

    t = Timer('Distributing input dataset among train, validate and test datasets')
    len_input_x_ds = None
    resize_factor = (output_image_dims[0]/input_image_dims[0], output_image_dims[1]/input_image_dims[1], output_image_dims[2]/input_image_dims[2], output_image_dims[3]/input_image_dims[3])
    dataset_file = input_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(input_image_dims[0], input_image_dims[1], input_image_dims[2])
    with h5py.File(dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        len_input_x_ds = len(input_x_ds)
        len_input_y_ds = len(input_y_ds)
        
        if(len_input_x_ds!=len_input_y_ds):
            raise Error('X and Y datasets have different sizes!')

        logger.info('Calculating label 0|1 proportion')
        label_total = np.array([[0,0]])
        for pi in range(len_input_x_ds):
            label_total = np.array(input_y_ds[pi]) + label_total

        label0_total = label_total[0][0]
        label1_total = label_total[0][1]
        
        label0_ratio = label0_total/len_input_y_ds    
        label1_ratio = label1_total/len_input_y_ds   

        logger.info('Y: total: ' + str(len_input_y_ds))
        logger.info('Y: label 0: ' + str(label_total[0][0]) + ' ' + str(100*label0_ratio) + '%')
        logger.info('Y: label 1: ' + str(label_total[0][1]) + ' ' + str(100*label1_ratio) + '%')
        
        logger.info('Calculate patient distribution among datasets')

        distributed_patients = []
        total_patients = len_input_x_ds
        
        
        #DISTRIBUTE TO TRAIN DATASET
        dataset_name = 'train' + DATASET_NAME
        t = Timer('Distribute to train dataset')
        train_qtty = round(min(min(label0_total*0.75, label1_total*0.75)*2, total_patients*0.75))
        qtty_label0 = round(train_qtty/2)
        qtty_label1 = train_qtty - qtty_label0
        logger.debug('train_qtty=' + str(train_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, train_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()

        total_patients = total_patients - train_qtty
        label0_total = label0_total - qtty_label0
        label1_total = label1_total - qtty_label1
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

        #DISTRIBUTE TO VALIDATE DATASET
        dataset_name = 'validate' + DATASET_NAME
        t = Timer('Distribute to validate dataset')
        validate_qtty = round(min(min(label0_total*0.5, label1_total*0.5)*2, total_patients*0.5))
        qtty_label0 = round(validate_qtty/2)
        qtty_label1 = validate_qtty - qtty_label0
        logger.debug('validate_qtty=' + str(validate_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, validate_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

        total_patients = total_patients - validate_qtty
        
        #DISTRIBUTE REMAINING TO TEST DATASET
        dataset_name = 'test' + DATASET_NAME
        t = Timer('Distribute to test dataset')
        test_qtty = total_patients
        qtty_label0 = test_qtty
        qtty_label1 = test_qtty
        logger.debug('test_qtty=' + str(test_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
        f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, test_qtty)
        distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
        f.close()
        t.stop()
        utils.validate_dataset(output_dir, dataset_name, output_image_dims, save_dir=output_dir + 'images/')

    t.stop()

# %%
logger.info('==== PROCESSING SHARDS MERGE ====')
start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
logger.info('==== ALL DONE ====')
# Out:
# 2017-03-08 22:59:48,584 INFO ==== PROCESSING SHARDS MERGE ====
# 2017-03-08 22:59:48,586 INFO Resizing images. input_dir=../../../output/kaggle-bowl/step4/ output_dir=../../../input/step5-224/
# 2017-03-08 22:59:48,587 INFO Preparing output dir
# 2017-03-08 22:59:48,589 INFO > [started] Distributing input dataset among train, validate and test datasets...
# 2017-03-08 22:59:48,590 INFO input x shape=(1392, 224, 152, 224, 1)
# 2017-03-08 22:59:48,592 INFO Calculating label 0|1 proportion
# 2017-03-08 22:59:48,770 INFO Y: total: 1392
# 2017-03-08 22:59:48,772 INFO Y: label 0: 1033.0 74.2097701149%
# 2017-03-08 22:59:48,772 INFO Y: label 1: 359.0 25.7902298851%
# 2017-03-08 22:59:48,773 INFO Calculate patient distribution among datasets
# 2017-03-08 22:59:48,774 INFO > [started] Distribute to train dataset...
# 2017-03-08 22:59:48,775 DEBUG train_qtty=538.0 qtty_label0=269.0 qtty_label1=269.0
# 2017-03-08 22:59:48,777 DEBUG input x shape=(538, 224, 152, 224, 1)
# 2017-03-08 22:59:48,779 INFO > [started] Resizing patient pixels 0...
# 2017-03-08 22:59:48,793 INFO > [done]    Resizing patient pixels 0 (14.063 ms)
# 2017-03-08 22:59:48,830 INFO > [started] Resizing patient pixels 1...
# 2017-03-08 22:59:48,843 INFO > [done]    Resizing patient pixels 1 (13.661 ms)
# 2017-03-08 22:59:48,880 INFO > [started] Resizing patient pixels 2...
# 2017-03-08 22:59:48,890 INFO > [done]    Resizing patient pixels 2 (10.069 ms)
# 2017-03-08 22:59:48,922 INFO > [started] Resizing patient pixels 3...
# 2017-03-08 22:59:48,933 INFO > [done]    Resizing patient pixels 3 (11.052 ms)
# 2017-03-08 22:59:48,966 INFO > [started] Resizing patient pixels 4...
# 2017-03-08 22:59:48,977 INFO > [done]    Resizing patient pixels 4 (11.341 ms)
# 2017-03-08 22:59:49,010 INFO > [started] Resizing patient pixels 5...
# 2017-03-08 22:59:49,021 INFO > [done]    Resizing patient pixels 5 (11.069 ms)
# 2017-03-08 22:59:49,053 INFO > [started] Resizing patient pixels 6...
# 2017-03-08 22:59:49,064 INFO > [done]    Resizing patient pixels 6 (10.996 ms)
# 2017-03-08 22:59:49,096 INFO > [started] Resizing patient pixels 7...
# 2017-03-08 22:59:49,107 INFO > [done]    Resizing patient pixels 7 (11.064 ms)
# 2017-03-08 22:59:49,140 INFO > [started] Resizing patient pixels 8...
# 2017-03-08 22:59:49,150 INFO > [done]    Resizing patient pixels 8 (10.731 ms)
# 2017-03-08 22:59:49,183 INFO > [started] Resizing patient pixels 9...
# 2017-03-08 22:59:49,194 INFO > [done]    Resizing patient pixels 9 (10.680 ms)
# 2017-03-08 22:59:49,226 INFO > [started] Resizing patient pixels 10...
# 2017-03-08 22:59:49,237 INFO > [done]    Resizing patient pixels 10 (10.557 ms)
# 2017-03-08 22:59:49,269 INFO > [started] Resizing patient pixels 11...
# 2017-03-08 23:00:15,259 INFO > [done]    Resizing patient pixels 68 (1235.214 ms)
# 2017-03-08 23:00:15,292 INFO > [started] Resizing patient pixels 69...
# 2017-03-08 23:00:16,407 INFO > [done]    Resizing patient pixels 69 (1115.032 ms)
# 2017-03-08 23:00:16,440 INFO > [started] Resizing patient pixels 70...
# 2017-03-08 23:00:17,593 INFO > [done]    Resizing patient pixels 70 (1152.596 ms)
# 2017-03-08 23:00:17,626 INFO > [started] Resizing patient pixels 71...
# 2017-03-08 23:00:18,804 INFO > [done]    Resizing patient pixels 71 (1178.399 ms)
# 2017-03-08 23:00:18,837 INFO > [started] Resizing patient pixels 72...
# 2017-03-08 23:00:19,821 INFO > [done]    Resizing patient pixels 72 (983.673 ms)
# 2017-03-08 23:00:19,853 INFO > [started] Resizing patient pixels 73...
# 2017-03-08 23:00:20,757 INFO > [done]    Resizing patient pixels 73 (903.762 ms)
# 2017-03-08 23:00:20,789 INFO > [started] Resizing patient pixels 74...
# 2017-03-08 23:00:21,699 INFO > [done]    Resizing patient pixels 74 (909.562 ms)
# 2017-03-08 23:00:21,731 INFO > [started] Resizing patient pixels 75...
# 2017-03-08 23:00:22,795 INFO > [done]    Resizing patient pixels 75 (1064.240 ms)
# 2017-03-08 23:00:22,829 INFO > [started] Resizing patient pixels 76...
# 2017-03-08 23:00:23,787 INFO > [done]    Resizing patient pixels 76 (957.600 ms)
# 2017-03-08 23:00:23,820 INFO > [started] Resizing patient pixels 77...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9bbcde270ee2> in <module>()
#       1 logger.info('==== PROCESSING SHARDS MERGE ====')
# ----> 2 start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
#       3 logger.info('==== ALL DONE ====')
#
# <ipython-input-5-381cad641a01> in start_processing(input_dir, input_image_dims, output_image_dims, output_dir)
#      50         logger.debug('train_qtty=' + str(train_qtty) + ' qtty_label0=' + str(qtty_label0) + ' qtty_label1=' + str(qtty_label1))
#      51         f, x_ds, y_ds = create_xy_datasets(output_dir, dataset_name, output_image_dims, train_qtty)
# ---> 52         distribute(input_x_ds, input_y_ds, x_ds, y_ds, qtty_label0, qtty_label1, distributed_patients, resize_factor)
#      53         f.close()
#      54         t.stop()
#
# <ipython-input-4-e00508f38d06> in distribute(input_x_ds, input_y_ds, output_x_ds, output_y_ds, qtty_label0, qtty_label1, non_usable_patients, resize_factor)
#      28             ts = Timer('Resizing patient pixels ' + str(i))
#      29 #            image_pixels = scipy.ndimage.interpolation.zoom(input_x_ds[i], resize_factor)
# ---> 30             image_pixels = input_x_ds[i]
#      31             ts.stop()
#      32             output_x_ds[output_index] = image_pixels
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip-at6d2npe-build/h5py/_objects.c:2684)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip-at6d2npe-build/h5py/_objects.c:2642)()
#
# /usr/local/lib/python3.5/dist-packages/h5py/_hl/dataset.py in __getitem__(self, args)
#     480         mspace = h5s.create_simple(mshape)
#     481         fspace = selection.id
# --> 482         self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     483
#     484         # Patch up the output for NumPy
#
# KeyboardInterrupt:
