# %%
INPUT_IMAGE_DIMS = (224, 152, 224, 1)
OUTPUT_IMAGE_DIMS = (50, 34, 50, 1)

SAVE_IMAGES = True

INPUT_FOLDER = '../../output/step4/'
OUTPUT_FOLDER = '../../output/step5/'

# %%
import sys
import h5py
from random import shuffle
import numpy as np
from numpy import ndarray
import pandas as pd
import statistics
import csv
import dicom
import math
from time import time
import os
import shutil
import scipy.ndimage
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.ndimage as ndimage
from scipy.ndimage.interpolation import rotate
from scipy.ndimage.interpolation import shift
import itertools
from itertools import product, combinations
from skimage import measure, morphology, transform
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import datetime
import logging

# %%
class Timer:
    def __init__(self, name, debug=True):
        self._name = name
        self._debug = debug
        self.start()
    
    def start(self):
        self._start = time()
        if(self._debug):
            logger.info('> [started] ' + self._name + '...')

    def stop(self):
        self._lastElapsed = (time()-self._start)
        if(self._debug):
            logger.info('> [done]    {} ({:.3f} ms)'.format(self._name, self._lastElapsed*1000))
            
    def elapsed(self):
        if(self._lastElapsed != None):
            return (self._lastElapsed)
        else:
            return (time()-self._start)

# %%
logger = logging.getLogger()
formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
sh = logging.StreamHandler()
sh.setLevel(logging.INFO)
sh.setFormatter(formatter)
logger.addHandler(sh)

def setup_file_logger(log_file):
    hdlr = logging.FileHandler(log_file)
    hdlr.setLevel(logging.DEBUG)
    hdlr.setFormatter(formatter)
    logger.addHandler(hdlr) 
    logger.setLevel(logging.DEBUG)

# %%
def show_image(pixels, slice_pos, patient_id):
    fig1, ax1 = plt.subplots(1)
    fig1.set_size_inches(4,4)
    ax1.imshow(pixels[round(np.shape(pixels)[0]*(slice_pos-1))][:,:,0], cmap=plt.cm.gray)
    
    if(SAVE_IMAGES):
        file = OUTPUT_FOLDER + 'images/' + patient_id + '-' + 'slice-' + str(slice_pos) + '.jpg'
        plt.savefig(file)
        plt.close(fig1)
    else:
        plt.show()

# %%
def show_slices(pixels, patient_id, nr_slices=12, cols=4):
    fig = plt.figure()
    slice_depth = round(np.shape(pixels)[0]/nr_slices)
    rows = round(nr_slices/cols)+1
    fig.set_size_inches(cols*10, rows*10)
    for i in range(nr_slices):
        slice_pos = int(slice_depth*i)
        y = fig.add_subplot(rows,cols,i+1)
        y.imshow(pixels[slice_pos][:,:,0], cmap='gray')
        
    if(SAVE_IMAGES):
        file = OUTPUT_FOLDER + 'images/' + patient_id + '-' + 'slices.jpg'
        plt.savefig(file)
        plt.close(fig)
    else:
        plt.show()

# %%
def validate_dataset(dataset_file):
    logger.info('VALIDATING OUTPUT DATASET ' + dataset_file)

    with h5py.File(dataset_file, 'r') as h5f:
        x_ds = h5f['X']
        y_ds = h5f['Y']

        if(len(x_ds) != len(y_ds)):
            logger.error('VALIDATION ERROR: x and y datasets with different lengths')

        for px in range(len(x_ds)):
            arr = np.array(x_ds[px])
            if(not np.any(arr)):
                logger.error('VALIDATION ERROR: No image found index=' + str(px))

        for py in range(len(y_ds)):
            arr = np.array(y_ds[py])
            if(not np.any(arr)):
                logger.error('VALIDATION ERROR: No label found index=' + str(py) + 'label=' + str(arr))

        logger.info('X shape=' + str(x_ds.shape))
        logger.info('Y shape=' + str(y_ds.shape))

        logger.info('Taking some shots from the output sample for later verification')
        size = len(x_ds)
        qtty = min(10, size)
        f = size/qtty
        for i in range(qtty):
            pi = round(i*f)
            logger.info('patient_index ' + str(pi))
            logger.info('x=')
            show_slices(x_ds[pi], 'validation-' + str(pi))
            logger.info('y=' + str(y_ds[pi]))

# %%
def generate_dataset(source_dataset_file, output_dataset_file, source_start_index, source_end_index, image_dims):
    with h5py.File(source_dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        
        output_len = source_end_index - source_start_index
        
        with h5py.File(output_dataset_file, 'w') as output_h5f:
            output_x_ds = output_h5f.create_dataset('X', (output_len, image_dims[0], image_dims[1], image_dims[2], 1), chunks=(1, image_dims[0], image_dims[1], image_dims[2], 1), dtype='f')
            output_y_ds = output_h5f.create_dataset('Y', (output_len, 2), dtype='f')

            output_x_ds[0:output_len] = input_x_ds[source_start_index:source_end_index]
            output_y_ds[0:output_len] = input_y_ds[source_start_index:source_end_index]

# %%
def start_processing(input_dir, input_image_dims, output_image_dims, output_dir):
    logger.info('Resizing images. input_dir='+ str(input_dir) + ' output_dir=' + output_dir)
    
    t = Timer('Preparing output dir')
    shutil.rmtree(output_dir, True)
    try:
        os.makedirs(output_dir + 'images')
    except:
        logger.warning('Ops! Couldnt create output dir')
        pass
    t.stop()

    setup_file_logger(output_dir + 'out.log')

    t = Timer('Starting to resize dataset')
    len_input_x_ds = None
    resize_factor = (output_image_dims[0]/input_image_dims[0], output_image_dims[1]/input_image_dims[1], output_image_dims[2]/input_image_dims[2], 1)
    dataset_file = input_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(input_image_dims[0], input_image_dims[1], input_image_dims[2])
    with h5py.File(dataset_file, 'r') as input_h5f:
        logger.info('input x shape={}'.format(input_h5f['X'].shape))
        input_x_ds = input_h5f['X']
        input_y_ds = input_h5f['Y']
        len_input_x_ds = len(input_x_ds)
        len_input_y_ds = len(input_y_ds)

        output_dataset_file = output_dir + 'data-centered-rotated-{}-{}-{}.h5'.format(output_image_dims[0], output_image_dims[1], output_image_dims[2])
        with h5py.File(output_dataset_file, 'w') as output_h5f:
            output_x_ds = output_h5f.create_dataset('X', (len_input_x_ds, output_image_dims[0], output_image_dims[1], output_image_dims[2], 1), chunks=(1, output_image_dims[0], output_image_dims[1], output_image_dims[2], 1), dtype='f')
            output_y_ds = output_h5f.create_dataset('Y', (len_input_y_ds, 2), dtype='f')

            for pi in range(len_input_x_ds):
                ts = Timer('Resizing patient index ' + str(pi))
                image_pixels = input_x_ds[pi]
#                 image_pixels = np.expand_dims(image_pixels, axis=3)#REMOVE LATER
#                 logger.info('redim shape=' + str(np.shape(image_pixels)))
                image_pixels = scipy.ndimage.interpolation.zoom(image_pixels, resize_factor)
                logger.info('resized shape=' + str(np.shape(image_pixels)))
                output_x_ds[pi] = image_pixels
                output_y_ds[pi] = input_y_ds[pi]
                ts.stop()
    t.stop()
            
    t = Timer('Validate output dataset')
    validate_dataset(output_dataset_file)
    t.stop()
    
    t = Timer('Generate train dataset')
    dataset_file = output_dir + 'train-centered-rotated-{}-{}-{}.h5'.format(output_image_dims[0], output_image_dims[1], output_image_dims[2])
    train_end = round(len_input_x_ds * 0.8)
    generate_dataset(output_dataset_file, dataset_file, 0, train_end, output_image_dims)
#     validate_dataset(dataset_file)
    t.stop()

    t = Timer('Generate validate dataset')
    dataset_file = output_dir + 'validate-centered-rotated-{}-{}-{}.h5'.format(output_image_dims[0], output_image_dims[1], output_image_dims[2])
    validate_end = train_end + round(len_input_x_ds * 0.1)
    generate_dataset(output_dataset_file, dataset_file, train_end, validate_end, output_image_dims)
#     validate_dataset(dataset_file)
    t.stop()
    
    t = Timer('Generate test dataset')
    dataset_file = output_dir + 'test-centered-rotated-{}-{}-{}.h5'.format(output_image_dims[0], output_image_dims[1], output_image_dims[2])
    generate_dataset(output_dataset_file, dataset_file, validate_end, len_input_x_ds, output_image_dims)
#     validate_dataset(dataset_file)
    t.stop()

# %%
logger.info('==== PROCESSING SHARDS MERGE ====')
start_processing(INPUT_FOLDER, INPUT_IMAGE_DIMS, OUTPUT_IMAGE_DIMS, OUTPUT_FOLDER)
logger.info('==== ALL DONE ====')
# Out:
# 2017-02-19 22:09:37,114 INFO ==== PROCESSING SHARDS MERGE ====
# 2017-02-19 22:09:37,115 INFO Resizing images. input_dir=../../output/step4/ output_dir=../../output/step5/
# 2017-02-19 22:09:37,116 INFO > [started] Preparing output dir...
# 2017-02-19 22:09:37,118 INFO > [done]    Preparing output dir (1.326 ms)
# 2017-02-19 22:09:37,119 INFO > [started] Starting to resize dataset...
# 2017-02-19 22:09:37,120 INFO input x shape=(231, 224, 152, 224)
# 2017-02-19 22:09:37,123 INFO > [started] Resizing patient index 0...
# 2017-02-19 22:09:37,162 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:37,862 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:37,864 INFO > [done]    Resizing patient index 0 (740.428 ms)
# 2017-02-19 22:09:37,865 INFO > [started] Resizing patient index 1...
# 2017-02-19 22:09:38,016 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:38,695 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:38,697 INFO > [done]    Resizing patient index 1 (832.328 ms)
# 2017-02-19 22:09:38,698 INFO > [started] Resizing patient index 2...
# 2017-02-19 22:09:38,771 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:39,405 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:39,406 INFO > [done]    Resizing patient index 2 (708.305 ms)
# 2017-02-19 22:09:39,407 INFO > [started] Resizing patient index 3...
# 2017-02-19 22:09:39,482 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:40,140 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:40,142 INFO > [done]    Resizing patient index 3 (735.105 ms)
# 2017-02-19 22:09:40,143 INFO > [started] Resizing patient index 4...
# 2017-02-19 22:09:40,216 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:40,862 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:40,865 INFO > [done]    Resizing patient index 4 (721.156 ms)
# 2017-02-19 22:09:40,866 INFO > [started] Resizing patient index 5...
# 2017-02-19 22:09:40,947 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09:41,601 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:09:41,603 INFO > [done]    Resizing patient index 5 (737.786 ms)
# 2017-02-19 22:09:41,604 INFO > [started] Resizing patient index 6...
# 2017-02-19 22:09:41,677 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:09
INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:17,030 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:17,032 INFO > [done]    Resizing patient index 175 (838.896 ms)
# ...
# 2017-02-19 22:12:21,154 INFO > [started] Resizing patient index 181...
# 2017-02-19 22:12:21,423 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:22,059 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:22,063 INFO > [done]    Resizing patient index 181 (909.334 ms)
# 2017-02-19 22:12:22,064 INFO > [started] Resizing patient index 182...
# 2017-02-19 22:12:22,198 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:22,817 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:22,819 INFO > [done]    Resizing patient index 182 (754.853 ms)
# 2017-02-19 22:12:22,820 INFO > [started] Resizing patient index 183...
# 2017-02-19 22:12:22,966 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:23,603 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:23,610 INFO > [done]    Resizing patient index 183 (789.840 ms)
# 2017-02-19 22:12:23,611 INFO > [started] Resizing patient index 184...
# 2017-02-19 22:12:23,709 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:24,350 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:24,359 INFO > [done]    Resizing patient index 184 (747.597 ms)
# 2017-02-19 22:12:24,360 INFO > [started] Resizing patient index 185...
# 2017-02-19 22:12:24,466 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:25,082 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:25,085 INFO > [done]    Resizing patient index 185 (725.013 ms)
# 2017-02-19 22:12:25,086 INFO > [started] Resizing patient index 186...
# 2017-02-19 22:12:25,176 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:25,803 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:25,806 INFO > [done]    Resizing patient index 186 (719.582 ms)
# 2017-02-19 22:12:25,807 INFO > [started] Resizing patient index 187...
# 2017-02-19 22:12:25,914 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:26,511 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:26,513 INFO > [done]    Resizing patient index 187 (706.224 ms)
# 2017-02-19 22:12:26,514 INFO > [started] Resizing patient index 188...
# 2017-02-19 22:12:26,588 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:27,215 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:27,217 INFO > [done]    Resizing patient index 188 (703.009 ms)
# 2017-02-19 22:12:27,218 INFO > [started] Resizing patient index 189...
# 2017-02-19 22:12:27,339 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:27,984 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:27,990 INFO > [done]    Resizing patient index 189 (771.405 ms)
# 2017-02-19 22:12:27,991 INFO > [started] Resizing patient index 190...
# 2017-02-19 22:12:28,162 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:28,754 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:28,757 INFO > [done]    Resizing patient index 190 (766.570 ms)
# 2017-02-19 22:12:28,758 INFO > [started] Resizing patient index 191...
# 2017-02-19 22:12:28,866 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:29,489 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:29,493 INFO > [done]    Resizing patient index 191 (734.864 ms)
# 2017-02-19 22:12:29,494 INFO > [started] Resizing patient index 192...
# 2017-02-19 22:12:29,585 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:30,180 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:30,182 INFO > [done]    Resizing patient index 192 (688.236 ms)
# 2017-02-19 22:12:30,183 INFO > [started] Resizing patient index 193...
# 2017-02-19 22:12:30,273 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:30,904 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:30,906 INFO > [done]    Resizing patient index 193 (722.767 ms)
# 2017-02-19 22:12:30,907 INFO > [started] Resizing patient index 194...
# 2017-02-19 22:12:30,974 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:31,569 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:31,571 INFO > [done]    Resizing patient index 194 (664.149 ms)
# 2017-02-19 22:12:31,572 INFO > [started] Resizing patient index 195...
# 2017-02-19 22:12:31,658 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:32,305 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:32,308 INFO > [done]    Resizing patient index 195 (735.952 ms)
# 2017-02-19 22:12:32,309 INFO > [started] Resizing patient index 196...
# 2017-02-19 22:12:32,392 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:33,075 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:33,077 INFO > [done]    Resizing patient index 196 (768.004 ms)
# 2017-02-19 22:12:33,078 INFO > [started] Resizing patient index 197...
# 2017-02-19 22:12:33,159 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12
INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:47,362 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:47,365 INFO > [done]    Resizing patient index 214 (870.912 ms)
# 2017-02-19 22:12:47,366 INFO > [started] Resizing patient index 215...
# 2017-02-19 22:12:47,597 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:48,233 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:48,235 INFO > [done]    Resizing patient index 215 (869.766 ms)
# 2017-02-19 22:12:48,236 INFO > [started] Resizing patient index 216...
# 2017-02-19 22:12:48,475 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:49,072 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:49,074 INFO > [done]    Resizing patient index 216 (837.592 ms)
# 2017-02-19 22:12:49,075 INFO > [started] Resizing patient index 217...
# 2017-02-19 22:12:49,196 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:49,788 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:49,792 INFO > [done]    Resizing patient index 217 (716.646 ms)
# 2017-02-19 22:12:49,792 INFO > [started] Resizing patient index 218...
# 2017-02-19 22:12:49,839 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:50,441 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:50,443 INFO > [done]    Resizing patient index 218 (650.925 ms)
# 2017-02-19 22:12:50,444 INFO > [started] Resizing patient index 219...
# 2017-02-19 22:12:50,553 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:51,197 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:51,199 INFO > [done]    Resizing patient index 219 (754.927 ms)
# 2017-02-19 22:12:51,200 INFO > [started] Resizing patient index 220...
# 2017-02-19 22:12:51,322 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:51,944 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:51,946 INFO > [done]    Resizing patient index 220 (745.398 ms)
# 2017-02-19 22:12:51,946 INFO > [started] Resizing patient index 221...
# 2017-02-19 22:12:52,082 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:52,714 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:52,717 INFO > [done]    Resizing patient index 221 (770.292 ms)
# 2017-02-19 22:12:52,719 INFO > [started] Resizing patient index 222...
# 2017-02-19 22:12:52,813 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:53,452 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:53,455 INFO > [done]    Resizing patient index 222 (736.069 ms)
# 2017-02-19 22:12:53,456 INFO > [started] Resizing patient index 223...
# 2017-02-19 22:12:53,544 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:54,172 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:54,174 INFO > [done]    Resizing patient index 223 (718.432 ms)
# 2017-02-19 22:12:54,175 INFO > [started] Resizing patient index 224...
# 2017-02-19 22:12:54,230 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:54,867 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:54,869 INFO > [done]    Resizing patient index 224 (694.052 ms)
# 2017-02-19 22:12:54,870 INFO > [started] Resizing patient index 225...
# 2017-02-19 22:12:54,940 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:55,571 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:55,573 INFO > [done]    Resizing patient index 225 (702.462 ms)
# 2017-02-19 22:12:55,574 INFO > [started] Resizing patient index 226...
# 2017-02-19 22:12:55,727 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:56,348 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:56,350 INFO > [done]    Resizing patient index 226 (776.635 ms)
# 2017-02-19 22:12:56,351 INFO > [started] Resizing patient index 227...
# 2017-02-19 22:12:56,480 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:57,106 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:57,109 INFO > [done]    Resizing patient index 227 (758.201 ms)
# 2017-02-19 22:12:57,110 INFO > [started] Resizing patient index 228...
# 2017-02-19 22:12:57,307 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:57,975 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:57,977 INFO > [done]    Resizing patient index 228 (866.579 ms)
# 2017-02-19 22:12:57,978 INFO > [started] Resizing patient index 229...
# 2017-02-19 22:12:58,158 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:58,765 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:58,767 INFO > [done]    Resizing patient index 229 (789.321 ms)
# 2017-02-19 22:12:58,768 INFO > [started] Resizing patient index 230...
# 2017-02-19 22:12:58,915 INFO redim shape=(224, 152, 224, 1)
# 2017-02-19 22:12:59,549 INFO resized shape=(50, 34, 50, 1)
# 2017-02-19 22:12:59,551 INFO > [done]    Resizing patient index 230 (782.742 ms)
# 2017-02-19 22:12:59,570 INFO > [done]    Starting to resize dataset (202451.416 ms)
# 2017-02-19 22:12:59,571 INFO > [started] Validate output dataset...
# 2017-02-19 22:12:59,573 INFO VALIDATING OUTPUT DATASET ../../output/step5/data-centered-rotated-50-34-50.h5
# 2017-02-19 22:13:00,157 INFO X shape=(231, 50, 34, 50, 1)
# 2017-02-19 22:13:00,158 INFO Y shape=(231, 2)
# 2017-02-19 22:13:00,160 INFO Taking some shots from the output sample for later verification
# 2017-02-19 22:13:00,161 INFO patient_index 0
# 2017-02-19 22:13:00,162 INFO x=
# 2017-02-19 22:13:02,379 INFO y=[ 1.  0.]
# 2017-02-19 22:13:02,380 INFO patient_index 23
# 2017-02-19 22:13:02,381 INFO x=
# 2017-02-19 22:13:04,115 INFO y=[ 1.  0.]
# 2017-02-19 22:13:04,116 INFO patient_index 46
# 2017-02-19 22:13:04,117 INFO x=
# 2017-02-19 22:13:05,953 INFO y=[ 1.  0.]
# 2017-02-19 22:13:05,953 INFO patient_index 69
# 2017-02-19 22:13:05,955 INFO x=
# 2017-02-19 22:13:07,882 INFO y=[ 1.  0.]
# 2017-02-19 22:13:07,883 INFO patient_index 92
# 2017-02-19 22:13:07,884 INFO x=
# 2017-02-19 22:13:09,641 INFO y=[ 1.  0.]
# 2017-02-19 22:13:09,642 INFO patient_index 116
# 2017-02-19 22:13:09,643 INFO x=
# 2017-02-19 22:13:11,485 INFO y=[ 0.  1.]
# 2017-02-19 22:13:11,486 INFO patient_index 139
# 2017-02-19 22:13:11,486 INFO x=
# 2017-02-19 22:13:13,377 INFO y=[ 1.  0.]
# 2017-02-19 22:13:13,378 INFO patient_index 162
# 2017-02-19 22:13:13,378 INFO x=
# 2017-02-19 22:13:15,159 INFO y=[ 1.  0.]
# 2017-02-19 22:13:15,160 INFO patient_index 185
# 2017-02-19 22:13:15,160 INFO x=
# 2017-02-19 22:13:17,120 INFO y=[ 0.  1.]
# 2017-02-19 22:13:17,121 INFO patient_index 208
# 2017-02-19 22:13:17,122 INFO x=
# 2017-02-19 22:13:18,868 INFO y=[ 1.  0.]
# 2017-02-19 22:13:18,869 INFO > [done]    Validate output dataset (19298.186 ms)
# 2017-02-19 22:13:18,871 INFO > [started] Generate train dataset...
# 2017-02-19 22:13:18,873 INFO input x shape=(231, 50, 34, 50, 1)
# 2017-02-19 22:13:19,001 INFO > [done]    Generate train dataset (129.724 ms)
# 2017-02-19 22:13:19,002 INFO > [started] Generate validate dataset...
# 2017-02-19 22:13:19,004 INFO input x shape=(231, 50, 34, 50, 1)
# 2017-02-19 22:13:19,016 INFO > [done]    Generate validate dataset (13.983 ms)
# 2017-02-19 22:13:19,017 INFO > [started] Generate test dataset...
# 2017-02-19 22:13:19,018 INFO input x shape=(231, 50, 34, 50, 1)
# 2017-02-19 22:13:19,030 INFO > [done]    Generate test dataset (12.663 ms)
# 2017-02-19 22:13:19,031 INFO ==== ALL DONE ====
